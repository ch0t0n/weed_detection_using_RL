# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pygame

class TwoAgentGridworldEnv(gym.Env):
    metadata = {'render_modes': ['human', 'print'], "render_fps": 4}
    
    def __init__(self, render_mode=None, grid_size=(10, 10)):
        super(TwoAgentGridworldEnv, self).__init__()
        self.size = grid_size[0]  # The size of the square grid
        self.window_size = 800  # The size of the PyGame window
        
        self.grid_size = grid_size
        self.action_space = spaces.MultiDiscrete([4, 4])  # 4 possible actions for each of the two agents
        self.observation_space = spaces.Tuple((
            spaces.Box(low=0, high=grid_size[0]-1, shape=(2,), dtype=np.int32),
            spaces.Box(low=0, high=grid_size[1]-1, shape=(2,), dtype=np.int32)
        ))
        
        
        assert render_mode is None or render_mode in self.metadata["render_modes"]
        self.render_mode = render_mode
        """
        If human-rendering is used, `self.window` will be a reference
        to the window that we draw to. `self.clock` will be a clock that is used
        to ensure that the environment is rendered at the correct framerate in
        human-mode. They will remain `None` until human-mode is used for the
        first time.
        """
        self.window = None
        self.clock = None
        # Reset the environment and start
        self.reset()

    def reset(self):
        self.agent_positions = [
            np.array([0, 0]),  # Agent 1 starts at top-left corner
            np.array([self.grid_size[0]-1, self.grid_size[1]-1])  # Agent 2 starts at bottom-right corner
        ]
        return self._get_obs()

    def _get_obs(self):
        return {'agent1': self.agent_positions[0], 'agent2': self.agent_positions[1]}

    def step(self, action):
        # Define the movements corresponding to each action
        movements = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # up, down, left, right
        rewards = 0
        
        # Update the positions of both agents
        for i, act in enumerate(action):
            movement = movements[act]
            new_position = self.agent_positions[i] + movement
            # Ensure the new position is within bounds
            new_position = np.clip(new_position, [0, 0], [self.grid_size[0]-1, self.grid_size[1]-1])
            self.agent_positions[i] = new_position
        
        # Placeholder for terminal state and rewards
        done = False
        reward = 0
        
        # If the agents meet at the same position, we can assign a reward or consider it a terminal state
        if np.array_equal(self.agent_positions[0], self.agent_positions[1]):
            done = True
            reward = 10  # Example reward for meeting at the same position
        
        obs = self._get_obs()
        return obs, reward, done, False, {}

    def render(self):
        if self.render_mode == 'print':
            grid = np.zeros(self.grid_size)
            grid[tuple(self.agent_positions[0])] = 1  # Mark the position of the first agent
            grid[tuple(self.agent_positions[1])] = 2  # Mark the position of the second agent
            print(grid)
        elif self.render_mode == 'human':
            if self.window is None: # Initialize pygame if it is not initialized
                pygame.init()
                pygame.display.init()
                self.window = pygame.display.set_mode(
                    (self.window_size, self.window_size)
                )
            if self.clock is None:
                self.clock = pygame.time.Clock()
            
            # Fill the canvas
            canvas = pygame.Surface((self.window_size, self.window_size))
            canvas.fill((255, 255, 255))
            pix_square_size = (
                self.window_size / self.size
            )  # The size of a single grid square in pixels


            # First we draw agent1 square
            pygame.draw.rect(
                canvas,
                (255, 0, 0),
                pygame.Rect(
                    pix_square_size * self.agent_positions[0],
                    (pix_square_size, pix_square_size),
                ),
            )
            # Now we draw the agent2 circle
            pygame.draw.circle(
                canvas,
                (0, 0, 255),
                (self.agent_positions[1] + 0.5) * pix_square_size,
                pix_square_size / 3,
            )
            # Finally, add some gridlines
            for x in range(self.size + 1):
                pygame.draw.line(
                    canvas,
                    0,
                    (0, pix_square_size * x),
                    (self.window_size, pix_square_size * x),
                    width=3,
                )
                pygame.draw.line(
                    canvas,
                    0,
                    (pix_square_size * x, 0),
                    (pix_square_size * x, self.window_size),
                    width=3,
                )
            # The following line copies our drawings from `canvas` to the visible window
            self.window.blit(canvas, canvas.get_rect())
            pygame.event.pump()
            pygame.display.update()

            # We need to ensure that human-rendering occurs at the predefined framerate.
            # The following line will automatically add a delay to keep the framerate stable.
            self.clock.tick(self.metadata["render_fps"])
            
    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()

# %%
# Register the environment
gym.envs.registration.register(
    id='TwoAgentGridworld-v0',
    entry_point=TwoAgentGridworldEnv,
    max_episode_steps=100,
)

# Example of creating and using the environment
env = gym.make('TwoAgentGridworld-v0', render_mode='human')
env.metadata['render_fps'] = 8
obs = env.reset()
env.render()

done = False
while not done:
    action = env.action_space.sample()
    obs, reward, done, _,  info = env.step(action)
    env.render()
    print(f"Obs: {obs}, Reward: {reward}, Done: {done}")
# Out:
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:168: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.deprecation(
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:189: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:143: UserWarning: WARN: The obs returned by the `step()` method was expecting a tuple, actual type: <class 'dict'>
#   logger.warn(f"{pre} was expecting a tuple, actual type: {type(obs)}")
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:131: UserWarning: WARN: The obs returned by the `step()` method was expecting a numpy array, actual type: <class 'str'>
#   logger.warn(
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\spaces\box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Obs: {'agent1': array([0, 1]), 'agent2': array([8, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 2]), 'agent2': array([8, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 3]), 'agent2': array([8, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([7, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([7, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 4]), 'agent2': array([6, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 5]), 'agent2': array([5, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 5]), 'agent2': array([4, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 6]), 'agent2': array([4, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 6]), 'agent2': array([4, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 5]), 'agent2': array([3, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 5]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 5]), 'agent2': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 6]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 7]), 'agent2': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 6]), 'agent2': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 6]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 6]), 'agent2': array([3, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 5]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([3, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([3, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([2, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 8]), 'agent2': array([1, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([1, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([0, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([1, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 5]), 'agent2': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 6]), 'agent2': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 7]), 'agent2': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 7]), 'agent2': array([0, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 7]), 'agent2': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 6]), 'agent2': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 7]), 'agent2': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 7]), 'agent2': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 7]), 'agent2': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 7]), 'agent2': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([1, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([2, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([1, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([2, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([1, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([1, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([1, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 9]), 'agent2': array([1, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([3, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([3, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([1, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([3, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([1, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([0, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([0, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([1, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 4]), 'agent2': array([2, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 4]), 'agent2': array([1, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 4]), 'agent2': array([1, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 4]), 'agent2': array([1, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 3]), 'agent2': array([1, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 3]), 'agent2': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 2]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 2]), 'agent2': array([3, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 2]), 'agent2': array([2, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([2, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 3]), 'agent2': array([1, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 3]), 'agent2': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 3]), 'agent2': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 2]), 'agent2': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 2]), 'agent2': array([0, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 3]), 'agent2': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 3]), 'agent2': array([1, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 3]), 'agent2': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 4]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 3]), 'agent2': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 2]), 'agent2': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 1]), 'agent2': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 1]), 'agent2': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 0]), 'agent2': array([0, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 0]), 'agent2': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 0]), 'agent2': array([2, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 1]), 'agent2': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 2]), 'agent2': array([2, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 3]), 'agent2': array([3, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 2]), 'agent2': array([3, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 1]), 'agent2': array([4, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 2]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 2]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([2, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 4]), 'agent2': array([1, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 4]), 'agent2': array([0, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 5]), 'agent2': array([0, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 6]), 'agent2': array([0, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 6]), 'agent2': array([0, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 6]), 'agent2': array([0, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([0, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([0, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([1, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 4]), 'agent2': array([2, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 4]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 4]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([2, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([4, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([3, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([4, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([4, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([4, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([3, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([2, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([2, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([2, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 5]), 'agent2': array([2, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([5, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 5]), 'agent2': array([6, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([7, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([7, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([8, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 5]), 'agent2': array([7, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([7, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 5]), 'agent2': array([6, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([5, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([6, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([5, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([5, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([5, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([6, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([6, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([6, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([5, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 4]), 'agent2': array([5, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([5, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([5, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([5, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([4, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 3]), 'agent2': array([4, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([3, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 3]), 'agent2': array([3, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 3]), 'agent2': array([2, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 4]), 'agent2': array([2, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 4]), 'agent2': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 7]), 'agent2': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([0, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([1, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([2, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([1, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([1, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 5]), 'agent2': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 4]), 'agent2': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 3]), 'agent2': array([2, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 3]), 'agent2': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 2]), 'agent2': array([2, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 3]), 'agent2': array([3, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 3]), 'agent2': array([4, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 4]), 'agent2': array([5, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 3]), 'agent2': array([5, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 3]), 'agent2': array([6, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 3]), 'agent2': array([6, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 2]), 'agent2': array([5, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 2]), 'agent2': array([6, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 3]), 'agent2': array([6, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 2]), 'agent2': array([5, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 3]), 'agent2': array([6, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 3]), 'agent2': array([7, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([7, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([7, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([7, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([7, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([7, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([7, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([8, 4])}, Reward: 10, Done: True

# %%
env.close()

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pygame

class ThreeAgentGridworldEnv(gym.Env):
    metadata = {'render_modes': ['human', 'print', 'rgb_array'], "render_fps": 4}
    
    def __init__(self, render_mode=None, grid_size=(10, 10)):
        super(ThreeAgentGridworldEnv, self).__init__()
        self.size = grid_size[0]  # The size of the square grid
        self.window_size = 800  # The size of the PyGame window
        
        self.grid_size = grid_size
        self.action_space = spaces.MultiDiscrete([4, 4, 4])  # 4 possible actions for each of the two agents
        self.observation_space = spaces.Tuple((
            spaces.Box(low=0, high=grid_size[0]-1, shape=(2,), dtype=np.int32),
            spaces.Box(low=0, high=grid_size[1]-1, shape=(2,), dtype=np.int32),
            spaces.Box(low=0, high=grid_size[1]-1, shape=(2,), dtype=np.int32)
        ))
        
        
        assert render_mode is None or render_mode in self.metadata["render_modes"]
        self.render_mode = render_mode
        """
        If human-rendering is used, `self.window` will be a reference
        to the window that we draw to. `self.clock` will be a clock that is used
        to ensure that the environment is rendered at the correct framerate in
        human-mode. They will remain `None` until human-mode is used for the
        first time.
        """
        self.window = None
        self.clock = None
        # Reset the environment and start
        self.reset()

    def reset(self, seed=0):
        self.agent_positions = [
            np.array([0, 0]),  # Agent 1 starts at top-left corner
            np.array([self.grid_size[0]-1, self.grid_size[1]-1]),  # Agent 2 starts at bottom-right corner,
            np.array([self.grid_size[0]-3, self.grid_size[1]-3])  # Agent 3 starts at specific position,
        ]
        return self._get_obs(), {}

    def _get_obs(self):
        return {'agent1': self.agent_positions[0], 'agent2': self.agent_positions[1], 'agent3': self.agent_positions[2]}

    def step(self, action):
        # Define the movements corresponding to each action
        movements = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # up, down, left, right
        rewards = 0
        
        # Update the positions of both agents
        for i, act in enumerate(action):
            movement = movements[act]
            new_position = self.agent_positions[i] + movement
            # Ensure the new position is within bounds
            new_position = np.clip(new_position, [0, 0], [self.grid_size[0]-1, self.grid_size[1]-1])
            self.agent_positions[i] = new_position
        
        # Placeholder for terminal state and rewards
        done = False
        reward = 0
        
        # If the agents meet at the same position, we can assign a reward or consider it a terminal state
        if np.array_equal(self.agent_positions[0], self.agent_positions[1]):
            done = True
            reward = 10  # Example reward for meeting at the same position
        
        obs = self._get_obs()
        return obs, reward, done, False, {}

    def render(self):
        if self.render_mode == 'print':
            grid = np.zeros(self.grid_size)
            grid[tuple(self.agent_positions[0])] = 1  # Mark the position of the first agent
            grid[tuple(self.agent_positions[1])] = 2  # Mark the position of the second agent
            print(grid)
        elif self.render_mode == 'human':
            if self.window is None: # Initialize pygame if it is not initialized
                pygame.init()
                pygame.display.init()
                self.window = pygame.display.set_mode(
                    (self.window_size, self.window_size)
                )
            if self.clock is None:
                self.clock = pygame.time.Clock()
            
            # Fill the canvas
            canvas = pygame.Surface((self.window_size, self.window_size))
            canvas.fill((255, 255, 255))
            pix_square_size = (
                self.window_size / self.size
            )  # The size of a single grid square in pixels


            # First we draw agent1 square
            pygame.draw.rect(
                canvas,
                (255, 0, 0),
                pygame.Rect(
                    pix_square_size * self.agent_positions[0],
                    (pix_square_size, pix_square_size),
                ),
            )
            # Now we draw the agent2 circle
            pygame.draw.circle(
                canvas,
                (0, 0, 255),
                (self.agent_positions[1] + 0.5) * pix_square_size,
                pix_square_size / 3,
            )
            # And agent3 circle
            pygame.draw.circle(
                canvas,
                (0, 255, 0),
                (self.agent_positions[2] + 0.5) * pix_square_size,
                pix_square_size / 3,
            )

            # Finally, add some gridlines
            for x in range(self.size + 1):
                pygame.draw.line(
                    canvas,
                    0,
                    (0, pix_square_size * x),
                    (self.window_size, pix_square_size * x),
                    width=3,
                )
                pygame.draw.line(
                    canvas,
                    0,
                    (pix_square_size * x, 0),
                    (pix_square_size * x, self.window_size),
                    width=3,
                )
            # The following line copies our drawings from `canvas` to the visible window
            self.window.blit(canvas, canvas.get_rect())
            pygame.event.pump()
            pygame.display.update()

            # We need to ensure that human-rendering occurs at the predefined framerate.
            # The following line will automatically add a delay to keep the framerate stable.
            self.clock.tick(self.metadata["render_fps"])

        elif self.render_mode == 'rgb_array':  # rgb_array
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(canvas)), axes=(1, 0, 2)
            )
            
    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()

# %%
# Register the environment
gym.envs.registration.register(
    id='ThreeAgentGridworld-v0',
    entry_point=ThreeAgentGridworldEnv,
    max_episode_steps=100,
)

# Example of creating and using the environment
env = gym.make('ThreeAgentGridworld-v0', render_mode='human')
env.metadata['render_fps'] = 8
obs, info = env.reset()
env.render()

done = False
while not done:
    pygame.event.get()
    action = env.action_space.sample()
    obs, reward, done, _,  info = env.step(action)
    env.render()
    print(f"Obs: {obs}, Reward: {reward}, Done: {done}")
# Out:
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:175: UserWarning: WARN: The default seed argument in `Env.reset` should be `None`, otherwise the environment will by default always be deterministic. Actual default: seed=0
#   logger.warn(
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:143: UserWarning: WARN: The obs returned by the `reset()` method was expecting a tuple, actual type: <class 'dict'>
#   logger.warn(f"{pre} was expecting a tuple, actual type: {type(obs)}")
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:131: UserWarning: WARN: The obs returned by the `reset()` method was expecting a numpy array, actual type: <class 'str'>
#   logger.warn(
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\spaces\box.py:240: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:143: UserWarning: WARN: The obs returned by the `step()` method was expecting a tuple, actual type: <class 'dict'>
#   logger.warn(f"{pre} was expecting a tuple, actual type: {type(obs)}")
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:131: UserWarning: WARN: The obs returned by the `step()` method was expecting a numpy array, actual type: <class 'str'>
#   logger.warn(
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Obs: {'agent1': array([0, 1]), 'agent2': array([9, 8]), 'agent3': array([7, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 2]), 'agent2': array([9, 9]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 2]), 'agent2': array([9, 9]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 3]), 'agent2': array([8, 9]), 'agent3': array([9, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 4]), 'agent2': array([8, 8]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 4]), 'agent2': array([8, 9]), 'agent3': array([7, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([8, 9]), 'agent3': array([7, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 3]), 'agent2': array([7, 9]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 3]), 'agent2': array([8, 9]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([8, 8]), 'agent3': array([7, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 4]), 'agent2': array([7, 8]), 'agent3': array([7, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 4]), 'agent2': array([7, 7]), 'agent3': array([6, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 3]), 'agent2': array([6, 7]), 'agent3': array([6, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([6, 8]), 'agent3': array([5, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 2]), 'agent2': array([5, 8]), 'agent3': array([5, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([5, 9]), 'agent3': array([5, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 2]), 'agent2': array([6, 9]), 'agent3': array([4, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([6, 9]), 'agent3': array([4, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 2]), 'agent2': array([6, 9]), 'agent3': array([3, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 1]), 'agent2': array([7, 9]), 'agent3': array([2, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 0]), 'agent2': array([7, 8]), 'agent3': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 0]), 'agent2': array([6, 8]), 'agent3': array([2, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 0]), 'agent2': array([7, 8]), 'agent3': array([2, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 0]), 'agent2': array([7, 9]), 'agent3': array([2, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 0]), 'agent2': array([8, 9]), 'agent3': array([2, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 1]), 'agent2': array([9, 9]), 'agent3': array([3, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 0]), 'agent2': array([9, 8]), 'agent3': array([3, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 1]), 'agent2': array([8, 8]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 1]), 'agent2': array([8, 9]), 'agent3': array([3, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 0]), 'agent2': array([8, 9]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 0]), 'agent2': array([9, 9]), 'agent3': array([3, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 0]), 'agent2': array([8, 9]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 0]), 'agent2': array([8, 8]), 'agent3': array([4, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 0]), 'agent2': array([9, 8]), 'agent3': array([5, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 1]), 'agent2': array([9, 7]), 'agent3': array([4, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 2]), 'agent2': array([9, 7]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 2]), 'agent2': array([8, 7]), 'agent3': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array
 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 9]), 'agent2': array([2, 7]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([1, 7]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([2, 7]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([3, 7]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([3, 8]), 'agent3': array([8, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([2, 8]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([2, 7]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([3, 7]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([2, 7]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 9]), 'agent2': array([2, 8]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 9]), 'agent2': array([3, 8]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 9]), 'agent2': array([3, 9]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([4, 9]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 9]), 'agent2': array([4, 9]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 9]), 'agent2': array([5, 9]), 'agent3': array([8, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 9]), 'agent2': array([6, 9]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([6, 8]), 'agent3': array([9, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([6, 9]), 'agent3': array([9, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([5, 9]), 'agent3': array([9, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([5, 9]), 'agent3': array([8, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([5, 9]), 'agent3': array([8, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([4, 9]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([3, 9]), 'agent3': array([8, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 8]), 'agent2': array([4, 9]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([4, 9]), 'agent3': array([7, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([3, 9]), 'agent3': array([7, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([3, 8]), 'agent3': array([7, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 6]), 'agent2': array([4, 8]), 'agent3': array([7, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 5]), 'agent2': array([4, 7]), 'agent3': array([6, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([4, 6]), 'agent3': array([7, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([3, 6]), 'agent3': array([7, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 3]), 'agent2': array([2, 6]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([1, 6]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([2, 6]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([3, 6]), 'agent3': array([8, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([4, 6]), 'agent3': array([7, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([4, 7]), 'agent3': array([8, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([4, 8]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([4, 9]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([3, 9]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([2, 9]), 'agent3': array([9, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([2, 9]), 'agent3': array([9, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([2, 9]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([1, 9]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([1, 8]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([0, 8]), 'agent3': array([7, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 3]), 'agent2': array([1, 8]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 2]), 'agent2': array([1, 7]), 'agent3': array([9, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 2]), 'agent2': array([1, 6]), 'agent3': array([9, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 3]), 'agent2': array([2, 6]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 2]), 'agent2': array([2, 5]), 'agent3': array([9, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 1]), 'agent2': array([1, 5]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 1]), 'agent2': array([1, 4]), 'agent3': array([9, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 1]), 'agent2': array([0, 4]), 'agent3': array([9, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 1]), 'agent2': array([0, 4]), 'agent3': array([8, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 1]), 'agent2': array([0, 4]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 0]), 'agent2': array([0, 5]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 1]), 'agent2': array([0, 4]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 0]), 'agent2': array([0, 3]), 'agent3': array([7, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 0]), 'agent2': array([0, 2]), 'agent3': array([7, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 1]), 'agent2': array([0, 1]), 'agent3': array([8, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 1]), 'agent2': array([0, 1]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 2]), 'agent2': array([0, 2]), 'agent3': array([7, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 1]), 'agent2': array([1, 2]), 'agent3': array([7, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 2]), 'agent2': array([1, 1]), 'agent3': array([6, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 2]), 'agent2': array([2, 1]), 'agent3': array([6, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 1]), 'agent2': array([2, 0]), 'agent3': array([6, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 0]), 'agent2': array([2, 1]), 'agent3': array([5, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 1]), 'agent2': array([2, 0]), 'agent3': array([5, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 2]), 'agent2': array([2, 0]), 'agent3': array([5, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 3]), 'agent2': array([2, 1]), 'agent3': array([5, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([1, 1]), 'agent3': array([6, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 4]), 'agent2': array([2, 1]), 'agent3': array([6, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 4]), 'agent2': array([2, 0]), 'agent3': array([7, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 5]), 'agent2': array([1, 0]), 'agent3': array([8, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 5]), 'agent2': array([1, 1]), 'agent3': array([8, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([1, 2]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([0, 2]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([1, 2]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([0, 2]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 8]), 'agent2': array([0, 2]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([0, 3]), 'agent3': array([8, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 8]), 'agent2': array([1, 3]), 'agent3': array([8, 6])}, Reward: 0, Done: False
# ...
# Obs: {'agent1': array([7, 9]), 'agent2': array([0, 8]), 'agent3': array([9, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 9]), 'agent2': array([1, 8]), 'agent3': array([9, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([1, 9]), 'agent3': array([9, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([1, 8]), 'agent3': array([9, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([1, 9]), 'agent3': array([9, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([0, 9]), 'agent3': array([8, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([0, 8]), 'agent3': array([8, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([0, 8]), 'agent3': array([8, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 9]), 'agent2': array([0, 9]), 'agent3': array([8, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 9]), 'agent2': array([0, 9]), 'agent3': array([9, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([0, 8]), 'agent3': array([9, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([0, 8]), 'agent3': array([9, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([0, 8]), 'agent3': array([9, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([1, 8]), 'agent3': array([9, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([1, 9]), 'agent3': array([9, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([0, 9]), 'agent3': array([8, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 8]), 'agent2': array([0, 9]), 'agent3': array([7, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([1, 9]), 'agent3': array([7, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 8]), 'agent2': array([1, 8]), 'agent3': array([8, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 9]), 'agent2': array([2, 8]), 'agent3': array([8, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 9]), 'agent2': array([2, 7]), 'agent3': array([7, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 9]), 'agent2': array([2, 6]), 'agent3': array([8, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 9]), 'agent2': array([2, 5]), 'agent3': array([8, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 9]), 'agent2': array([3, 5]), 'agent3': array([7, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([4, 5]), 'agent3': array([7, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([3, 5]), 'agent3': array([8, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 6]), 'agent2': array([3, 6]), 'agent3': array([8, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([2, 6]), 'agent3': array([8, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 6]), 'agent2': array([2, 7]), 'agent3': array([8, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([9, 7]), 'agent2': array([2, 6]), 'agent3': array([8, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([2, 5]), 'agent3': array([8, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([2, 6]), 'agent3': array([8, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([1, 6]), 'agent3': array([9, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 8]), 'agent2': array([2, 6]), 'agent3': array([9, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([8, 7]), 'agent2': array([2, 5]), 'agent3': array([9, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([7, 7]), 'agent2': array([1, 5]), 'agent3': array([9, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 7]), 'agent2': array([1, 6]), 'agent3': array([9, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 6]), 'agent2': array([1, 5]), 'agent3': array([9, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 7]), 'agent2': array([0, 5]), 'agent3': array([8, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 7]), 'agent2': array([0, 6]), 'agent3': array([7, 0])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 7]), 'agent2': array([0, 6]), 'agent3': array([7, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 7]), 'agent2': array([0, 6]), 'agent3': array([6, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 8]), 'agent2': array([0, 5]), 'agent3': array([5, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([6, 8]), 'agent2': array([0, 4]), 'agent3': array([4, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 8]), 'agent2': array([0, 4]), 'agent3': array([4, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 9]), 'agent2': array([1, 4]), 'agent3': array([4, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 9]), 'agent2': array([1, 5]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 8]), 'agent2': array([1, 4]), 'agent3': array([3, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 9]), 'agent2': array([1, 5]), 'agent3': array([2, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 9]), 'agent2': array([2, 5]), 'agent3': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 9]), 'agent2': array([3, 5]), 'agent3': array([1, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 9]), 'agent2': array([3, 6]), 'agent3': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 9]), 'agent2': array([2, 6]), 'agent3': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 9]), 'agent2': array([2, 5]), 'agent3': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 9]), 'agent2': array([2, 4]), 'agent3': array([0, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 9]), 'agent2': array([1, 4]), 'agent3': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 9]), 'agent2': array([0, 4]), 'agent3': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 9]), 'agent2': array([1, 4]), 'agent3': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 8]), 'agent2': array([0, 4]), 'agent3': array([1, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 8]), 'agent2': array([0, 3]), 'agent3': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 8]), 'agent2': array([0, 4]), 'agent3': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([0, 3]), 'agent3': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 7]), 'agent2': array([0, 3]), 'agent3': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([0, 3]), 'agent3': array([0, 9])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 6]), 'agent2': array([1, 3]), 'agent3': array([0, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 6]), 'agent2': array([2, 3]), 'agent3': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 7]), 'agent2': array([2, 4]), 'agent3': array([0, 8])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 6]), 'agent2': array([2, 3]), 'agent3': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 7]), 'agent2': array([2, 4]), 'agent3': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 8]), 'agent2': array([2, 5]), 'agent3': array([0, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 8]), 'agent2': array([1, 5]), 'agent3': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 8]), 'agent2': array([1, 6]), 'agent3': array([1, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 8]), 'agent2': array([0, 6]), 'agent3': array([1, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 7]), 'agent2': array([0, 5]), 'agent3': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 7]), 'agent2': array([0, 6]), 'agent3': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([1, 6]), 'agent3': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 8]), 'agent2': array([1, 5]), 'agent3': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 8]), 'agent2': array([0, 5]), 'agent3': array([0, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 9]), 'agent2': array([0, 4]), 'agent3': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 9]), 'agent2': array([0, 4]), 'agent3': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 8]), 'agent2': array([0, 4]), 'agent3': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([1, 4]), 'agent3': array([0, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 7]), 'agent2': array([0, 4]), 'agent3': array([0, 1])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([0, 3]), 'agent3': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 8]), 'agent2': array([0, 4]), 'agent3': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([0, 3]), 'agent3': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 7]), 'agent2': array([0, 2]), 'agent3': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 7]), 'agent2': array([0, 1]), 'agent3': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 6]), 'agent2': array([0, 0]), 'agent3': array([0, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 6]), 'agent2': array([1, 0]), 'agent3': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 6]), 'agent2': array([0, 0]), 'agent3': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([0, 0]), 'agent3': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 6]), 'agent2': array([0, 0]), 'agent3': array([0, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([0, 0]), 'agent3': array([1, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 7]), 'agent2': array([1, 0]), 'agent3': array([2, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 7]), 'agent2': array([0, 0]), 'agent3': array([2, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 6]), 'agent2': array([0, 0]), 'agent3': array([2, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 5]), 'agent2': array([1, 0]), 'agent3': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 5]), 'agent2': array([2, 0]), 'agent3': array([1, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 4]), 'agent2': array([1, 0]), 'agent3': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 3]), 'agent2': array([1, 0]), 'agent3': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 3]), 'agent2': array([1, 0]), 'agent3': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([2, 0]), 'agent3': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 2]), 'agent2': array([1, 0]), 'agent3': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([0, 0]), 'agent3': array([2, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([1, 0]), 'agent3': array([3, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 4]), 'agent2': array([2, 0]), 'agent3': array([4, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([2, 0]), 'agent3': array([4, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 4]), 'agent2': array([2, 0]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 4]), 'agent2': array([2, 0]), 'agent3': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 4]), 'agent2': array([2, 0]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([0, 3]), 'agent2': array([3, 0]), 'agent3': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([3, 1]), 'agent3': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([4, 1]), 'agent3': array([1, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([4, 2]), 'agent3': array([0, 2])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 2]), 'agent2': array([4, 1]), 'agent3': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 2]), 'agent2': array([5, 1]), 'agent3': array([0, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([4, 1]), 'agent3': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 4]), 'agent2': array([5, 1]), 'agent3': array([0, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([6, 1]), 'agent3': array([1, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 3]), 'agent2': array([6, 2]), 'agent3': array([2, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 4]), 'agent2': array([6, 3]), 'agent3': array([1, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 4]), 'agent2': array([6, 4]), 'agent3': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 5]), 'agent2': array([6, 3]), 'agent3': array([2, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 4]), 'agent2': array([6, 4]), 'agent3': array([1, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 4]), 'agent2': array([6, 3]), 'agent3': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([1, 3]), 'agent2': array([6, 4]), 'agent3': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([7, 4]), 'agent3': array([0, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 2]), 'agent2': array([8, 4]), 'agent3': array([1, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([2, 3]), 'agent2': array([8, 3]), 'agent3': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 3]), 'agent2': array([8, 4]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 3]), 'agent2': array([7, 4]), 'agent3': array([4, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 3]), 'agent2': array([6, 4]), 'agent3': array([5, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 3]), 'agent2': array([6, 3]), 'agent3': array([4, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 3]), 'agent2': array([6, 2]), 'agent3': array([3, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 2]), 'agent2': array([6, 1]), 'agent3': array([2, 3])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 1]), 'agent2': array([6, 0]), 'agent3': array([2, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 2]), 'agent2': array([6, 1]), 'agent3': array([3, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 2]), 'agent2': array([6, 0]), 'agent3': array([3, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 1]), 'agent2': array([5, 0]), 'agent3': array([3, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 2]), 'agent2': array([6, 0]), 'agent3': array([4, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 2]), 'agent2': array([5, 0]), 'agent3': array([4, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 2]), 'agent2': array([6, 0]), 'agent3': array([3, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 1]), 'agent2': array([5, 0]), 'agent3': array([2, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 1]), 'agent2': array([4, 0]), 'agent3': array([3, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 2]), 'agent2': array([4, 0]), 'agent3': array([3, 4])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 1]), 'agent2': array([4, 0]), 'agent3': array([3, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 1]), 'agent2': array([3, 0]), 'agent3': array([4, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 1]), 'agent2': array([2, 0]), 'agent3': array([5, 5])}, Reward: 0, Done: False
# Obs: {'agent1': array([5, 0]), 'agent2': array([2, 0]), 'agent3': array([5, 6])}, Reward: 0, Done: False
# Obs: {'agent1': array([4, 0]), 'agent2': array([2, 0]), 'agent3': array([5, 7])}, Reward: 0, Done: False
# Obs: {'agent1': array([3, 0]), 'agent2': array([3, 0]), 'agent3': array([5, 8])}, Reward: 10, Done: True

# %%
env.close()

# %%
# Record video
env_rgb = gym.make('ThreeAgentGridworld-v0', render_mode='rgb_array')
env = gym.wrappers.RecordVideo(env=env_rgb, video_folder="/", name_prefix="test-video", episode_trigger=lambda x: x % 2 == 0)

obs, info = env.reset()
# env.render()

# Start the recorder
env.start_video_recorder()

done = False
while not done:
    pygame.event.get()
    action = env.action_space.sample()
    obs, reward, done, _,  info = env.step(action)
    env.render()
    print(f"Obs: {obs}, Reward: {reward}, Done: {done}")

# Don't forget to close the video recorder before the env!
env.close_video_recorder()

# Close the environment
env.close()
# Out:
# c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at c:\ folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       2 env_rgb = gym.make('ThreeAgentGridworld-v0', render_mode='rgb_array')
#       3 env = gym.wrappers.RecordVideo(env=env_rgb, video_folder="/", name_prefix="test-video", episode_trigger=lambda x: x % 2 == 0)
# ----> 5 obs, info = env.reset()
#       6 # env.render()
#       7
#       8 # Start the recorder
#       9 env.start_video_recorder()
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\wrappers\record_video.py:117, in RecordVideo.reset(self, **kwargs)
#     115 def reset(self, **kwargs):
#     116     """Reset the environment using kwargs and then starts recording if video enabled."""
# --> 117     observations = super().reset(**kwargs)
#     118     self.terminated = False
#     119     self.truncated = False
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\core.py:467, in Wrapper.reset(self, seed, options)
#     463 def reset(
#     464     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     465 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     466     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 467     return self.env.reset(seed=seed, options=options)
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\wrappers\time_limit.py:75, in TimeLimit.reset(self, **kwargs)
#      66 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#      67
#      68 Args:
#    (...)
#      72     The reset environment
#      73 """
#      74 self._elapsed_steps = 0
# ---> 75 return self.env.reset(**kwargs)
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:61, in OrderEnforcing.reset(self, **kwargs)
#      59 """Resets the environment with `kwargs`."""
#      60 self._has_reset = True
# ---> 61 return self.env.reset(**kwargs)
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\wrappers\env_checker.py:57, in PassiveEnvChecker.reset(self, **kwargs)
#      55 if not self.checked_reset:
#      56     self.checked_reset = True
# ---> 57     return env_reset_passive_checker(self.env, **kwargs)
#      58 else:
#      59     return self.env.reset(**kwargs)
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\gymnasium\utils\passive_env_checker.py:186, in env_reset_passive_checker(env, **kwargs)
#     181     logger.deprecation(
#     182         "Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information."
#     183     )
#     185 # Checks the result of env.reset with kwargs
# --> 186 result = env.reset(**kwargs)
#     188 if not isinstance(result, tuple):
#     189     logger.warn(
#     190         f"The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `{type(result)}`"
#     191     )
#
# TypeError: ThreeAgentGridworldEnv.reset() got an unexpected keyword argument 'options'
