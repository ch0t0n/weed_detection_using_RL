# %% [markdown]
# *************** This is the best working model so far ***********

# %% [markdown]
# # Muti-agent reinforcement learning for Precision Agriculture

# %%
# Import libraries
import matplotlib.pyplot as plt
from shapely import Polygon
from shapely.geometry import Point
from scipy.spatial import ConvexHull
import numpy as np
plt.rcParams["figure.figsize"] = (5,5)
np.random.seed(33)

# Take random x,y values
x = [int(np.random.random()*100/2) for i in range(5)]
y = [int(np.random.random()*100/2) for i in range(5)]
# Make polygon using the values
vertices = list(set(zip(x,y))) # Take unique x,y combinations
Poly1 = Polygon(vertices) # The first polygon (maybe non-convex)
print("Vertices:", vertices)
print("Vertices from polygon object:", Poly1.exterior.xy)
Poly1.exterior
# Out:
# Vertices: [(43, 24), (12, 9), (22, 0), (20, 47), (13, 34)]
# Vertices from polygon object: (array('d', [43.0, 12.0, 22.0, 20.0, 13.0, 43.0]), array('d', [24.0, 9.0, 0.0, 47.0, 34.0, 24.0]))
# <LINEARRING (43 24, 12 9, 22 0, 20 47, 13 34, 43 24)>

# %%
# Take the convex hull
hull = ConvexHull(vertices)
hull_points = [vertices[i] for i in hull.vertices]
inner_points = [point for i, point in enumerate(vertices) if i not in hull.vertices]
conv_vertices = hull_points + inner_points
Poly2 = Polygon(conv_vertices)
print('vertices of convex polygon:', conv_vertices)
print('vertices from convex polygon object:', Poly2.exterior.xy)
Poly2.exterior
# Out:
# vertices of convex polygon: [(43, 24), (20, 47), (13, 34), (12, 9), (22, 0)]
# vertices from convex polygon object: (array('d', [43.0, 20.0, 13.0, 12.0, 22.0, 43.0]), array('d', [24.0, 47.0, 34.0, 9.0, 0.0, 24.0]))
# <LINEARRING (43 24, 20 47, 13 34, 12 9, 22 0, 43 24)>

# %%
# Polygon exterior points
xp,yp = Poly2.exterior.xy

# Gridpoints
xs = np.arange(0, 90, 1)
ys = np.arange(0, 90, 1)

# Inside points
xps, yps = [], []
for xi in xs:
    for yi in ys:
        p = Point(xi,yi)
        if Poly2.contains(p):
            xps += [p.x]
            yps += [p.y]
xps += xp
yps += yp

plt.plot(xp,yp) # Plot the vertices
plt.scatter(xps,yps, color='r') # Plot the inside points

# Take buffer of distance 2 and plot it
buff = Poly2.buffer(distance=2)
print('Buffer vertices:', buff.exterior.xy)
x1,y1 = buff.exterior.xy
plt.plot(x1,y1, color='orange') # Plot the buffer

plt.show()
# Out:
# Buffer vertices: (array('d', [44.505153389413756, 23.505153389413756, 23.367541098854634, 23.216523275503103, 23.05358029489221, 22.880309430750476, 22.69840919747952, 22.509662700204384, 22.315920155610172, 22.119080754907316, 21.921074046716445, 21.723841022370106, 21.529315089045483, 21.339403117241996, 21.155966748388792, 20.980804145817153, 20.81563236798678, 20.6620705367551, 10.6620705367551, 10.52364307351378, 10.399253805864424, 10.290085510707032, 10.19717623368786, 10.121409418762571, 10.063505507816336, 10.024015090217361, 10.003313667442502, 10.001598082556422, 11.001598082556422, 11.017076756107226, 11.048890004907665, 11.096775763389614, 11.160339566700372, 11.23905780015565, 18.23905780015565, 18.34029684315675, 18.4574672493014, 18.589444308859253, 18.734961184170967, 18.892621069925575, 19.06091060098741, 19.23821437907181, 19.422830478829216, 19.612986784495877, 19.806858000296998, 20.00258317132068, 20.19828354668124, 20.392080613504636, 20.582114128629325, 20.766559974937493, 20.943647670915173, 21.111677365368347, 21.269036154164016, 21.414213562373096, 44.41421356237309, 44.54869094185812, 44.66760702815008, 44.769766948835034, 44.85414419795534, 44.91989095037243, 44.96634658073929, 44.99304430148389, 44.99971585310469, 44.98629419965022, 44.95291420229832, 44.89991126426698, 44.82781796067273, 44.73735868719978, 44.62944238135045, 44.505153389413756]), array('d', [22.682990784262962, -1.317009215737036, -1.4593941698333115, -1.587473187225283, -1.6999907535674543, -1.7958438980411897, -1.8740930053964797, -1.9339710266755228, -1.974890998328577, -1.9964517960147958, -1.9984420666855174, -1.9808423004051614, -1.943825021600385, -1.88775309786275, -1.8131761828831237, -1.7208253283864985, -1.6116058178845722, -1.4865882924943328, 7.513411707505667, 7.65078903591167, 7.800995570500063, 7.962603046415709, 8.134074790977817, 8.313780335398334, 8.500010918376876, 8.690995734153567, 8.884918770522365, 9.079936076697743, 34.07993607669774, 34.26079763961692, 34.43951084975321, 34.614603534954696, 34.78463334759098, 34.94819964607004, 47.94819964607004, 48.11596838269037, 48.273025024507454, 48.41786199687785, 48.54908902082672, 48.665446458228914, 48.76581740297863, 48.84923840208531, 48.91490870378498, 48.96219794389484, 48.99065219663073, 48.999998331805784, 48.99014663658624, 48.96119167663791, 48.913411388397726, 48.84726441118315, 48.76338568474863, 48.66258035454762, 48.54581604320327, 48.41421356237309, 25.414213562373096, 25.2655261224513, 25.10412263796394, 24.93162489598074, 24.749766159004626, 24.56037374909793, 24.36535068689534, 24.166656569995265, 23.96628788286419, 23.766257936100697, 23.568576636629945, 23.375230292098415, 23.188161652394896, 23.00925038884113, 22.840294207197804, 22.682990784262962]))

# %%
# Now print all points inside polygon
all_points = set(zip(xps,yps))
print("All points inside polygon:", all_points)
poly_vertices = conv_vertices # Taking all vertices of polygon
print("Polygon vertices for gymnasium test case:", poly_vertices)
# Out:
# All points inside polygon: {(15.0, 21.0), (26.0, 21.0), (38.0, 23.0), (18.0, 17.0), (15.0, 30.0), (26.0, 30.0), (18.0, 26.0), (26.0, 39.0), (18.0, 35.0), (27.0, 13.0), (29.0, 32.0), (19.0, 9.0), (19.0, 18.0), (21.0, 37.0), (30.0, 18.0), (41.0, 24.0), (33.0, 20.0), (33.0, 29.0), (25.0, 25.0), (25.0, 34.0), (22.0, 10.0), (22.0, 19.0), (34.0, 21.0), (14.0, 15.0), (22.0, 28.0), (34.0, 30.0), (14.0, 24.0), (37.0, 26.0), (22.0, 37.0), (14.0, 33.0), (15.0, 7.0), (26.0, 7.0), (15.0, 16.0), (26.0, 16.0), (18.0, 12.0), (15.0, 25.0), (26.0, 25.0), (18.0, 21.0), (18.0, 30.0), (27.0, 8.0), (29.0, 27.0), (19.0, 4.0), (29.0, 36.0), (30.0, 13.0), (21.0, 32.0), (21.0, 41.0), (33.0, 15.0), (25.0, 11.0), (33.0, 24.0), (25.0, 20.0), (33.0, 33.0), (25.0, 29.0), (22.0, 5.0), (25.0, 38.0), (22.0, 14.0), (34.0, 16.0), (14.0, 10.0), (22.0, 23.0), (34.0, 25.0), (14.0, 19.0), (37.0, 21.0), (22.0, 32.0), (14.0, 28.0), (15.0, 11.0), (26.0, 11.0), (18.0, 7.0), (26.0, 20.0), (17.0, 39.0), (18.0, 16.0), (29.0, 13.0), (29.0, 22.0), (40.0, 22.0), (21.0, 18.0), (29.0, 31.0), (21.0, 27.0), (21.0, 36.0), (21.0, 45.0), (41.0, 23.0), (25.0, 6.0), (33.0, 19.0), (25.0, 15.0), (33.0, 28.0), (25.0, 24.0), (22.0, 0.0), (25.0, 33.0), (22.0, 9.0), (22.0, 18.0), (14.0, 14.0), (22.0, 27.0), (14.0, 23.0), (14.0, 32.0), (36.0, 29.0), (26.0, 6.0), (17.0, 25.0), (28.0, 25.0), (17.0, 34.0), (28.0, 34.0), (18.0, 11.0), (29.0, 17.0), (21.0, 13.0), (29.0, 26.0), (40.0, 26.0), (21.0, 22.0), (29.0, 35.0), (21.0, 31.0), (21.0, 40.0), (33.0, 14.0), (25.0, 10.0), (33.0, 23.0), (25.0, 19.0), (25.0, 28.0), (22.0, 4.0), (22.0, 13.0), (13.0, 32.0), (24.0, 32.0), (14.0, 9.0), (24.0, 41.0), (14.0, 18.0), (16.0, 37.0), (36.0, 24.0), (17.0, 20.0), (28.0, 20.0), (17.0, 29.0), (28.0, 29.0), (17.0, 38.0), (28.0, 38.0), (29.0, 12.0), (21.0, 8.0), (29.0, 21.0), (40.0, 21.0), (21.0, 17.0), (29.0, 30.0), (21.0, 26.0), (21.0, 35.0), (20.0, 39.0), (25.0, 5.0), (33.0, 18.0), (25.0, 14.0), (32.0, 22.0), (32.0, 31.0), (22.0, 8.0), (13.0, 27.0), (24.0, 27.0), (35.0, 27.0), (24.0, 36.0), (16.0, 32.0), (17.0, 6.0), (36.0, 19.0), (17.0, 15.0), (28.0, 15.0), (36.0, 28.0), (17.0, 24.0), (28.0, 24.0), (17.0, 33.0), (28.0, 33.0), (21.0, 3.0), (29.0, 16.0), (21.0, 12.0), (29.0, 25.0), (40.0, 25.0), (21.0, 21.0), (21.0, 30.0), (20.0, 34.0), (31.0, 34.0), (20.0, 43.0), (25.0, 9.0), (23.0, 39.0), (32.0, 17.0), (13.0, 13.0), (24.0, 13.0), (32.0, 26.0), (13.0, 22.0), (24.0, 22.0), (35.0, 22.0), (16.0, 18.0), (13.0, 31.0), (24.0, 31.0), (35.0, 31.0), (16.0, 27.0), (24.0, 40.0), (16.0, 36.0), (17.0, 10.0), (28.0, 10.0), (36.0, 23.0), (17.0, 19.0), (28.0, 19.0), (17.0, 28.0), (28.0, 28.0), (17.0, 37.0), (28.0, 37.0), (29.0, 11.0), (21.0, 7.0), (21.0, 16.0), (39.0, 24.0), (20.0, 20.0), (20.0, 29.0), (31.0, 29.0), (23.0, 25.0), (20.0, 38.0), (23.0, 34.0), (20.0, 47.0), (32.0, 12.0), (23.0, 43.0), (24.0, 8.0), (32.0, 21.0), (13.0, 17.0), (24.0, 17.0), (32.0, 30.0), (16.0, 13.0), (35.0, 17.0), (13.0, 26.0), (24.0, 26.0), (35.0, 26.0), (16.0, 22.0), (24.0, 35.0), (16.0, 31.0), (17.0, 5.0), (36.0, 18.0), (17.0, 14.0), (28.0, 14.0), (17.0, 23.0), (28.0, 23.0), (21.0, 2.0), (27.0, 36.0), (19.0, 32.0), (19.0, 41.0), (20.0, 15.0), (31.0, 15.0), (20.0, 24.0), (31.0, 24.0), (23.0, 20.0), (20.0, 33.0), (31.0, 33.0), (23.0, 29.0), (20.0, 42.0), (23.0, 38.0), (24.0, 3.0), (32.0, 16.0), (13.0, 12.0), (24.0, 12.0), (32.0, 25.0), (16.0, 8.0), (13.0, 21.0), (24.0, 21.0), (35.0, 21.0), (16.0, 17.0), (13.0, 30.0), (24.0, 30.0), (35.0, 30.0), (16.0, 26.0), (16.0, 35.0), (17.0, 9.0), (28.0, 9.0), (28.0, 18.0), (27.0, 22.0), (27.0, 31.0), (19.0, 27.0), (30.0, 27.0), (19.0, 36.0), (30.0, 36.0), (19.0, 45.0), (20.0, 10.0), (39.0, 23.0), (23.0, 6.0), (20.0, 19.0), (31.0, 19.0), (23.0, 15.0), (20.0, 28.0), (31.0, 28.0), (23.0, 24.0), (20.0, 37.0), (23.0, 33.0), (23.0, 42.0), (24.0, 7.0), (32.0, 20.0), (13.0, 16.0), (24.0, 16.0), (35.0, 16.0), (16.0, 12.0), (24.0, 25.0), (35.0, 25.0), (16.0, 21.0), (16.0, 30.0), (38.0, 27.0), (15.0, 34.0), (26.0, 34.0 ...
# Polygon vertices for gymnasium test case: [(43, 24), (20, 47), (13, 34), (12, 9), (22, 0)]

# %% [markdown]
# Take a function for random starting points:

# %%
import random

# function for random starting points
def random_starting_locations(points, infected_locations):
    points = set([tuple(p) for p in points])
    st_locs = points.difference(infected_locations) # for points - infected_locations
    st_locs = random.choices(np.array(list(st_locs)),k=3)
    return st_locs

infected_locations = {(15,10), (22,13), (25,20), (26,21), (35,25)}
random_starting_locations(all_points, infected_locations)
# Out:
# [array([25.,  4.]), array([23., 41.]), array([17., 25.])]

# %%
test_dict = {1:'a', 2:'sd', 3:'sdd', 4:'q', 5:'w'}
list(test_dict.values())
# Out:
# ['a', 'sd', 'sdd', 'q', 'w']

# %% [markdown]
# Make the multi-agent class:

# %%
test_dict = {1:'a', 2:'sd', 3:'sdd', 4:'q', 5:'w'}

x = 2**(len(test_dict.values()))
print(x)
# Out:
# 32

# %%
binary = '11111'
x = int(binary, 2)
print(x)
# Out:
# 31

# %%
x = '0'*5
print(x)
# Out:
# 00000

# %%
def binary_list_to_decimal(bin_list):
    bin = ''
    for b in bin_list:
        bin += str(b)
    dec = int(bin,2)
    return dec

blist = [1,1,0,0,1]
x = binary_list_to_decimal(blist)
print(x)
# Out:
# 25

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pygame

class ThreeAgentGridworldEnv(gym.Env):
    metadata = {'render_modes': ['human', 'print', 'rgb_array'], "render_fps": 4}    
    def __init__(self, render_mode=None, grid_size=(50, 50), poly_vertices=poly_vertices):        
        super(ThreeAgentGridworldEnv, self).__init__()        
        self.Poly = Polygon(poly_vertices) # Get the points of the polygon
        self.poly_vertices = poly_vertices # Vertices of polygon
        self.size = grid_size[0]  # The size of the square grid
        self.window_size = 800  # The size of the PyGame window        
        self.grid_size = grid_size # Size of the grid (May need to remove later on)
        self.outer_boundary = self.Poly.buffer(distance=2) # outer boundary with buffer of distance 2

        # Observation points
        self.observation_points = self.obs_points()
        # print('Observation points:', self.observation_points)
        self.observation_length = len(self.observation_points)
        self.observation_map = {tuple(v):i for i,v in enumerate(self.observation_points)}
        # for p in self.observation_points:
        #     print('observation map:', p, self.observation_map[tuple(p)])

        # Keep track of visited states and count steps
        self.step_count = 0
        self.visited = set()
        self.infected_locations = {(15,10), (22,13), (25,20), (26,21), (35,25)}
        self.infected_length = 2**(len(self.infected_locations)) # 2**5, binary to decimal
        self.infected_dict = {v:0 for v in self.infected_locations} # dictionary of locations
        
        # Action and observation space
        self.action_space = spaces.MultiDiscrete([5, 5, 5])  # 4 possible actions for each of the two agents
        # self.observation_positions = spaces.MultiDiscrete([self.observation_length, self.observation_length, self.observation_length])
        # self.infected_space = spaces.MultiBinary(5)
        # self.observation_space = spaces.Tuple((self.observation_positions, self.infected_space))
        self.observation_space = spaces.MultiDiscrete([self.observation_length, self.observation_length, self.observation_length, self.infected_length])
        
        assert render_mode is None or render_mode in self.metadata["render_modes"] # Check if the render mode is correct
        self.render_mode = render_mode
        # If human-rendering is used, `self.window` will be a reference
        # to the window that we draw to. `self.clock` will be a clock that is used
        # to ensure that the environment is rendered at the correct framerate in
        # human-mode. They will remain `None` until human-mode is used for the
        # first time.
        self.window = None
        self.clock = None

        # Reset the environment and start
        self.reset()

    def obs_points(self):
        xp,yp = self.Poly.exterior.xy
        # Gridpoints
        xs = np.arange(0, 90, 1)
        ys = np.arange(0, 90, 1)
        # Inside points
        # print(xs,ys)
        xps, yps = [], []
        for xi in xs:
            for yi in ys:
                p = Point(xi,yi)
                if self.Poly.contains(p):
                    xps += [p.x]
                    yps += [p.y]
        xps += xp
        yps += yp
        # plt.plot(xp,yp)
        # plt.scatter(xps,yps, color='r')
        obs_points = np.array(list(set(zip(xps,yps)))) # Taking unique observation points
        return obs_points
    
    def _get_obs(self):
        a1, a2, a3 = self.agent_positions[0], self.agent_positions[1], self.agent_positions[2]
        info = {'agent1': a1, 'agent2': a2, 'agent3': a3, 'step_count': self.step_count}
        # print('agent positions:', a1, a2, a3)
        p1,p2,p3 = self.observation_map[tuple(a1)], self.observation_map[tuple(a2)], self.observation_map[tuple(a3)]
        infected = binary_list_to_decimal(list(self.infected_dict.values()))
        state = np.array([p1,p2,p3,infected]) # convert the infected binary list to decimal
        return state, info

    def reset(self, seed=None, options={}):
        self.visited = set()
        self.step_count = 0
        self.infected_locations = {(15,10), (22,13), (25,20), (26,21), (35,25)}
        self.infected_dict = {v:0 for v in self.infected_locations} # dictionary of locations
        self.agent_positions = [
            np.array([14, 34]),  # Agent 1 
            # np.array([self.grid_size[0]-1, self.grid_size[1]-1]),  # Agent 2 starts at bottom-right corner,
            # np.array([self.grid_size[0]-3, self.grid_size[1]-3])  # Agent 3 starts at specific position,
            np.array([80/2, 50/2]),  # Agent 2 
            np.array([40/2, 80/2]),  # Agent 3
        ]
        # self.agent_positions = random_starting_locations(self.observation_points, self.infected_locations)
        return self._get_obs()

    def step(self, action):
        # Placeholder for terminal state and rewards
        terminated, truncated = False, False
        rewards = 0
        self.step_count += 1

        # Define the movements corresponding to each action
        movements = [(-1, 0), (1, 0), (0, -1), (0, 1), (0, 0)]  # up, down, left, right, none
        
        # Update the positions of both agents
        for i, act in enumerate(action):
            # if act == 4: # If the action is none
            #     terminated = True # Terminated
            #     break

            movement = movements[act] # What movement to take
            new_position = self.agent_positions[i] + movement # New position after movement
            
            # Ensure the new position is within bounds
            # new_position = np.clip(new_position, [0, 0], [self.grid_size[0]-1, self.grid_size[1]-1])
            new_p = Point(new_position[0], new_position[1])
            # print("checking new position", tuple(new_position))
            if self.Poly.contains(new_p):
                self.agent_positions[i] = new_position
            else:
                rewards -= 10
            if tuple(new_position) in self.visited:
                rewards -= 10
            else:
                rewards -= 1
            self.visited.add(tuple(new_position))
        
        # Check if an infected location is visited
        infected_visited = [x for x in self.agent_positions if tuple(x) in self.infected_locations] # If infected cells are visited
        for v in infected_visited:
            if tuple(v) in self.infected_locations:
                self.infected_locations.remove(tuple(v))
                self.infected_dict[tuple(v)] = 1
        
        if infected_visited:
            rewards += 100 * len(infected_visited) 

        if sum(list(self.infected_dict.values()))==5:
            rewards += 100000
            terminated = True

        
        # If the agents meet at the same position, we can assign a reward or consider it a terminal state
        if np.array_equal(self.agent_positions[0], self.agent_positions[1]) or np.array_equal(self.agent_positions[0], self.agent_positions[2]) or np.array_equal(self.agent_positions[1], self.agent_positions[2]):
            rewards -= 100000  # Infinity reward for meeting at the same position
            terminated = True
        
        obs, info = self._get_obs()
        # rewards = rewards * self.gamma ** self.step_count
        return obs, rewards, terminated, truncated, info

    def render(self):
        if self.render_mode == 'print':
            grid = np.zeros(self.grid_size)
            grid[tuple(self.agent_positions[0])] = 1  # Mark the position of the first agent
            grid[tuple(self.agent_positions[1])] = 2  # Mark the position of the second agent
            print(grid)
        else:
            if self.window is None and self.render_mode == "human": # Initialize pygame if it is not initialized
                pygame.init()
                pygame.display.init()
                self.window = pygame.display.set_mode(
                    (self.window_size, self.window_size)
                )
            if self.clock is None and self.render_mode == "human":
                self.clock = pygame.time.Clock()
            
            # Fill the canvas
            canvas = pygame.Surface((self.window_size, self.window_size))
            canvas.fill((255, 255, 255))
            pix_square_size = (
                self.window_size / self.size
            )  # The size of a single grid square in pixels

            # Draw the polygon
            pixel_poly_vertices = [(point[0] * pix_square_size, point[1] * pix_square_size) for point in self.poly_vertices]
            pygame.draw.polygon(surface=canvas, 
                                color=(255, 255, 0), 
                                points=pixel_poly_vertices)
            
            # Draw the visited regions
            for p in self.visited:
                pygame.draw.rect(
                canvas,
                pygame.Color(100, 100, 100, a=0.5),
                pygame.Rect(
                    pix_square_size * np.array(p),
                    (pix_square_size, pix_square_size),
                ),
                )
            # Draw agent1 (square)
            pygame.draw.rect(
                canvas,
                (255, 0, 0),
                pygame.Rect(
                    pix_square_size * self.agent_positions[0],
                    (pix_square_size, pix_square_size),
                ),
            )
            # Draw agent2 (circle)
            pygame.draw.circle(
                canvas,
                (0, 0, 255),
                (self.agent_positions[1] + 0.5) * pix_square_size,
                pix_square_size / 3,
            )
            # Draw agent3 (circle)
            pygame.draw.circle(
                canvas,
                (0, 255, 0),
                (self.agent_positions[2] + 0.5) * pix_square_size,
                pix_square_size / 3,
            )
            # Draw infected locations
            for l in self.infected_locations:
                pygame.draw.rect(
                    canvas,
                    (0, 255, 255),
                    pygame.Rect(
                        pix_square_size * np.array(l),
                        (pix_square_size, pix_square_size),
                    ),
                )


            if self.render_mode == "human":
                # The following line copies our drawings from `canvas` to the visible window
                self.window.blit(canvas, canvas.get_rect())
                pygame.event.pump()
                pygame.display.update()

                # We need to ensure that human-rendering occurs at the predefined framerate.
                # The following line will automatically add a delay to keep the framerate stable.
                self.clock.tick(self.metadata["render_fps"])
                # Finally
                pygame.event.get()

            elif self.render_mode == 'rgb_array':  # rgb_array
                return np.transpose(
                    np.array(pygame.surfarray.pixels3d(canvas)), axes=(1, 0, 2)
                )
            
    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()

# %% [markdown]
# Register, create the environment and random play:

# %%
# Register the environment
gym.envs.registration.register(
    id='ThreeAgentGridworld-v0',
    entry_point=ThreeAgentGridworldEnv,
    max_episode_steps=2000,
)

# Example of creating and using the environment
env = gym.make('ThreeAgentGridworld-v0',poly_vertices=poly_vertices, render_mode='human')
env.metadata['render_fps'] = 30
obs, info = env.reset()
env.render()

# %%
# Random play
terminated, truncated = False, False
total_rewards = 0
while True:
    act_str = input("Enter 3 actions by comma:")
    action = eval(act_str)
    obs, reward, terminated, truncated,  info = env.step(action)
    env.render()
    total_rewards += reward
    print(f"Obs: {obs}, Reward: {reward}, terminated: {terminated}, total_rewards: {total_rewards}, action: {action}")
    if terminated or truncated:
        print('terminated:', terminated, 'truncated:', truncated)
        break
    pygame.event.get()
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[13], line 6
#     action = eval(act_str)
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %%
# Random play
env.reset()
terminated, truncated = False, False
total_rewards = 0
while True:
    action = env.action_space.sample()
    print(action)
    obs, reward, terminated, truncated,  info = env.step(action)
    env.render()
    total_rewards += reward
    print(f"Obs: {obs}, Reward: {reward}, terminated: {terminated}, total_rewards: {total_rewards}")
    if terminated or truncated:
        print('terminated:', terminated, 'truncated:', truncated)
        break
    pygame.event.get()
# Out:
# [0 2 0]
# Obs: [775 495 296   0], Reward: -13, terminated: False, total_rewards: -13
# [0 1 3]
# Obs: [775  15 225   0], Reward: -22, terminated: False, total_rewards: -35
# [4 3 4]
# Obs: [775 500 225   0], Reward: -12, terminated: False, total_rewards: -47
# [3 4 1]
# Obs: [455 500 558   0], Reward: -12, terminated: False, total_rewards: -59
# [2 2 1]
# Obs: [775  15  45   0], Reward: -21, terminated: False, total_rewards: -80
# [1 1 4]
# Obs: [284 293  45   0], Reward: -12, terminated: False, total_rewards: -92
# [2 3 3]
# Obs: [352 293 530   0], Reward: -13, terminated: False, total_rewards: -105
# [4 0 4]
# Obs: [352  15 530   0], Reward: -30, terminated: False, total_rewards: -135
# [1 3 3]
# Obs: [644 500 468   0], Reward: -12, terminated: False, total_rewards: -147
# [3 1 0]
# Obs: [574 500 164   0], Reward: -22, terminated: False, total_rewards: -169
# [2 2 3]
# Obs: [644  15 667   0], Reward: -21, terminated: False, total_rewards: -190
# [1 4 3]
# Obs: [153  15 594   0], Reward: -12, terminated: False, total_rewards: -202
# [2 1 2]
# Obs: [486 293 667   0], Reward: -21, terminated: False, total_rewards: -223
# [2 0 3]
# Obs: [548  15 594   0], Reward: -21, terminated: False, total_rewards: -244
# [4 4 3]
# Obs: [548  15 532   0], Reward: -21, terminated: False, total_rewards: -265
# [2 0 4]
# Obs: [616 495 532   0], Reward: -21, terminated: False, total_rewards: -286
# [0 4 4]
# Obs: [282 495 532   0], Reward: -21, terminated: False, total_rewards: -307
# [2 2 2]
# Obs: [608 555 594   0], Reward: -12, terminated: False, total_rewards: -319
# [0 4 1]
# Obs: [316 555  76   0], Reward: -12, terminated: False, total_rewards: -331
# [4 4 0]
# Obs: [316 555 594   0], Reward: -30, terminated: False, total_rewards: -361
# [1 0 1]
# Obs: [608 262  76   0], Reward: -21, terminated: False, total_rewards: -382
# [3 1 1]
# Obs: [282 555  76   0], Reward: -31, terminated: False, total_rewards: -413
# [1 4 4]
# Obs: [616 555  76   0], Reward: -30, terminated: False, total_rewards: -443
# [3 4 4]
# Obs: [548 555  76   0], Reward: -30, terminated: False, total_rewards: -473
# [3 0 2]
# Obs: [486 262 403   0], Reward: -21, terminated: False, total_rewards: -494
# [4 2 2]
# Obs: [486 335 468   0], Reward: -21, terminated: False, total_rewards: -515
# [0 1 3]
# Obs: [145  71 403   0], Reward: -12, terminated: False, total_rewards: -527
# [2 3 3]
# Obs: [215 555  76   0], Reward: -21, terminated: False, total_rewards: -548
# [4 4 1]
# Obs: [215 555  76   0], Reward: -40, terminated: False, total_rewards: -588
# [3 3 3]
# Obs: [145 495  76   0], Reward: -31, terminated: False, total_rewards: -619
# [2 2 1]
# Obs: [215 555  76   0], Reward: -40, terminated: False, total_rewards: -659
# [1 3 1]
# Obs: [548 495  76   0], Reward: -40, terminated: False, total_rewards: -699
# [4 4 4]
# Obs: [548 495  76   0], Reward: -30, terminated: False, total_rewards: -729
# [4 0 3]
# Obs: [548 193  76   0], Reward: -31, terminated: False, total_rewards: -760
# [2 0 2]
# Obs: [616 747 403   0], Reward: -21, terminated: False, total_rewards: -781
# [4 4 3]
# Obs: [616 747  76   0], Reward: -30, terminated: False, total_rewards: -811
# [2 1 0]
# Obs: [122 193 594   0], Reward: -21, terminated: False, total_rewards: -832
# [3 2 0]
# Obs: [616 262 260   0], Reward: -21, terminated: False, total_rewards: -853
# [1 3 1]
# Obs: [ 38 193 594   0], Reward: -21, terminated: False, total_rewards: -874
# [2 4 4]
# Obs: [354 193 594   0], Reward: -21, terminated: False, total_rewards: -895
# [0 3 0]
# Obs: [122 694 260   0], Reward: -21, terminated: False, total_rewards: -916
# [1 0 0]
# Obs: [354 680 260   0], Reward: -22, terminated: False, total_rewards: -938
# [2 1 0]
# Obs: [430 694 260   0], Reward: -31, terminated: False, total_rewards: -969
# [3 4 1]
# Obs: [354 694 594   0], Reward: -30, terminated: False, total_rewards: -999
# [4 4 2]
# Obs: [354 694 667   0], Reward: -30, terminated: False, total_rewards: -1029
# [2 1 0]
# Obs: [430 159 333   0], Reward: -12, terminated: False, total_rewards: -1041
# [4 4 1]
# Obs: [430 159 667   0], Reward: -30, terminated: False, total_rewards: -1071
# [3 3 3]
# Obs: [354 101 594   0], Reward: -21, terminated: False, total_rewards: -1092
# [1 4 1]
# Obs: [688 101  76   0], Reward: -21, terminated: False, total_rewards: -1113
# [1 4 2]
# Obs: [195 101 403   0], Reward: -21, terminated: False, total_rewards: -1134
# [3 4 3]
# Obs: [699 101  76   0], Reward: -21, terminated: False, total_rewards: -1155
# [0 1 4]
# Obs: [365 101  76   0], Reward: -22, terminated: False, total_rewards: -1177
# [3 1 2]
# Obs: [294 101 403   0], Reward: -31, terminated: False, total_rewards: -1208
# [3 1 1]
# Obs: [224 101 420   0], Reward: -22, terminated: False, total_rewards: -1230
# [0 2 4]
# Obs: [717 159 420   0], Reward: -21, terminated: False, total_rewards: -1251
# [0 3 2]
# Obs: [486 101 744   0], Reward: -21, terminated: False, total_rewards: -1272
# [1 3 4]
# Obs: [717 101 744   0], Reward: -31, terminated: False, total_rewards: -1303
# [1 1 0]
# Obs: [224 101 468   0], Reward: -40, terminated: False, total_rewards: -1343
# [1 2 0]
# Obs: [305 159 164   0], Reward: -21, terminated: False, total_rewards: -1364
# [2 2 0]
# Obs: [624 495 655   0], Reward: -12, terminated: False, total_rewards: -1376
# [2 0 4]
# Obs: [699 193 655   0], Reward: -30, terminated: False, total_rewards: -1406
# [4 4 3]
# Obs: [699 193 333   0], Reward: -30, terminated: False, total_rewards: -1436
# [0 3 3]
# Obs: [365 694 260   0], Reward: -30, terminated: False, total_rewards: -1466
# [2 4 1]
# Obs: [688 694 594   0], Reward: -30, terminated: False, total_rewards: -1496
# [1 3 2]
# Obs: [195 621 667   0], Reward: -21, terminated: False, total_rewards: -1517
# [3 3 3]
# Obs: [699 300 594   0], Reward: -21, terminated: False, total_rewards: -1538
# [3 3 1]
# Obs: [624 300  76   0], Reward: -31, terminated: False, total_rewards: -1569
# [4 2 1]
# Obs: [624 621  76   0], Reward: -40, terminated: False, total_rewards: -1609
# [1 3 0]
# Obs: [104 300 594   0], Reward: -21, terminated: False, total_rewards: -1630
# [0 1 4]
# Obs: [624 300 594   0], Reward: -40, terminated: False, total_rewards: -1670
# [1 2 0]
# Obs: [104 621 260   0], Reward: -30, terminated: False, total_rewards: -1700
# [3 1 0]
# Obs: [ 44 101 260   0], Reward: -31, terminated: False, total_rewards: -1731
# [2 0 2]
# Obs: [104 621 333   0], Reward: -30, terminated: False, total_rewards: -1761
# [3 0 4]
# Obs: [ 44 350 333   0], Reward: -21, terminated: False, total_rewards: -1782
# [2 3 4]
# Obs: [104 283 333   0], Reward: -21, terminated: False, total_rewards: -1803
# [2 1 4]
# Obs: [161 300 333   0], Reward: -21, terminated: False, total_rewards: -1824
# [0 2 4]
# Obs: [699 621 333   0], Reward: -30, terminated: False, total_rewards: -1854
# [2 4 4]
# Obs: [195 621 333   0], Reward: -30, terminated: False, total_rewards: -1884
# [4 3 3]
# Obs: [195 300 260   0], Reward: -30, terminated: False, total_rewards: -1914
# [4 0 2]
# Obs: [195 283 333   0], Reward: -30, terminated: False, total_rewards: -1944
# [3 1 1]
# Obs: [699 300 667   0], Reward: -30, terminated: False, total_rewards: -1974
# [2 4 2]
# Obs: [195 300 164   0], Reward: -30, terminated: False, total_rewards: -2004
# [2 4 2]
# Obs: [267 300 234   0], Reward: -12, terminated: False, total_rewards: -2016
# [0 3 3]
# Obs: [760 300 164   0], Reward: -31, terminated: False, total_rewards: -2047
# [3 4 4]
# Obs: [688 300 164   0], Reward: -30, terminated: False, total_rewards: -2077
# [3 0 1]
# Obs: [365 283 468   0], Reward: -30, terminated: False, total_rewards: -2107
# [3 2 1]
# Obs: [294 350 744   0], Reward: -30, terminated: False, total_rewards: -2137
# [3 0 2]
# Obs: [224  27 813   0], Reward: -12, terminated: False, total_rewards: -2149
# [4 1 3]
# Obs: [224 350 744   0], Reward: -30, terminated: False, total_rewards: -2179
# [4 2 3]
# Obs: [224 680 420   0], Reward: -30, terminated: False, total_rewards: -2209
# [0 4 1]
# Obs: [717 680 420   0], Reward: -31, terminated: False, total_rewards: -2240
# [1 2 0]
# Obs: [224 747 403   0], Reward: -30, terminated: False, total_rewards: -2270
# [3 0 3]
# Obs: [727 417  76   0], Reward: -12, terminated: False, total_rewards: -2282
# [3 2 0]
# Obs: [653 482 594   0], Reward: -12, terminated: False, total_rewards: -2294
# [1 2 0]
# Obs: [162 810 260   0], Reward: -12, terminated: False, total_rewards: -2306
# [1 4 3]
# Obs: [467 810 260   0], Reward: -22, terminated: False, total_rewards: -2328
# [3 3 0]
# Obs: [133 482 260   0], Reward: -31, terminated: False, total_rewards: -2359
# [0 4 3]
# Obs: [664 482 260   0], Reward: -31, terminated: False, total_rewards: -2390
# [1 2 4]
# Obs: [133 810 260   0], Reward: -30, terminated: False, total_rewards: -2420
# [3 3 3]
# Obs: [ 75 482 260   0], Reward: -31, terminated: False, total_rewards: -2451
# [0 2 0]
# Obs: [592 810 260   0], Reward: -31, terminated: False, total_rewards: -2482
# [1 4 1]
# Obs: [ 75 810 594   0], Reward: -30, terminated: False, total_rewards: -2512
# [2 2 0]
# Obs: [133  60 260   0], Reward: -21, terminated: False, total_rewards: -2533
# [0 0 0]
# Obs: [664 577 260   0], Reward: -31, terminated: False, total_rewards: -2564
# [4 2 0]
# Obs: [664 647 260   0], Reward: -31, terminated: False, total_rewards: -2595
# [3 1 1]
# Obs: [592 378 594   0], Reward: -21, terminated: False, total_rewards: -2616
# [1 4 3]
# Obs: [ 75 378 532   0], Reward: -30, terminated: False, total_rewards: -2646
# [2 3 4]
# Obs: [133  60 532   0], Reward: -30, terminated: False, total_rewards: -2676
# [4 0 3]
# Obs: [133 577 532   0], Reward: -31, terminated: False, total_rewards: -2707
# [3 4 1]
# Obs: [ 75 577 532   0], Reward: -40, terminated: False, total_rewards: -2747
# [0 3 0]
# Obs: [592 514 532   0], Reward: -31, terminated: False, total_rewards: -2778
# [2 0 1]
# Obs: [664 173 532   0], Reward: -31, terminated: False, total_rewards: -2809
# [3 4 2]
# Obs: [592 173 594   0], Reward: -30, terminated: False, total_rewards: -2839
# [2 3 1]
# Obs: [664 677  76   0], Reward: -21, terminated: False, total_rewards: -2860
# [2 4 0]
# Obs: [162 677 594   0], Reward: -30, terminated: False, total_rewards: -2890
# [0 0 2]
# Obs: [653 448 667   0], Reward: -21, terminated: False, total_rewards: -2911
# [3 4 3]
# Obs: [331 448 594   0], Reward: -21, terminated: False, total_rewards: -2932
# [2 4 3]
# Obs: [653 448 532   0], Reward: -30, terminated: False, total_rewards: -2962
# [4 1 2]
# Obs: [653 677 594   0], Reward: -30, terminated: False, total_rewards: -2992
# [2 1 3]
# Obs: [727 183 532   0], Reward: -21, terminated: False, total_rewards: -3013
# [3 4 4]
# Obs: [653 183 532   0], Reward: -30, terminated: False, total_rewards: -3043
# [4 0 1]
# Obs: [653 677 532   0], Reward: -40, terminated: False, total_rewards: -3083
# [0 1 4]
# Obs: [320 183 532   0], Reward: -21, terminated: False, total_rewards: -3104
# [2 0 2]
# Obs: [395 677 594   0], Reward: -21, terminated: False, total_rewards: -3125
# [4 2 0]
# Obs: [395 173 260   0], Reward: -30, terminated: False, total_rewards: -3155
# [2 4 4]
# Obs: [717 173 260   0], Reward: -30, terminated: False, total_rewards: -3185
# [0 1 4]
# Obs: [486 514 260   0], Reward: -30, terminated: False, total_rewards: -3215
# [1 0 2]
# Obs: [717 173 333   0], Reward: -30, terminated: False, total_rewards: -3245
# [3 2 0]
# Obs: [395 244 333   0], Reward: -22, terminated: False, total_rewards: -3267
# [3 1 4]
# Obs: [320 577 333   0], Reward: -30, terminated: False, total_rewards: -3297
# [4 3 4]
# Obs: [320 514 333   0], Reward: -30, terminated: False, total_rewards: -3327
# [3 3 4]
# Obs: [  8 183 333   0], Reward: -21, terminated: False, total_rewards: -3348
# [4 2 3]
# Obs: [  8 514 260   0], Reward: -30, terminated: False, total_rewards: -3378
# [0 4 1]
# Obs: [583 514 594   0], Reward: -21, terminated: False, total_rewards: -3399
# [1 0 2]
# Obs: [  8 173 667   0], Reward: -30, terminated: False, total_rewards: -3429
# [4 4 0]
# Obs: [  8 173 333   0], Reward: -30, terminated: False, total_rewards: -3459
# [4 3 3]
# Obs: [  8 677 260   0], Reward: -30, terminated: False, total_rewards: -3489
# [0 1 1]
# Obs: [583 183 594   0], Reward: -30, terminated: False, total_rewards: -3519
# [3 1 1]
# Obs: [519 482  76   0], Reward: -21, terminated: False, total_rewards: -3540
# [2 4 3]
# Obs: [583 482  76   0], Reward: -40, terminated: False, total_rewards: -3580
# [4 4 3]
# Obs: [583 482  76   0], Reward: -40, terminated: False, total_rewards: -3620
# [0 3 1]
# Obs: [250 417  76   0], Reward: -31, terminated: False, total_rewards: -3651
# [3 0 3]
# Obs: [180 119  76   0], Reward: -22, terminated: False, total_rewards: -3673
# [1 3 4]
# Obs: [519 613  76   0], Reward: -21, terminated: False, total_rewards: -3694
# [2 1 0]
# Obs: [583 344 594   0], Reward: -21, terminated: False, total_rewards: -3715
# [2 1 2]
# Obs: [ 95 680 667   0], Reward: -21, terminated: False, total_rewards: -3736
# [0 4 3]
# Obs: [574 680 594   0], Reward: -30, terminated: False, total_rewards: -3766
# [0 4 3]
# Obs: [284 680 532   0], Reward: -30, terminated: False, total_rewards: -3796
# [3 0 3]
# Obs: [786 344 532   0], Reward: -31, terminated: False, total_rewards: -3827
# [2 1 2]
# Obs: [284 680 594   0], Reward: -30, terminated: False, total_rewards: -3857
# [3 0 0]
# Obs: [786 344 260   0], Reward: -30, terminated: False, total_rewards: -3887
# [0 4 0]
# Obs: [455 344 260   0], Reward: -40, terminated: False, total_rewards: -3927
# [3 4 4]
# Obs: [455 344 260   0], Reward: -31, terminated: False, total_rewards: -3958
# [4 3 2]
# Obs: [455  27 333   0], Reward: -30, terminated: False, total_rewards: -3988
# [3 4 3]
# Obs: [455  27 260   0], Reward: -40, terminated: False, total_rewards: -4028
# [2 3 2]
# Obs: [775 773 333   0], Reward: -21, terminated: False, total_rewards: -4049
# [1 0 0]
# Obs: [284 484 333   0], Reward: -31, terminated: False, total_rewards: -4080
# [3 1 3]
# Obs: [786 773 260   0], Reward: -30, terminated: False, total_rewards: -4110
# [0 3 3]
# Obs: [455 453 260   0], Reward: -31, terminated: False, total_rewards: -4141
# [4 3 1]
# Obs: [455 381 594   0], Reward: -21, terminated: False, total_rewards: -4162
# [1 2 1]
# Obs: [786 453  76   0], Reward: -30, terminated: False, total_rewards: -4192
# [1 4 4]
# Obs: [250 453  76   0], Reward: -30, terminated: False, total_rewards: -4222
# [0 0 2]
# Obs: [786 150 403   0], Reward: -21, terminated: False, total_rewards: -4243
# [3 4 4]
# Obs: [715 150 403   0], Reward: -21, terminated: False, total_rewards: -4264
# [4 2 2]
# Obs: [715 484 468   0], Reward: -30, terminated: False, total_rewards: -4294
# [1 0 4]
# Obs: [180 143 468   0], Reward: -21, terminated: False, total_rewards: -4315
# [3 1 0]
# Obs: [118 484 164   0], Reward: -21, terminated: False, total_rewards: -4336
# [1 4 0]
# Obs: [188 484 655   0], Reward: -21, terminated: False, total_rewards: -4357
# [4 0 2]
# Obs: [188 143 729   0], Reward: -21, terminated: False, total_rewards: -4378
# [3 1 1]
# Obs: [124 484 234   0], Reward: -21, terminated: False, total_rewards: -4399
# [4 1 1]
# Obs: [124 773 530   0], Reward: -30, terminated: False, total_rewards: -4429
# [3 0 4]
# Obs: [ 67 484 530   0], Reward: -21, terminated: False, total_rewards: -4450
# [2 4 3]
# Obs: [124 484 468   0], Reward: -30, terminated: False, total_rewards: -4480
# [2 4 3]
# Obs: [188 484 403   0], Reward: -30, terminated: False, total_rewards: -4510
# [0 3 4]
# Obs: [118 150 403   0], Reward: -30, terminated: False, total_rewards: -4540
# [2 0 4]
# Obs: [180 641 403   0], Reward: -21, terminated: False, total_rewards: -4561
# [3 4 0]
# Obs: [118 641 667   0], Reward: -30, terminated: False, total_rewards: -4591
# [2 1 4]
# Obs: [180 150 667   0], Reward: -30, terminated: False, total_rewards: -4621
# [2 4 4]
# Obs: [250 150 667   0], Reward: -30, terminated: False, total_rewards: -4651
# [2 2 0]
# Obs: [574 484 333   0], Reward: -30, terminated: False, total_rewards: -4681
# [1 2 4]
# Obs: [ 95 545 333   0], Reward: -21, terminated: False, total_rewards: -4702
# [2 4 3]
# Obs: [153 545 260   0], Reward: -30, terminated: False, total_rewards: -4732
# [2 1 0]
# Obs: [486  27 260   0], Reward: -40, terminated: False, total_rewards: -4772
# [4 4 0]
# Obs: [486  27 260   0], Reward: -40, terminated: False, total_rewards: -4812
# [0 3 0]
# Obs: [145 773 260   0], Reward: -40, terminated: False, total_rewards: -4852
# [4 3 3]
# Obs: [145 453 260   0], Reward: -40, terminated: False, total_rewards: -4892
# [4 1 2]
# Obs: [145 784 333   0], Reward: -21, terminated: False, total_rewards: -4913
# [4 4 0]
# Obs: [145 784 333   0], Reward: -40, terminated: False, total_rewards: -4953
# [2 0 4]
# Obs: [215 453 333   0], Reward: -30, terminated: False, total_rewards: -4983
# [2 2 0]
# Obs: [282 773 333   0], Reward: -40, terminated: False, total_rewards: -5023
# [0 2 3]
# Obs: [  4  27 260   0], Reward: -21, terminated: False, total_rewards: -5044
# [1 2 4]
# Obs: [282 344 260   0], Reward: -30, terminated: False, total_rewards: -5074
# [1 2 0]
# Obs: [616 417 260   0], Reward: -40, terminated: False, total_rewards: -5114
# [2 1 0]
# Obs: [122 747 260   0], Reward: -40, terminated: False, total_rewards: -5154
# [1 3 4]
# Obs: [354 680 260   0], Reward: -30, terminated: False, total_rewards: -5184
# [2 0 2]
# Obs: [430 344 333   0], Reward: -30, terminated: False, total_rewards: -5214
# [0 4 0]
# Obs: [186 344 333   0], Reward: -31, terminated: False, total_rewards: -5245
# [4 0 4]
# Obs: [186 613 333   0], Reward: -30, terminated: False, total_rewards: -5275
# [1 0 3]
# Obs: [430 280 260   2], Reward: 79, terminated: False, total_rewards: -5196
# [0 4 2]
# Obs: [186 280 333   2], Reward: -30, terminated: False, total_rewards: -5226
# [4 2 3]
# Obs: [186 604 260   2], Reward: -21, terminated: False, total_rewards: -5247
# [2 2 0]
# Obs: [516 677 260   2], Reward: -31, terminated: False, total_rewards: -5278
# [3 0 4]
# Obs: [186 448 260   2], Reward: -30, terminated: False, total_rewards: -5308
# [0 3 1]
# Obs: [679 377 594   2], Reward: -12, terminated: False, total_rewards: -5320
# [2 3 3]
# Obs: [178  58 532   2], Reward: -12, terminated: False, total_rewards: -5332
# [3 2 2]
# Obs: [679 377 594   2], Reward: -30, terminated: False, total_rewards: -5362
# [2 3 4]
# Obs: [178  58 594   2], Reward: -30, terminated: False, total_rewards: -5392
# [0 3 4]
# Obs: [713 808 594   2], Reward: -12, terminated: False, total_rewards: -5404
# [3 0 2]
# Obs: [390 472 667   2], Reward: -12, terminated: False, total_rewards: -5416
# [4 3 4]
# Obs: [390 406 667   2], Reward: -21, terminated: False, total_rewards: -5437
# [1 0 1]
# Obs: [679 673 403   2], Reward: -21, terminated: False, total_rewards: -5458
# [0 4 0]
# Obs: [390 673 667   2], Reward: -30, terminated: False, total_rewards: -5488
# [2 4 1]
# Obs: [713 673 403   2], Reward: -30, terminated: False, total_rewards: -5518
# [3 2 2]
# Obs: [390 170 468   2], Reward: -21, terminated: False, total_rewards: -5539
# [4 2 0]
# Obs: [390 240 164   2], Reward: -21, terminated: False, total_rewards: -5560
# [2 3 2]
# Obs: [713 170 234   2], Reward: -30, terminated: False, total_rewards: -5590
# [2 0 2]
# Obs: [782 662 558   2], Reward: -12, terminated: False, total_rewards: -5602
# [0 0 3]
# Obs: [452 329 234   2], Reward: -12, terminated: False, total_rewards: -5614
# [1 0 3]
# Obs: [782 100 164   2], Reward: -21, terminated: False, total_rewards: -5635
# [1 3 2]
# Obs: [249  40 234   2], Reward: -12, terminated: False, total_rewards: -5647
# [3 3 2]
# Obs: [178 526 558   2], Reward: -21, terminated: False, total_rewards: -5668
# [0 1 1]
# Obs: [713 761  45   2], Reward: -21, terminated: False, total_rewards: -5689
# [1 0 4]
# Obs: [178 526  45   2], Reward: -30, terminated: False, total_rewards: -5719
# [0 4 4]
# Obs: [713 526  45   2], Reward: -30, terminated: False, total_rewards: -5749
# [4 2 2]
# Obs: [713  40 105   2], Reward: -21, terminated: False, total_rewards: -5770
# [1 2 1]
# Obs: [178 100 382   2], Reward: -21, terminated: False, total_rewards: -5791
# [1 4 1]
# Obs: [516 100 668   2], Reward: -21, terminated: False, total_rewards: -5812
# [1 3 0]
# Obs: [750  40 382   2], Reward: -21, terminated: False, total_rewards: -5833
# [4 4 1]
# Obs: [750  40 668   2], Reward: -30, terminated: False, total_rewards: -5863
# [4 4 2]
# Obs: [750  40 166   2], Reward: -21, terminated: False, total_rewards: -5884
# [1 3 4]
# Obs: [256 526 166   2], Reward: -21, terminated: False, total_rewards: -5905
# [1 0 3]
# Obs: [590 187 668   2], Reward: -12, terminated: False, total_rewards: -5917
# [1 3 2]
# Obs: [ 74 123 166   2], Reward: -12, terminated: False, total_rewards: -5929
# [2 4 4]
# Obs: [132 123 166   2], Reward: -21, terminated: False, total_rewards: -5950
# [3 0 4]
# Obs: [ 74 650 166   2], Reward: -21, terminated: False, total_rewards: -5971
# [4 4 3]
# Obs: [ 74 650 668   2], Reward: -30, terminated: False, total_rewards: -6001
# [3 2 4]
# Obs: [557 723 668   2], Reward: -12, terminated: False, total_rewards: -6013
# [2 1 1]
# Obs: [ 74 187 179   2], Reward: -21, terminated: False, total_rewards: -6034
# [4 0 0]
# Obs: [ 74 723 668   2], Reward: -30, terminated: False, total_rewards: -6064
# [2 2 0]
# Obs: [132 795 382   2], Reward: -21, terminated: False, total_rewards: -6085
# [0 1 0]
# Obs: [661 517 105   2], Reward: -12, terminated: False, total_rewards: -6097
# [1 2 0]
# Obs: [132 582 627   2], Reward: -12, terminated: False, total_rewards: -6109
# [4 0 2]
# Obs: [132 289 134   2], Reward: -12, terminated: False, total_rewards: -6121
# [2 2 3]
# Obs: [466 361 627   2], Reward: -12, terminated: False, total_rewards: -6133
# [0 1 3]
# Obs: [736  94 558   2], Reward: -12, terminated: False, total_rewards: -6145
# [1 2 4]
# Obs: [466 152 558   2], Reward: -21, terminated: False, total_rewards: -6166
# [0 2 3]
# Obs: [736 221 234   2], Reward: -21, terminated: False, total_rewards: -6187
# [3 1 0]
# Obs: [661 554 729   2], Reward: -21, terminated: False, total_rewards: -6208
# [4 0 0]
# Obs: [661 221 397   2], Reward: -21, terminated: False, total_rewards: -6229
# [4 0 0]
# Obs: [661 756 397   2], Reward: -22, terminated: False, total_rewards: -6251
# [2 2 1]
# Obs: [736 254 729   2], Reward: -21, terminated: False, total_rewards: -6272
# [1 1 0]
# Obs: [466 547 397   2], Reward: -21, terminated: False, total_rewards: -6293
# [2 1 4]
# Obs: [527  70 397   2], Reward: -12, terminated: False, total_rewards: -6305
# [1 3 2]
# Obs: [807 554 719   2], Reward: -12, terminated: False, total_rewards: -6317
# [2 3 2]
# Obs: [ 57 494 790   2], Reward: -3, terminated: False, total_rewards: -6320
# [2 1 1]
# Obs: [376 725 296   2], Reward: -12, terminated: False, total_rewards: -6332
# [2 0 4]
# Obs: [447 494 296   2], Reward: -21, terminated: False, total_rewards: -6353
# [1 0 0]
# Obs: [738 152 790   2], Reward: -21, terminated: False, total_rewards: -6374
# [2 0 1]
# Obs: [230 684 296   2], Reward: -12, terminated: False, total_rewards: -6386
# [2 0 4]
# Obs: [304 349 296   2], Reward: -12, terminated: False, total_rewards: -6398
# [1 1 3]
# Obs: [635 684 225   2], Reward: -21, terminated: False, total_rewards: -6419
# [1 1 3]
# Obs: [109 152 729   2], Reward: -21, terminated: False, total_rewards: -6440
# [3 4 3]
# Obs: [ 49 152 655   3], Reward: 79, terminated: False, total_rewards: -6361
# [3 0 4]
# Obs: [534 684 655   3], Reward: -21, terminated: False, total_rewards: -6382
# [1 0 2]
# Obs: [  1 349 729  19], Reward: 79, terminated: False, total_rewards: -6303
# [2 3 0]
# Obs: [ 66  36 397  19], Reward: -12, terminated: False, total_rewards: -6315
# [3 4 1]
# Obs: [  1  36 729  19], Reward: -30, terminated: False, total_rewards: -6345
# [0 0 2]
# Obs: [534  18 225  19], Reward: -21, terminated: False, total_rewards: -6366
# [1 0 3]
# Obs: [  1 279 729  19], Reward: -21, terminated: False, total_rewards: -6387
# [0 4 3]
# Obs: [534 279 655  19], Reward: -30, terminated: False, total_rewards: -6417
# [4 4 4]
# Obs: [534 279 655  19], Reward: -30, terminated: False, total_rewards: -6447
# [4 2 4]
# Obs: [534 603 655  19], Reward: -21, terminated: False, total_rewards: -6468
# [4 1 1]
# Obs: [534  82 164  19], Reward: -21, terminated: False, total_rewards: -6489
# [4 1 1]
# Obs: [534 349 468  19], Reward: -30, terminated: False, total_rewards: -6519
# [0 3 2]
# Obs: [243  36 530  19], Reward: -21, terminated: False, total_rewards: -6540
# [3 1 4]
# Obs: [172 361 530  19], Reward: -21, terminated: False, total_rewards: -6561
# [3 4 0]
# Obs: [676 361 234  19], Reward: -21, terminated: False, total_rewards: -6582
# [0 2 1]
# Obs: [340 684 530  19], Reward: -21, terminated: False, total_rewards: -6603
# [0 3 0]
# Obs: [ 57 361 234  19], Reward: -30, terminated: False, total_rewards: -6633
# [3 3 3]
# Obs: [807 289 164  19], Reward: -30, terminated: False, total_rewards: -6663
# [2 4 4]
# Obs: [ 57 289 164  19], Reward: -30, terminated: False, total_rewards: -6693
# [3 2 0]
# Obs: [807 361 655  19], Reward: -30, terminated: False, total_rewards: -6723
# [4 1 1]
# Obs: [807  94 164  19], Reward: -30, terminated: False, total_rewards: -6753
# [0 4 2]
# Obs: [527  94 234  19], Reward: -30, terminated: False, total_rewards: -6783
# [1 0 2]
# Obs: [807 361 558  19], Reward: -30, terminated: False, total_rewards: -6813
# [2 3 0]
# Obs: [ 57 289 225  19], Reward: -30, terminated: False, total_rewards: -6843
# [1 3 3]
# Obs: [340 795 729  19], Reward: -30, terminated: False, total_rewards: -6873
# [4 0 0]
# Obs: [340 714 397  19], Reward: -21, terminated: False, total_rewards: -6894
# [4 3 1]
# Obs: [340 391 729  19], Reward: -21, terminated: False, total_rewards: -6915
# [0 4 4]
# Obs: [ 57 391 729  19], Reward: -30, terminated: False, total_rewards: -6945
# [4 0 3]
# Obs: [ 57 110 655  19], Reward: -21, terminated: False, total_rewards: -6966
# [4 1 1]
# Obs: [ 57 391 164  19], Reward: -30, terminated: False, total_rewards: -6996
# [2 4 0]
# Obs: [376 391 655  19], Reward: -30, terminated: False, total_rewards: -7026
# [0 2 0]
# Obs: [102 714 322  19], Reward: -12, terminated: False, total_rewards: -7038
# [0 3 3]
# Obs: [622 391 322  19], Reward: -31, terminated: False, total_rewards: -7069
# [0 2 1]
# Obs: [290 714 655  19], Reward: -21, terminated: False, total_rewards: -7090
# [4 0 4]
# Obs: [290 441 655  19], Reward: -21, terminated: False, total_rewards: -7111
# [2 1 0]
# Obs: [362 714 322  19], Reward: -21, terminated: False, total_rewards: -7132
# [4 2 0]
# Obs: [362 783 322  19], Reward: -22, terminated: False, total_rewards: -7154
# [1 1 2]
# Obs: [696 289 397  19], Reward: -21, terminated: False, total_rewards: -7175
# [3 3 3]
# Obs: [622 795 322  19], Reward: -30, terminated: False, total_rewards: -7205
# [3 2 4]
# Obs: [302 289 322  19], Reward: -21, terminated: False, total_rewards: -7226
# [0 2 2]
# Obs: [796 361 397  19], Reward: -21, terminated: False, total_rewards: -7247
# [1 4 3]
# Obs: [302 361 322  19], Reward: -30, terminated: False, total_rewards: -7277
# [4 1 0]
# Obs: [302  94 322  19], Reward: -40, terminated: False, total_rewards: -7317
# [0 3 3]
# Obs: [796 582 322  19], Reward: -40, terminated: False, total_rewards: -7357
# [3 3 0]
# Obs: [724 517 322  19], Reward: -31, terminated: False, total_rewards: -7388
# [4 0 3]
# Obs: [724 795 322  19], Reward: -40, terminated: False, total_rewards: -7428
# [1 4 0]
# Obs: [228 795 322  19], Reward: -31, terminated: False, total_rewards: -7459
# [1 0 3]
# Obs: [527 714 322  19], Reward: -40, terminated: False, total_rewards: -7499
# [4 1 0]
# Obs: [527 795 322  19], Reward: -40, terminated: False, total_rewards: -7539
# [2 0 2]
# Obs: [589 714 397  19], Reward: -21, terminated: False, total_rewards: -7560
# [1 3 3]
# Obs: [ 57 391 322  19], Reward: -30, terminated: False, total_rewards: -7590
# [2 1 2]
# Obs: [376 723 397  19], Reward: -30, terminated: False, total_rewards: -7620
# [1 1 1]
# Obs: [663 187 729  19], Reward: -21, terminated: False, total_rewards: -7641
# [1 0 3]
# Obs: [172 723 655  19], Reward: -30, terminated: False, total_rewards: -7671
# [2 1 0]
# Obs: [243 187 322  19], Reward: -30, terminated: False, total_rewards: -7701
# [3 3 3]
# Obs: [172 123 322  19], Reward: -40, terminated: False, total_rewards: -7741
# [2 2 3]
# Obs: [243 187 322  19], Reward: -40, terminated: False, total_rewards: -7781
# [3 3 3]
# Obs: [172 123 322  19], Reward: -40, terminated: False, total_rewards: -7821
# [0 4 0]
# Obs: [663 123 322  19], Reward: -40, terminated: False, total_rewards: -7861
# [3 1 2]
# Obs: [340 464 397  19], Reward: -21, terminated: False, total_rewards: -7882
# [4 3 2]
# Obs: [340 131 719  19], Reward: -21, terminated: False, total_rewards: -7903
# [2 1 2]
# Obs: [663 366 790  19], Reward: -21, terminated: False, total_rewards: -7924
# [1 0 4]
# Obs: [172 131 790  19], Reward: -30, terminated: False, total_rewards: -7954
# [1 1 3]
# Obs: [473 366 719  19], Reward: -21, terminated: False, total_rewards: -7975
# [1 1 0]
# Obs: [746 700 490  19], Reward: -3, terminated: False, total_rewards: -7978
# [4 0 4]
# Obs: [746 366 490  19], Reward: -30, terminated: False, total_rewards: -8008
# [0 4 3]
# Obs: [473 366 490  19], Reward: -40, terminated: False, total_rewards: -8048
# [3 2 0]
# Obs: [408 689 490  19], Reward: -13, terminated: False, total_rewards: -8061
# [1 4 0]
# Obs: [426 689 490  19], Reward: -31, terminated: False, total_rewards: -8092
# [2 0 1]
# Obs: [746 464 719  19], Reward: -30, terminated: False, total_rewards: -8122
# [0 2 4]
# Obs: [473 526 719  19], Reward: -30, terminated: False, total_rewards: -8152
# [3 1 3]
# Obs: [408 761 397  19], Reward: -30, terminated: False, total_rewards: -8182
# [1 3 3]
# Obs: [426 689 322  19], Reward: -30, terminated: False, total_rewards: -8212
# [4 1 3]
# Obs: [426 196 322  19], Reward: -31, terminated: False, total_rewards: -8243
# [2 1 1]
# Obs: [746 535 655  19], Reward: -21, terminated: False, total_rewards: -8264
# [1 2 3]
# Obs: [254 599 333  19], Reward: -21, terminated: False, total_rewards: -8285
# [0 4 0]
# Obs: [746 599 333  19], Reward: -40, terminated: False, total_rewards: -8325
# [1 4 2]
# Obs: [254 599 655  19], Reward: -30, terminated: False, total_rewards: -8355
# [2 4 4]
# Obs: [324 599 655  19], Reward: -21, terminated: False, total_rewards: -8376
# [2 2 2]
# Obs: [399 673 729  19], Reward: -21, terminated: False, total_rewards: -8397
# [1 4 1]
# Obs: [121 673 234  19], Reward: -21, terminated: False, total_rewards: -8418
# [4 1 3]
# Obs: [121 406 164  19], Reward: -30, terminated: False, total_rewards: -8448
# [4 3 2]
# Obs: [121  81 234  19], Reward: -21, terminated: False, total_rewards: -8469
# [1 4 2]
# Obs: [463  81 558  19], Reward: -21, terminated: False, total_rewards: -8490
# [3 2 2]
# Obs: [128 406 627  19], Reward: -21, terminated: False, total_rewards: -8511
# [1 2 1]
# Obs: [363 472 105  19], Reward: -21, terminated: False, total_rewards: -8532
# [0 1 4]
# Obs: [128 808 105  19], Reward: -30, terminated: False, total_rewards: -8562
# [1 4 3]
# Obs: [363 808  45  19], Reward: -30, terminated: False, total_rewards: -8592
# [2 4 3]
# Obs: [686 808 530  19], Reward: -21, terminated: False, total_rewards: -8613
# [4 2 0]
# Obs: [686  58 234  19], Reward: -30, terminated: False, total_rewards: -8643
# [4 0 2]
# Obs: [686 800 558  19], Reward: -21, terminated: False, total_rewards: -8664
# [0 3 1]
# Obs: [463 472  45  19], Reward: -30, terminated: False, total_rewards: -8694
# [1 0 3]
# Obs: [686 170 530  19], Reward: -30, terminated: False, total_rewards: -8724
# [1 3 4]
# Obs: [767 673 530  19], Reward: -21, terminated: False, total_rewards: -8745
# [1 2 0]
# Obs: [274 170 234  19], Reward: -21, terminated: False, total_rewards: -8766
# [1 2 4]
# Obs: [ 16 240 234  19], Reward: -21, terminated: False, total_rewards: -8787
# [0 2 1]
# Obs: [274 562 530  19], Reward: -21, terminated: False, total_rewards: -8808
# [4 1 4]
# Obs: [274  48 530  19], Reward: -21, terminated: False, total_rewards: -8829
# [2 2 2]
# Obs: [596 108  45  19], Reward: -12, terminated: False, total_rewards: -8841
# [2 4 1]
# Obs: [670 108 312  19], Reward: -12, terminated: False, total_rewards: -8853
# [2 3 4]
# Obs: [167  48 312  19], Reward: -21, terminated: False, total_rewards: -8874
# [3 4 3]
# Obs: [670  48 813  19], Reward: -30, terminated: False, total_rewards: -8904
# [0 3 4]
# Obs: [338 800 813  19], Reward: -21, terminated: False, total_rewards: -8925
# [4 2 4]
# Obs: [338  48 813  19], Reward: -30, terminated: False, total_rewards: -8955
# [3 1 0]
# Obs: [265 377 530  19], Reward: -21, terminated: False, total_rewards: -8976
# [1 0 4]
# Obs: [596  48 530  19], Reward: -30, terminated: False, total_rewards: -9006
# [0 1 4]
# Obs: [265 377 530  19], Reward: -30, terminated: False, total_rewards: -9036
# [0 1 0]
# Obs: [758 604 234  19], Reward: -21, terminated: False, total_rewards: -9057
# [3 3 2]
# Obs: [686 280 558  19], Reward: -30, terminated: False, total_rewards: -9087
# [2 0 0]
# Obs: [758  58 225  19], Reward: -30, terminated: False, total_rewards: -9117
# [2 2 4]
# Obs: [ 14 377 225  19], Reward: -21, terminated: False, total_rewards: -9138
# [2 3 2]
# Obs: [326  58 296  19], Reward: -21, terminated: False, total_rewards: -9159
# [1 3 0]
# Obs: [659 808 790  19], Reward: -21, terminated: False, total_rewards: -9180
# [3 2 0]
# Obs: [338  58 550  19], Reward: -21, terminated: False, total_rewards: -9201
# [1 0 3]
# Obs: [670 800 490  19], Reward: -30, terminated: False, total_rewards: -9231
# [4 3 3]
# Obs: [670 472 490  19], Reward: -40, terminated: False, total_rewards: -9271
# [3 0 2]
# Obs: [596 170 550  19], Reward: -30, terminated: False, total_rewards: -9301
# [1 1 2]
# Obs: [ 79 472  67  19], Reward: -21, terminated: False, total_rewards: -9322
# [2 0 4]
# Obs: [136 170  67  19], Reward: -21, terminated: False, total_rewards: -9343
# [0 4 4]
# Obs: [670 170  67  19], Reward: -30, terminated: False, total_rewards: -9373
# [3 2 0]
# Obs: [596 240 541  19], Reward: -21, terminated: False, total_rewards: -9394
# [4 1 4]
# Obs: [596 800 541  19], Reward: -30, terminated: False, total_rewards: -9424
# [1 2 0]
# Obs: [ 79  48 541  19], Reward: -31, terminated: False, total_rewards: -9455
# [0 3 2]
# Obs: [596 800 610  19], Reward: -21, terminated: False, total_rewards: -9476
# [2 4 0]
# Obs: [670 800 610  19], Reward: -31, terminated: False, total_rewards: -9507
# [0 0 3]
# Obs: [338 240 541  19], Reward: -30, terminated: False, total_rewards: -9537
# [2 0 2]
# Obs: [659 737 610  19], Reward: -21, terminated: False, total_rewards: -9558
# [1 1 3]
# Obs: [167 240 541  19], Reward: -30, terminated: False, total_rewards: -9588
# [0 3 3]
# Obs: [659 170 541  19], Reward: -31, terminated: False, total_rewards: -9619
# [4 2 4]
# Obs: [659 240 541  19], Reward: -30, terminated: False, total_rewards: -9649
# [1 1 3]
# Obs: [167 800 541  19], Reward: -40, terminated: False, total_rewards: -9689
# [3 1 4]
# Obs: [670  58 541  19], Reward: -30, terminated: False, total_rewards: -9719
# [3 0 2]
# Obs: [596 800 610  19], Reward: -30, terminated: False, total_rewards: -9749
# [3 2 0]
# Obs: [274  48 610  19], Reward: -40, terminated: False, total_rewards: -9789
# [0 0 1]
# Obs: [767 562 124  19], Reward: -30, terminated: False, total_rewards: -9819
# [2 4 4]
# Obs: [265 562 124  19], Reward: -30, terminated: False, total_rewards: -9849
# [2 3 4]
# Obs: [338 240 124  19], Reward: -30, terminated: False, total_rewards: -9879
# [3 4 2]
# Obs: [265 240 188  19], Reward: -30, terminated: False, total_rewards: -9909
# [0 1 2]
# Obs: [758 800 519  19], Reward: -30, terminated: False, total_rewards: -9939
# [1 2 1]
# Obs: [265  48 752  19], Reward: -21, terminated: False, total_rewards: -9960
# [2 4 2]
# Obs: [338  48   8  19], Reward: -30, terminated: False, total_rewards: -9990
# [4 1 0]
# Obs: [338 377 583  19], Reward: -30, terminated: False, total_rewards: -10020
# [0 1 3]
# Obs: [ 14 604 519  19], Reward: -30, terminated: False, total_rewards: -10050
# [0 2 3]
# Obs: [587 677 188  19], Reward: -21, terminated: False, total_rewards: -10071
# [2 3 4]
# Obs: [ 98 604 188  19], Reward: -21, terminated: False, total_rewards: -10092
# [0 4 1]
# Obs: [579 604 432  19], Reward: -12, terminated: False, total_rewards: -10104
# [3 3 4]
# Obs: [253 280 432  19], Reward: -21, terminated: False, total_rewards: -10125
# [1 4 4]
# Obs: [587 280 432  19], Reward: -30, terminated: False, total_rewards: -10155
# [3 1 1]
# Obs: [524 613 762  19], Reward: -12, terminated: False, total_rewards: -10167
# [1 2 1]
# Obs: [758 119 270  19], Reward: -21, terminated: False, total_rewards: -10188
# [0 4 3]
# Obs: [524 119 198  19], Reward: -21, terminated: False, total_rewards: -10209
# [3 3 4]
# Obs: [463 613 198  19], Reward: -30, terminated: False, total_rewards: -10239
# [1 1 0]
# Obs: [686 344 690  19], Reward: -21, terminated: False, total_rewards: -10260
# [0 3 4]
# Obs: [463  27 690  19], Reward: -30, terminated: False, total_rewards: -10290
# [0 3 2]
# Obs: [121 773 762  19], Reward: -30, terminated: False, total_rewards: -10320
# [4 0 0]
# Obs: [121 484 432  19], Reward: -30, terminated: False, total_rewards: -10350
# [3 4 1]
# Obs: [615 484 762  19], Reward: -21, terminated: False, total_rewards: -10371
# [4 1 2]
# Obs: [615 773 258  19], Reward: -21, terminated: False, total_rewards: -10392
# [1 4 4]
# Obs: [128 773 258  19], Reward: -30, terminated: False, total_rewards: -10422
# [2 1 1]
# Obs: [463 283 592  19], Reward: -30, terminated: False, total_rewards: -10452
# [4 3 4]
# Obs: [463 784 592  19], Reward: -30, terminated: False, total_rewards: -10482
# [3 2 0]
# Obs: [128 283 258  19], Reward: -30, terminated: False, total_rewards: -10512
# [2 0 1]
# Obs: [463 773 592  19], Reward: -30, terminated: False, total_rewards: -10542
# [1 0 3]
# Obs: [686 484 270  19], Reward: -30, terminated: False, total_rewards: -10572
# [1 2 1]
# Obs: [767 545  13  19], Reward: -21, terminated: False, total_rewards: -10593
# [1 0 1]
# Obs: [274 212  28  19], Reward: -12, terminated: False, total_rewards: -10605
# [1 3 2]
# Obs: [ 16 143 345  19], Reward: -21, terminated: False, total_rewards: -10626
# [0 1 3]
# Obs: [274 484  28  19], Reward: -30, terminated: False, total_rewards: -10656
# [4 2 1]
# Obs: [274 545 308  19], Reward: -21, terminated: False, total_rewards: -10677
# [3 4 0]
# Obs: [204 545  28  19], Reward: -21, terminated: False, total_rewards: -10698
# [2 0 4]
# Obs: [274 212  28  19], Reward: -30, terminated: False, total_rewards: -10728
# [0 0 3]
# Obs: [767 808 774  19], Reward: -21, terminated: False, total_rewards: -10749
# [4 3 3]
# Obs: [767 740 454  19], Reward: -12, terminated: False, total_rewards: -10761
# [4 2 4]
# Obs: [767 808 454  19], Reward: -30, terminated: False, total_rewards: -10791
# [2 2 3]
# Obs: [265  58 382  19], Reward: -30, terminated: False, total_rewards: -10821
# [1 2 1]
# Obs: [596 377 668  19], Reward: -30, terminated: False, total_rewards: -10851
# [1 1 0]
# Obs: [ 79 604 382  19], Reward: -30, terminated: False, total_rewards: -10881
# [1 3 2]
# Obs: [412 280 454  19], Reward: -21, terminated: False, total_rewards: -10902
# [1 0 1]
# Obs: [638  58 166  19], Reward: -21, terminated: False, total_rewards: -10923
# [3 3 0]
# Obs: [568 808 454  19], Reward: -21, terminated: False, total_rewards: -10944
# [3 3 4]
# Obs: [244 740 454  19], Reward: -30, terminated: False, total_rewards: -10974
# [4 2 3]
# Obs: [244 808 382  19], Reward: -30, terminated: False, total_rewards: -11004
# [3 0 0]
# Obs: [173 472 105  19], Reward: -30, terminated: False, total_rewards: -11034
# [0 4 0]
# Obs: [769 472 627  19], Reward: -21, terminated: False, total_rewards: -11055
# [4 3 3]
# Obs: [769 406 558  19], Reward: -30, terminated: False, total_rewards: -11085
# [3 2 2]
# Obs: [448 472 627  19], Reward: -30, terminated: False, total_rewards: -11115
# [4 0 0]
# Obs: [448 170 296  19], Reward: -30, terminated: False, total_rewards: -11145
# [3 2 0]
# Obs: [377 240 790  19], Reward: -30, terminated: False, total_rewards: -11175
# [1 3 1]
# Obs: [604 170 296  19], Reward: -30, terminated: False, total_rewards: -11205
# [4 0 1]
# Obs: [604 662 627  19], Reward: -30, terminated: False, total_rewards: -11235
# [4 3 4]
# Obs: [604 591 627  19], Reward: -21, terminated: False, total_rewards: -11256
# [3 2 3]
# Obs: [280 662 558  19], Reward: -30, terminated: False, total_rewards: -11286
# [2 1 0]
# Obs: [604 170 225  19], Reward: -30, terminated: False, total_rewards: -11316
# [2 3 0]
# Obs: [677 673 719  19], Reward: -30, terminated: False, total_rewards: -11346
# [1 1 0]
# Obs: [183 406 490  19], Reward: -30, terminated: False, total_rewards: -11376
# [3 0 0]
# Obs: [119 673 490  19], Reward: -40, terminated: False, total_rewards: -11416
# [1 1 3]
# Obs: [417 406 490  19], Reward: -40, terminated: False, total_rewards: -11456
# [2 2 2]
# Obs: [482 472 550  19], Reward: -30, terminated: False, total_rewards: -11486
# [0 3 2]
# Obs: [183 406  67  19], Reward: -30, terminated: False, total_rewards: -11516
# [2 1 4]
# Obs: [514 740  67  19], Reward: -30, terminated: False, total_rewards: -11546
# [1 0 3]
# Obs: [810 406 550  19], Reward: -30, terminated: False, total_rewards: -11576
# [1 2 1]
# Obs: [315 472 790  19], Reward: -21, terminated: False, total_rewards: -11597
# [0 3 2]
# Obs: [810 406 286  19], Reward: -21, terminated: False, total_rewards: -11618
# [0 4 4]
# Obs: [514 406 286  19], Reward: -30, terminated: False, total_rewards: -11648
# [1 4 2]
# Obs: [810 406 356  19], Reward: -21, terminated: False, total_rewards: -11669
# [0 4 1]
# Obs: [514 406 690  19], Reward: -30, terminated: False, total_rewards: -11699
# [4 3 2]
# Obs: [514  81 762  19], Reward: -30, terminated: False, total_rewards: -11729
# [1 0 0]
# Obs: [810 599 432  19], Reward: -30, terminated: False, total_rewards: -11759
# [4 3 1]
# Obs: [810 535 762  19], Reward: -30, terminated: False, total_rewards: -11789
# [1 4 2]
# Obs: [315 535 258  19], Reward: -30, terminated: False, total_rewards: -11819
# [1 4 3]
# Obs: [335 535 762  19], Reward: -30, terminated: False, total_rewards: -11849
# [0 1 0]
# Obs: [315  17 432  19], Reward: -21, terminated: False, total_rewards: -11870
# [2 2 2]
# Obs: [388  81 752  19], Reward: -21, terminated: False, total_rewards: -11891
# [4 4 4]
# Obs: [388  81 752  19], Reward: -30, terminated: False, total_rewards: -11921
# [4 0 3]
# Obs: [388 599 432  19], Reward: -30, terminated: False, total_rewards: -11951
# [2 3 0]
# Obs: [712 535 188  19], Reward: -21, terminated: False, total_rewards: -11972
# [2 0 4]
# Obs: [780 196 188  19], Reward: -21, terminated: False, total_rewards: -11993
# [1 4 3]
# Obs: [780 196 124  19], Reward: -31, terminated: False, total_rewards: -12024
# [3 0 4]
# Obs: [712 689 124  19], Reward: -30, terminated: False, total_rewards: -12054
# [3 0 1]
# Obs: [388 464 356  19], Reward: -30, terminated: False, total_rewards: -12084
# [2 2 1]
# Obs: [712 526 690  19], Reward: -30, terminated: False, total_rewards: -12114
# [4 4 2]
# Obs: [712 526 762  19], Reward: -30, terminated: False, total_rewards: -12144
# [2 0 2]
# Obs: [780 187 258  19], Reward: -30, terminated: False, total_rewards: -12174
# [1 1 4]
# Obs: [780 526 258  19], Reward: -40, terminated: False, total_rewards: -12214
# [4 4 1]
# Obs: [780 526 592  19], Reward: -30, terminated: False, total_rewards: -12244
# [3 1 3]
# Obs: [712 761 270  19], Reward: -30, terminated: False, total_rewards: -12274
# [1 3 2]
# Obs: [731 689 592  19], Reward: -21, terminated: False, total_rewards: -12295
# [2 4 1]
# Obs: [731 689  75  19], Reward: -40, terminated: False, total_rewards: -12335
# [4 0 4]
# Obs: [731 464  75  19], Reward: -30, terminated: False, total_rewards: -12365
# [2 2 0]
# Obs: [731 526 592  19], Reward: -40, terminated: False, total_rewards: -12405
# [4 3 2]
# Obs: [731 464 664  19], Reward: -30, terminated: False, total_rewards: -12435
# [1 4 0]
# Obs: [731 464 331  19], Reward: -31, terminated: False, total_rewards: -12466
# [1 2 4]
# Obs: [731 526 331  19], Reward: -40, terminated: False, total_rewards: -12506
# [4 3 1]
# Obs: [731 464 664  19], Reward: -30, terminated: False, total_rewards: -12536
# [3 1 0]
# Obs: [657 689 331  19], Reward: -21, terminated: False, total_rewards: -12557
# [1 0 3]
# Obs: [129 464 258  19], Reward: -21, terminated: False, total_rewards: -12578
# [2 4 0]
# Obs: [129 464 752  19], Reward: -40, terminated: False, total_rewards: -12618
# [3 2 2]
# Obs: [ 71 526   8  19], Reward: -30, terminated: False, total_rewards: -12648
# [0 2 3]
# Obs: [335  40 752  19], Reward: -30, terminated: False, total_rewards: -12678
# [1 3 3]
# Obs: [ 71 526 432  19], Reward: -30, terminated: False, total_rewards: -12708
# [0 4 1]
# Obs: [335 526 762  19], Reward: -30, terminated: False, total_rewards: -12738
# [2 4 3]
# Obs: [657 526 690  19], Reward: -30, terminated: False, total_rewards: -12768
# [4 1 4]
# Obs: [657 761 690  19], Reward: -30, terminated: False, total_rewards: -12798
# [1 2 4]
# Obs: [129 257 690  19], Reward: -21, terminated: False, total_rewards: -12819
# [3 3 4]
# Obs: [ 71 761 690  19], Reward: -30, terminated: False, total_rewards: -12849
# [1 1 0]
# Obs: [405 268 356  19], Reward: -12, terminated: False, total_rewards: -12861
# [3 2 4]
# Obs: [ 77 591 356  19], Reward: -21, terminated: False, total_rewards: -12882
# [2 2 1]
# Obs: [405 662 690  19], Reward: -30, terminated: False, total_rewards: -12912
# [2 0 1]
# Obs: [405 329 198  19], Reward: -31, terminated: False, total_rewards: -12943
# [0 0 1]
# Obs: [ 71 100 499  19], Reward: -21, terminated: False, total_rewards: -12964
# [2 0 2]
# Obs: [129 582  13  19], Reward: -30, terminated: False, total_rewards: -12994
# [4 4 3]
# Obs: [129 582 499  19], Reward: -30, terminated: False, total_rewards: -13024
# [2 4 0]
# Obs: [129 582 198  19], Reward: -40, terminated: False, total_rewards: -13064
# [0 0 3]
# Obs: [657 289 134  19], Reward: -30, terminated: False, total_rewards: -13094
# [3 3 1]
# Obs: [335 795 436  19], Reward: -21, terminated: False, total_rewards: -13115
# [2 1 3]
# Obs: [657 517 105  19], Reward: -30, terminated: False, total_rewards: -13145
# [4 1 1]
# Obs: [657  40 382  19], Reward: -30, terminated: False, total_rewards: -13175
# [0 3 4]
# Obs: [388 526 382  19], Reward: -30, terminated: False, total_rewards: -13205
# [0 1 1]
# Obs: [ 60 761 668  19], Reward: -30, terminated: False, total_rewards: -13235
# [3 0 3]
# Obs: [810 526 595  19], Reward: -21, terminated: False, total_rewards: -13256
# [0 3 2]
# Obs: [514 464 668  19], Reward: -30, terminated: False, total_rewards: -13286
# [0 2 1]
# Obs: [173 526 179  19], Reward: -30, terminated: False, total_rewards: -13316
# [2 2 1]
# Obs: [244  40 476  19], Reward: -21, terminated: False, total_rewards: -13337
# [1 4 0]
# Obs: [577  40 179  19], Reward: -30, terminated: False, total_rewards: -13367
# [2 0 1]
# Obs: [647 517 476  19], Reward: -30, terminated: False, total_rewards: -13397
# [4 1 3]
# Obs: [647  40 410  19], Reward: -21, terminated: False, total_rewards: -13418
# [0 1 2]
# Obs: [568 257 476  19], Reward: -30, terminated: False, total_rewards: -13448
# [4 4 0]
# Obs: [568 257 179  19], Reward: -30, terminated: False, total_rewards: -13478
# [1 0 4]
# Obs: [647  40 179  19], Reward: -30, terminated: False, total_rewards: -13508
# [4 0 1]
# Obs: [647 517 476  19], Reward: -30, terminated: False, total_rewards: -13538
# [0 1 4]
# Obs: [568  40 476  19], Reward: -30, terminated: False, total_rewards: -13568
# [1 3 2]
# Obs: [647 526 804  19], Reward: -21, terminated: False, total_rewards: -13589
# [2 2 0]
# Obs: [147  40 511  19], Reward: -12, terminated: False, total_rewards: -13601
# [0 0 2]
# Obs: [638 517 573  19], Reward: -21, terminated: False, total_rewards: -13622
# [0 2 2]
# Obs: [412 582 643  19], Reward: -21, terminated: False, total_rewards: -13643
# [0 1 3]
# Obs: [ 79 100 573  19], Reward: -30, terminated: False, total_rewards: -13673
# [3 4 1]
# Obs: [ 16 100  53  19], Reward: -21, terminated: False, total_rewards: -13694
# [2 1 4]
# Obs: [ 79 329  53  19], Reward: -30, terminated: False, total_rewards: -13724
# [0 4 1]
# Obs: [596 329 319  19], Reward: -21, terminated: False, total_rewards: -13745
# [3 2 3]
# Obs: [274 404   7  19], Reward: -12, terminated: False, total_rewards: -13757
# [4 2 4]
# Obs: [274 725   7  19], Reward: -30, terminated: False, total_rewards: -13787
# [1 0 1]
# Obs: [ 16 494 330  19], Reward: -21, terminated: False, total_rewards: -13808
# [2 2 1]
# Obs: [ 79 554 330  19], Reward: -31, terminated: False, total_rewards: -13839
# [0 1 0]
# Obs: [596 797   7  19], Reward: -21, terminated: False, total_rewards: -13860
# [0 2 0]
# Obs: [265 291 804  19], Reward: -21, terminated: False, total_rewards: -13881
# [1 3 3]
# Obs: [596 797 476  19], Reward: -30, terminated: False, total_rewards: -13911
# [3 3 3]
# Obs: [274 725 410  19], Reward: -30, terminated: False, total_rewards: -13941
# [0 3 4]
# Obs: [767 404 410  19], Reward: -30, terminated: False, total_rewards: -13971
# [2 1 4]
# Obs: [265 737 410  19], Reward: -30, terminated: False, total_rewards: -14001
# [0 2 2]
# Obs: [758 229 476  19], Reward: -21, terminated: False, total_rewards: -14022
# [2 4 0]
# Obs: [ 14 229 179  19], Reward: -30, terminated: False, total_rewards: -14052
# [1 4 1]
# Obs: [338 229 476  19], Reward: -30, terminated: False, total_rewards: -14082
# [3 0 1]
# Obs: [265 725 751  19], Reward: -21, terminated: False, total_rewards: -14103
# [0 2 3]
# Obs: [758 797 751  19], Reward: -31, terminated: False, total_rewards: -14134
# [0 0 2]
# Obs: [524 554   7  19], Reward: -30, terminated: False, total_rewards: -14164
# [4 3 3]
# Obs: [524 494 751  19], Reward: -30, terminated: False, total_rewards: -14194
# [1 1 0]
# Obs: [758 725 476  19], Reward: -30, terminated: False, total_rewards: -14224
# [1 1 1]
# Obs: [265 229 751  19], Reward: -30, terminated: False, total_rewards: -14254
# [1 3 3]
# Obs: [596 737 751  19], Reward: -40, terminated: False, total_rewards: -14294
# [4 0 3]
# Obs: [596 404 751  19], Reward: -40, terminated: False, total_rewards: -14334
# [0 3 4]
# Obs: [265 329 751  19], Reward: -30, terminated: False, total_rewards: -14364
# [0 0 0]
# ...
# [0 2 0]
# Obs: [ 63 486 432  27], Reward: -30, terminated: False, total_rewards: -28821
# [3 3 3]
# Obs: [814 153 356  27], Reward: -30, terminated: False, total_rewards: -28851
# [0 0 1]
# Obs: [479 644 690  27], Reward: -30, terminated: False, total_rewards: -28881
# [0 2 2]
# Obs: [238 145 762  27], Reward: -30, terminated: False, total_rewards: -28911
# [3 1 2]
# Obs: [168 486 258  27], Reward: -30, terminated: False, total_rewards: -28941
# [3 3 2]
# Obs: [671 153 331  27], Reward: -30, terminated: False, total_rewards: -28971
# [0 3 1]
# Obs: [671  95 664  27], Reward: -31, terminated: False, total_rewards: -29002
# [4 1 2]
# Obs: [671 320 162  27], Reward: -30, terminated: False, total_rewards: -29032
# [1 2 1]
# Obs: [ 87 395 467  27], Reward: -30, terminated: False, total_rewards: -29062
# [0 1 2]
# Obs: [671 727 529  27], Reward: -30, terminated: False, total_rewards: -29092
# [0 0 1]
# Obs: [671 395 811  27], Reward: -40, terminated: False, total_rewards: -29132
# [0 1 0]
# Obs: [671 727 529  27], Reward: -40, terminated: False, total_rewards: -29172
# [1 3 3]
# Obs: [ 87 653 467  27], Reward: -30, terminated: False, total_rewards: -29202
# [2 4 4]
# Obs: [413 653 467  27], Reward: -30, terminated: False, total_rewards: -29232
# [1 4 2]
# Obs: [485 653 529  27], Reward: -30, terminated: False, total_rewards: -29262
# [1 4 0]
# Obs: [208 653 231  27], Reward: -30, terminated: False, total_rewards: -29292
# [4 4 3]
# Obs: [208 653 162  27], Reward: -30, terminated: False, total_rewards: -29322
# [3 1 3]
# Obs: [710 162 664  27], Reward: -30, terminated: False, total_rewards: -29352
# [0 0 1]
# Obs: [422 653 133  27], Reward: -30, terminated: False, total_rewards: -29382
# [1 4 1]
# Obs: [710 653 418  27], Reward: -30, terminated: False, total_rewards: -29412
# [0 1 3]
# Obs: [422 162 345  27], Reward: -30, terminated: False, total_rewards: -29442
# [0 0 0]
# Obs: [ 87 653  75  27], Reward: -30, terminated: False, total_rewards: -29472
# [1 0 2]
# Obs: [422 320 133  27], Reward: -30, terminated: False, total_rewards: -29502
# [0 1 3]
# Obs: [ 87 653  75  27], Reward: -30, terminated: False, total_rewards: -29532
# [0 1 2]
# Obs: [671 162 133  27], Reward: -30, terminated: False, total_rewards: -29562
# [0 4 2]
# Obs: [671 162 467  27], Reward: -40, terminated: False, total_rewards: -29602
# [1 0 1]
# Obs: [ 87 653 742  27], Reward: -30, terminated: False, total_rewards: -29632
# [4 2 4]
# Obs: [ 87 727 742  27], Reward: -30, terminated: False, total_rewards: -29662
# [4 2 1]
# Obs: [ 87 224 199  27], Reward: -30, terminated: False, total_rewards: -29692
# [1 3 3]
# Obs: [422 727 702  27], Reward: -30, terminated: False, total_rewards: -29722
# [4 4 0]
# Obs: [422 727 418  27], Reward: -30, terminated: False, total_rewards: -29752
# [4 4 0]
# Obs: [422 727 133  27], Reward: -30, terminated: False, total_rewards: -29782
# [1 2 3]
# Obs: [710 224  75  27], Reward: -30, terminated: False, total_rewards: -29812
# [2 1 1]
# Obs: [208 305 345  27], Reward: -30, terminated: False, total_rewards: -29842
# [4 1 3]
# Obs: [208  44  28  27], Reward: -30, terminated: False, total_rewards: -29872
# [1 0 2]
# Obs: [543 305 345  27], Reward: -30, terminated: False, total_rewards: -29902
# [0 3 2]
# Obs: [208 231 418  27], Reward: -30, terminated: False, total_rewards: -29932
# [2 3 4]
# Obs: [278 162 418  27], Reward: -30, terminated: False, total_rewards: -29962
# [3 0 2]
# Obs: [208 653 742  27], Reward: -30, terminated: False, total_rewards: -29992
# [3 0 1]
# Obs: [710 320 199  27], Reward: -30, terminated: False, total_rewards: -30022
# [2 0 3]
# Obs: [208  95 702  27], Reward: -30, terminated: False, total_rewards: -30052
# [1 1 2]
# Obs: [543 320 199  27], Reward: -30, terminated: False, total_rewards: -30082
# [0 1 2]
# Obs: [208 653 271  27], Reward: -30, terminated: False, total_rewards: -30112
# [3 0 1]
# Obs: [710 320 607  27], Reward: -30, terminated: False, total_rewards: -30142
# [4 1 1]
# Obs: [710 653  84  27], Reward: -30, terminated: False, total_rewards: -30172
# [4 0 3]
# Obs: [710 320  19  27], Reward: -30, terminated: False, total_rewards: -30202
# [4 1 4]
# Obs: [710 653  19  27], Reward: -30, terminated: False, total_rewards: -30232
# [3 1 4]
# Obs: [637 162  19  27], Reward: -30, terminated: False, total_rewards: -30262
# [1 2 1]
# Obs: [148 231 285  27], Reward: -30, terminated: False, total_rewards: -30292
# [1 4 4]
# Obs: [389 231 285  27], Reward: -30, terminated: False, total_rewards: -30322
# [3 2 2]
# Obs: [ 68 305 353  27], Reward: -21, terminated: False, total_rewards: -30343
# [0 2 4]
# Obs: [648 624 353  27], Reward: -30, terminated: False, total_rewards: -30373
# [4 4 3]
# Obs: [648 624 285  27], Reward: -30, terminated: False, total_rewards: -30403
# [2 0 2]
# Obs: [148 294 353  27], Reward: -30, terminated: False, total_rewards: -30433
# [3 0 2]
# Obs: [648 788 429  27], Reward: -21, terminated: False, total_rewards: -30454
# [2 1 1]
# Obs: [148 294 759  27], Reward: -21, terminated: False, total_rewards: -30475
# [0 0 4]
# Obs: [637 788 759  27], Reward: -30, terminated: False, total_rewards: -30505
# [2 4 4]
# Obs: [710 788 759  27], Reward: -30, terminated: False, total_rewards: -30535
# [2 1 0]
# Obs: [208 294 429  27], Reward: -30, terminated: False, total_rewards: -30565
# [0 0 3]
# Obs: [485 788 353  27], Reward: -30, terminated: False, total_rewards: -30595
# [4 3 4]
# Obs: [485 717 353  27], Reward: -30, terminated: False, total_rewards: -30625
# [4 1 4]
# Obs: [485 224 353  27], Reward: -30, terminated: False, total_rewards: -30655
# [4 1 3]
# Obs: [485 305 285  27], Reward: -30, terminated: False, total_rewards: -30685
# [3 2 2]
# Obs: [422 624 353  27], Reward: -30, terminated: False, total_rewards: -30715
# [4 4 1]
# Obs: [422 624 687  27], Reward: -21, terminated: False, total_rewards: -30736
# [3 1 1]
# Obs: [346 104 154  27], Reward: -30, terminated: False, total_rewards: -30766
# [3 1 0]
# Obs: [ 32 379 687  27], Reward: -30, terminated: False, total_rewards: -30796
# [0 0 4]
# Obs: [512 104 687  27], Reward: -30, terminated: False, total_rewards: -30826
# [1 1 0]
# Obs: [ 32 379 353  27], Reward: -30, terminated: False, total_rewards: -30856
# [0 4 1]
# Obs: [512 379 687  27], Reward: -30, terminated: False, total_rewards: -30886
# [2 3 2]
# Obs: [ 23  61 759  27], Reward: -30, terminated: False, total_rewards: -30916
# [0 4 2]
# Obs: [597  61 255  27], Reward: -21, terminated: False, total_rewards: -30937
# [0 4 3]
# Obs: [597  61 759  27], Reward: -31, terminated: False, total_rewards: -30968
# [4 0 3]
# Obs: [597  44 687  27], Reward: -30, terminated: False, total_rewards: -30998
# [0 0 1]
# Obs: [597 305 154  27], Reward: -40, terminated: False, total_rewards: -31038
# [1 0 2]
# Obs: [ 23 224 489  27], Reward: -21, terminated: False, total_rewards: -31059
# [0 0 2]
# Obs: [597 717 549  27], Reward: -21, terminated: False, total_rewards: -31080
# [3 4 1]
# Obs: [275 717  73  27], Reward: -30, terminated: False, total_rewards: -31110
# [3 0 3]
# Obs: [205 486  10  27], Reward: -30, terminated: False, total_rewards: -31140
# [3 2 3]
# Obs: [707 548 497  27], Reward: -30, terminated: False, total_rewards: -31170
# [3 4 4]
# Obs: [634 548 497  27], Reward: -21, terminated: False, total_rewards: -31191
# [2 0 1]
# Obs: [707 215 728  27], Reward: -30, terminated: False, total_rewards: -31221
# [1 3 2]
# Obs: [117 145 798  27], Reward: -30, terminated: False, total_rewards: -31251
# [0 0 1]
# Obs: [707 428 306  27], Reward: -12, terminated: False, total_rewards: -31263
# [0 3 2]
# Obs: [707 352 625  27], Reward: -31, terminated: False, total_rewards: -31294
# [0 4 0]
# Obs: [707 352 295  27], Reward: -40, terminated: False, total_rewards: -31334
# [2 0 2]
# Obs: [205  29 366  27], Reward: -21, terminated: False, total_rewards: -31355
# [1 2 3]
# Obs: [449  90 295  27], Reward: -21, terminated: False, total_rewards: -31376
# [2 1 3]
# Obs: [512 428 798  27], Reward: -30, terminated: False, total_rewards: -31406
# [0 4 0]
# Obs: [275 428  10  27], Reward: -30, terminated: False, total_rewards: -31436
# [4 1 4]
# Obs: [275 145  10  27], Reward: -30, terminated: False, total_rewards: -31466
# [2 0 0]
# Obs: [597 428 489  27], Reward: -30, terminated: False, total_rewards: -31496
# [1 4 2]
# Obs: [ 23 428 549  27], Reward: -30, terminated: False, total_rewards: -31526
# [0 0 4]
# Obs: [597  90 549  27], Reward: -30, terminated: False, total_rewards: -31556
# [2 0 2]
# Obs: [671 113 617  27], Reward: -21, terminated: False, total_rewards: -31577
# [3 4 1]
# Obs: [597 113 131  27], Reward: -30, terminated: False, total_rewards: -31607
# [3 4 1]
# Obs: [275 113 366  27], Reward: -30, terminated: False, total_rewards: -31637
# [1 1 4]
# Obs: [512  90 366  27], Reward: -30, terminated: False, total_rewards: -31667
# [2 1 4]
# Obs: [ 23 428 366  27], Reward: -30, terminated: False, total_rewards: -31697
# [4 0 0]
# Obs: [ 23  90 131  27], Reward: -30, terminated: False, total_rewards: -31727
# [0 2 4]
# Obs: [597 419 131  27], Reward: -30, terminated: False, total_rewards: -31757
# [2 4 1]
# Obs: [671 419 366  27], Reward: -30, terminated: False, total_rewards: -31787
# [0 4 4]
# Obs: [671 419 366  27], Reward: -40, terminated: False, total_rewards: -31827
# [3 1 4]
# Obs: [597 748 366  27], Reward: -30, terminated: False, total_rewards: -31857
# [1 1 2]
# Obs: [ 23 215 689  27], Reward: -30, terminated: False, total_rewards: -31887
# [2 2 2]
# Obs: [ 87 282 761  27], Reward: -30, terminated: False, total_rewards: -31917
# [4 4 4]
# Obs: [ 87 282 761  27], Reward: -30, terminated: False, total_rewards: -31947
# [1 0 0]
# Obs: [422   4 526  27], Reward: -30, terminated: False, total_rewards: -31977
# [3 4 4]
# Obs: [346   4 526  27], Reward: -30, terminated: False, total_rewards: -32007
# [0 1 1]
# Obs: [ 23 282 761  27], Reward: -30, terminated: False, total_rewards: -32037
# [1 3 3]
# Obs: [346 215 689  27], Reward: -30, terminated: False, total_rewards: -32067
# [1 4 3]
# Obs: [637 215 366  27], Reward: -30, terminated: False, total_rewards: -32097
# [0 3 1]
# Obs: [346 145 700  27], Reward: -30, terminated: False, total_rewards: -32127
# [4 0 3]
# Obs: [346 428 625  27], Reward: -30, terminated: False, total_rewards: -32157
# [2 1 3]
# Obs: [422 145 306  27], Reward: -30, terminated: False, total_rewards: -32187
# [3 0 3]
# Obs: [346 428 232  27], Reward: -21, terminated: False, total_rewards: -32208
# [1 3 3]
# Obs: [637 352 163  27], Reward: -21, terminated: False, total_rewards: -32229
# [4 1 3]
# Obs: [637 644 665  27], Reward: -21, terminated: False, total_rewards: -32250
# [2 3 3]
# Obs: [710 574 665  27], Reward: -31, terminated: False, total_rewards: -32281
# [4 4 0]
# Obs: [710 574 332  27], Reward: -21, terminated: False, total_rewards: -32302
# [2 4 3]
# Obs: [208 574 259  27], Reward: -30, terminated: False, total_rewards: -32332
# [4 3 1]
# Obs: [208 250 259  27], Reward: -40, terminated: False, total_rewards: -32372
# [3 2 4]
# Obs: [710 574 259  27], Reward: -30, terminated: False, total_rewards: -32402
# [0 1 1]
# Obs: [422  95 259  27], Reward: -40, terminated: False, total_rewards: -32442
# [4 2 3]
# Obs: [422 153 259  27], Reward: -31, terminated: False, total_rewards: -32473
# [2 2 4]
# Obs: [485 486 259  27], Reward: -30, terminated: False, total_rewards: -32503
# [2 2 2]
# Obs: [814 548 332  27], Reward: -30, terminated: False, total_rewards: -32533
# [1 0 0]
# Obs: [278 215 103  27], Reward: -30, terminated: False, total_rewards: -32563
# [3 0 0]
# Obs: [208 748 584  27], Reward: -30, terminated: False, total_rewards: -32593
# [4 3 4]
# Obs: [208 428 584  27], Reward: -30, terminated: False, total_rewards: -32623
# [3 0 0]
# Obs: [710  90 292  27], Reward: -30, terminated: False, total_rewards: -32653
# [3 2 3]
# Obs: [637 419 223  27], Reward: -30, terminated: False, total_rewards: -32683
# [0 1 3]
# Obs: [346 748 726  27], Reward: -30, terminated: False, total_rewards: -32713
# [4 4 3]
# Obs: [346 748 652  27], Reward: -30, terminated: False, total_rewards: -32743
# [3 2 3]
# Obs: [ 32   4 330  27], Reward: -30, terminated: False, total_rewards: -32773
# [3 4 2]
# Obs: [778   4 652  27], Reward: -30, terminated: False, total_rewards: -32803
# [4 1 3]
# Obs: [778 282 330  27], Reward: -30, terminated: False, total_rewards: -32833
# [1 1 0]
# Obs: [245 616   7  27], Reward: -30, terminated: False, total_rewards: -32863
# [1 2 1]
# Obs: [578 122 330  27], Reward: -30, terminated: False, total_rewards: -32893
# [1 0 4]
# Obs: [  3 608 330  27], Reward: -30, terminated: False, total_rewards: -32923
# [1 4 1]
# Obs: [325 608 330  27], Reward: -40, terminated: False, total_rewards: -32963
# [2 4 2]
# Obs: [400 608 652  27], Reward: -30, terminated: False, total_rewards: -32993
# [2 0 3]
# Obs: [721 316 330  27], Reward: -30, terminated: False, total_rewards: -33023
# [2 2 4]
# Obs: [793 390 330  27], Reward: -30, terminated: False, total_rewards: -33053
# [4 3 4]
# Obs: [793 316 330  27], Reward: -30, terminated: False, total_rewards: -33083
# [0 1 1]
# Obs: [461 608 330  27], Reward: -40, terminated: False, total_rewards: -33123
# [0 0 2]
# Obs: [218 316 652  27], Reward: -30, terminated: False, total_rewards: -33153
# [1 1 1]
# Obs: [461 608 125  27], Reward: -30, terminated: False, total_rewards: -33183
# [2 3 2]
# Obs: [781 282 189  27], Reward: -30, terminated: False, total_rewards: -33213
# [1 4 0]
# Obs: [288 282 726  27], Reward: -30, terminated: False, total_rewards: -33243
# [4 2 3]
# Obs: [288 608 652  27], Reward: -30, terminated: False, total_rewards: -33273
# [1 3 3]
# Obs: [368 282 330  27], Reward: -30, terminated: False, total_rewards: -33303
# [4 3 2]
# Obs: [368 215 652  27], Reward: -30, terminated: False, total_rewards: -33333
# [4 4 1]
# Obs: [368 215 125  27], Reward: -30, terminated: False, total_rewards: -33363
# [4 2 0]
# Obs: [368 282 652  27], Reward: -30, terminated: False, total_rewards: -33393
# [2 0 4]
# Obs: [692   4 652  27], Reward: -30, terminated: False, total_rewards: -33423
# [3 0 1]
# Obs: [368 483 125  27], Reward: -30, terminated: False, total_rewards: -33453
# [0 3 2]
# Obs: [288 419 189  27], Reward: -30, terminated: False, total_rewards: -33483
# [1 2 2]
# Obs: [368 483 520  27], Reward: -30, terminated: False, total_rewards: -33513
# [0 0 3]
# Obs: [288 246 189  27], Reward: -30, terminated: False, total_rewards: -33543
# [2 0 3]
# Obs: [359 246 125  27], Reward: -40, terminated: False, total_rewards: -33583
# [3 3 1]
# Obs: [288 175 125  27], Reward: -31, terminated: False, total_rewards: -33614
# [2 4 1]
# Obs: [359 175 125  27], Reward: -40, terminated: False, total_rewards: -33654
# [0 0 3]
# Obs: [ 34 175 125  27], Reward: -50, terminated: False, total_rewards: -33704
# [1 4 3]
# Obs: [359 175 125  27], Reward: -40, terminated: False, total_rewards: -33744
# [4 3 1]
# Obs: [359 113 125  27], Reward: -40, terminated: False, total_rewards: -33784
# [3 1 4]
# Obs: [288  90 125  27], Reward: -30, terminated: False, total_rewards: -33814
# [0 4 2]
# Obs: [781  90 189  27], Reward: -30, terminated: False, total_rewards: -33844
# [3 0 0]
# Obs: [461 113 726  27], Reward: -30, terminated: False, total_rewards: -33874
# [2 1 3]
# Obs: [781  90 652  27], Reward: -30, terminated: False, total_rewards: -33904
# [0 2 3]
# Obs: [543 419 330  27], Reward: -30, terminated: False, total_rewards: -33934
# [4 1 2]
# Obs: [543 748 652  27], Reward: -30, terminated: False, total_rewards: -33964
# [2 4 3]
# Obs: [611 748 330  27], Reward: -30, terminated: False, total_rewards: -33994
# [3 1 1]
# Obs: [543 215 330  27], Reward: -40, terminated: False, total_rewards: -34034
# [1 2 1]
# Obs: [781 282 330  27], Reward: -40, terminated: False, total_rewards: -34074
# [1 1 4]
# Obs: [288 616 330  27], Reward: -30, terminated: False, total_rewards: -34104
# [0 3 3]
# Obs: [781 548 330  27], Reward: -40, terminated: False, total_rewards: -34144
# [2 0 4]
# Obs: [ 34 215 330  27], Reward: -30, terminated: False, total_rewards: -34174
# [1 0 4]
# Obs: [359 748 330  27], Reward: -30, terminated: False, total_rewards: -34204
# [2 4 4]
# Obs: [434 748 330  27], Reward: -21, terminated: False, total_rewards: -34225
# [1 1 4]
# Obs: [764 215 330  27], Reward: -21, terminated: False, total_rewards: -34246
# [1 4 0]
# Obs: [493 215   7  27], Reward: -21, terminated: False, total_rewards: -34267
# [3 2 3]
# Obs: [157 282 751  27], Reward: -21, terminated: False, total_rewards: -34288
# [1 0 2]
# Obs: [444   4   7  27], Reward: -21, terminated: False, total_rewards: -34309
# [3 3 1]
# Obs: [112 748 330  31], Reward: 100079, terminated: True, total_rewards: 65770
# terminated: True truncated: False

# %%
# Close the environment
env.close()
# Set a breakpoint
assert False, "breakpoint"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 4
#       2 env.close()
#       3 # Set a breakpoint
# ----> 4 assert False, "breakpoint"
#
# AssertionError: breakpoint

# %% [markdown]
# # Training cell

# %%
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

# Training cell
vec_env = make_vec_env('ThreeAgentGridworld-v0', n_envs=4)

model = A2C("MlpPolicy", vec_env, verbose=1, tensorboard_log="./a2c_log4", gamma=0.99)
model.learn(total_timesteps=1000000)
model.save("three_agent_a2c_test_1")
del model, A2C, make_vec_env
# Out:
# Using cuda device
# Logging to ./a2c_log4\A2C_2
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 161       |
# |    ep_rew_mean        | -1.04e+05 |
# | time/                 |           |
# |    fps                | 661       |
# |    iterations         | 100       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -4.81     |
# |    explained_variance | -0.00716  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -412      |
# |    value_loss         | 9.14e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 220       |
# |    ep_rew_mean        | -1.05e+05 |
# | time/                 |           |
# |    fps                | 651       |
# |    iterations         | 200       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -4.81     |
# |    explained_variance | 0.00333   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -365      |
# |    value_loss         | 7.25e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 571       |
# |    ep_rew_mean        | -9.23e+04 |
# | time/                 |           |
# |    fps                | 624       |
# |    iterations         | 300       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -4.79     |
# |    explained_variance | 0.00016   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -278      |
# |    value_loss         | 4.84e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 589       |
# |    ep_rew_mean        | -9.49e+04 |
# | time/                 |           |
# |    fps                | 619       |
# |    iterations         | 400       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -4.78     |
# |    explained_variance | 0.000112  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -439      |
# |    value_loss         | 1.05e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 594       |
# |    ep_rew_mean        | -8.43e+04 |
# | time/                 |           |
# |    fps                | 615       |
# |    iterations         | 500       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -4.78     |
# |    explained_variance | 5.53e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -417      |
# |    value_loss         | 9.03e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 541       |
# |    ep_rew_mean        | -8.86e+04 |
# | time/                 |           |
# |    fps                | 610       |
# |    iterations         | 600       |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -4.79     |
# |    explained_variance | -2.9e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -351      |
# |    value_loss         | 6.94e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 626       |
# |    ep_rew_mean        | -8.67e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 700       |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -4.8      |
# |    explained_variance | 2.49e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -389      |
# |    value_loss         | 8.16e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 693       |
# |    ep_rew_mean        | -8.48e+04 |
# | time/                 |           |
# |    fps                | 596       |
# |    iterations         | 800       |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -4.77     |
# |    explained_variance | 4.36e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -355      |
# |    value_loss         | 7.06e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -7.88e+04 |
# | time/                 |           |
# |    fps                | 595       |
# |    iterations         | 900       |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -4.74     |
# |    explained_variance | -2.26e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -370      |
# |    value_loss         | 7.38e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 684       |
# |    ep_rew_mean        | -8.18e+04 |
# | time/                 |           |
# |    fps                | 592       |
# |    iterations         | 1000      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -4.78     |
# |    explained_variance | 2.8e-06   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -331      |
# |    value_loss         | 6.27e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 724       |
# |    ep_rew_mean        | -8.56e+04 |
# | time/                 |           |
# |    fps                | 589       |
# |    iterations         | 1100      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -4.75     |
# |    explained_variance | -2.5e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -390      |
# |    value_loss         | 8.2e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 689       |
# |    ep_rew_mean        | -8.35e+04 |
# | time/                 |           |
# |    fps                | 588       |
# |    iterations         | 1200      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -4.74     |
# |    explained_variance | -2.03e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -356      |
# |    value_loss         | 7.38e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 670       |
# |    ep_rew_mean        | -8.22e+04 |
# | time/                 |           |
# |    fps                | 586       |
# |    iterations         | 1300      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -4.76     |
# |    explained_variance | -1.42e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -344      |
# |    value_loss         | 6.98e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 642       |
# |    ep_rew_mean        | -8.08e+04 |
# | time/                 |           |
# |    fps                | 584       |
# |    iterations         | 1400      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -4.75     |
# |    explained_variance | -5.96e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -298      |
# |    value_loss         | 5.2e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 610       |
# |    ep_rew_mean        | -8.37e+04 |
# | time/                 |           |
# |    fps                | 582       |
# |    iterations         | 1500      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -4.71     |
# |    explained_variance | 1.07e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -369      |
# |    value_loss         | 7.67e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 582       |
# |    ep_rew_mean        | -8.6e+04  |
# | time/                 |           |
# |    fps                | 581       |
# |    iterations         | 1600      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -4.73     |
# |    explained_variance | -8.34e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -344      |
# |    value_loss         | 6.62e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 591       |
# |    ep_rew_mean        | -8.42e+04 |
# | time/                 |           |
# |    fps                | 580       |
# |    iterations         | 1700      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -4.77     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -271      |
# |    value_loss         | 3.75e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 599       |
# |    ep_rew_mean        | -8.14e+04 |
# | time/                 |           |
# |    fps                | 578       |
# |    iterations         | 1800      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -4.77     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -400      |
# |    value_loss         | 8.34e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 592       |
# |    ep_rew_mean        | -8.12e+04 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 1900      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -4.69     |
# |    explained_variance | -9.54e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -317      |
# |    value_loss         | 6.03e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 586       |
# |    ep_rew_mean        | -8.35e+04 |
# | time/                 |           |
# |    fps                | 576       |
# |    iterations         | 2000      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -4.75     |
# |    explained_variance | -2.38e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -281      |
# |    value_loss         | 5.32e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 565       |
# |    ep_rew_mean        | -8.55e+04 |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 2100      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -4.64     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -350      |
# |    value_loss         | 7.19e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 561       |
# |    ep_rew_mean        | -8.66e+04 |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 2200      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -4.79     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -316      |
# |    value_loss         | 6.05e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 559       |
# |    ep_rew_mean        | -8.73e+04 |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 2300      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -4.72     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -405      |
# |    value_loss         | 8.8e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 556       |
# |    ep_rew_mean        | -8.64e+04 |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 2400      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -4.62     |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -246      |
# |    value_loss         | 4.71e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 558       |
# |    ep_rew_mean        | -8.66e+04 |
# | time/                 |           |
# |    fps                | 576       |
# |    iterations         | 2500      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -4.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -369      |
# |    value_loss         | 7.69e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 551       |
# |    ep_rew_mean        | -8.73e+04 |
# | time/                 |           |
# |    fps                | 578       |
# |    iterations         | 2600      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 52000     |
# | train/                |           |
# |    entropy_loss       | -4.76     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -373      |
# |    value_loss         | 7.43e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 563       |
# |    ep_rew_mean        | -8.88e+04 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 2700      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 54000     |
# | train/                |           |
# |    entropy_loss       | -4.64     |
# |    explained_variance | -8.34e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -219      |
# |    value_loss         | 5.81e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 556       |
# |    ep_rew_mean        | -8.73e+04 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 2800      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 56000     |
# | train/                |           |
# |    entropy_loss       | -4.65     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 2.12e+04  |
# |    value_loss         | 5.02e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 565       |
# |    ep_rew_mean        | -8.81e+04 |
# | time/                 |           |
# |    fps                | 576       |
# |    iterations         | 2900      |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 58000     |
# | train/                |           |
# |    entropy_loss       | -4.67     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -298      |
# |    value_loss         | 5.1e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 573       |
# |    ep_rew_mean        | -8.46e+04 |
# | time/                 |           |
# |    fps                | 575       |
# |    iterations         | 3000      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 60000     |
# | train/                |           |
# |    entropy_loss       | -4.56     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -381      |
# |    value_loss         | 9.61e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 562       |
# |    ep_rew_mean        | -8.63e+04 |
# | time/                 |           |
# |    fps                | 575       |
# |    iterations         | 3100      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 62000     |
# | train/                |           |
# |    entropy_loss       | -4.65     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -272      |
# |    value_loss         | 4.86e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 549       |
# |    ep_rew_mean        | -8.39e+04 |
# | time/                 |           |
# |    fps                | 575       |
# |    iterations         | 3200      |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 64000     |
# | train/                |           |
# |    entropy_loss       | -4.61     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -259      |
# |    value_loss         | 5.82e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 550       |
# |    ep_rew_mean        | -8.2e+04  |
# | time/                 |           |
# |    fps                | 575       |
# |    iterations         | 3300      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 66000     |
# | train/                |           |
# |    entropy_loss       | -4.59     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -334      |
# |    value_loss         | 7.71e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 528       |
# |    ep_rew_mean        | -8.34e+04 |
# | time/                 |           |
# |    fps                | 575       |
# |    iterations         | 3400      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 68000     |
# | train/                |           |
# |    entropy_loss       | -4.48     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -341      |
# |    value_loss         | 6.96e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 510       |
# |    ep_rew_mean        | -8.49e+04 |
# | time/                 |           |
# |    fps                | 575       |
# |    iterations         | 3500      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 70000     |
# | train/                |           |
# |    entropy_loss       | -4.64     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -340      |
# |    value_loss         | 7.28e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 481       |
# |    ep_rew_mean        | -8.62e+04 |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 3600      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 72000     |
# | train/                |           |
# |    entropy_loss       | -4.41     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -402      |
# |    value_loss         | 8.89e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 482       |
# |    ep_rew_mean        | -8.83e+04 |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 3700      |
# |    time_elapsed       | 128       |
# |    total_timesteps    | 74000     |
# | train/                |           |
# |    entropy_loss       | -4.6      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -360      |
# |    value_loss         | 7.83e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 486       |
# |    ep_rew_mean        | -8.85e+04 |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 3800      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 76000     |
# | train/                |           |
# |    entropy_loss       | -4.62     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -306      |
# |    value_loss         | 6.39e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 489       |
# |    ep_rew_mean        | -9.06e+04 |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 3900      |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 78000     |
# | train/                |           |
# |    entropy_loss       | -4.6      |
# |    explained_variance | -2.26e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -374      |
# |    value_loss         | 7.78e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 489       |
# |    ep_rew_mean        | -9.07e+04 |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 4000      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 80000     |
# | train/                |           |
# |    entropy_loss       | -4.78     |
# |    explained_variance | -8.34e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -384      |
# |    value_loss         | 8.07e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 501       |
# |    ep_rew_mean        | -9.1e+04  |
# | time/                 |           |
# |    fps                | 572       |
# |    iterations         | 4100      |
# |    time_elapsed       | 143       |
# |    total_timesteps    | 82000     |
# | train/                |           |
# |    entropy_loss       | -4.69     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -396      |
# |    value_loss         | 8.57e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 508       |
# |    ep_rew_mean        | -9.12e+04 |
# | time/                 |           |
# |    fps                | 572       |
# |    iterations         | 4200      |
# |    time_elapsed       | 146       |
# |    total_timesteps    | 84000     |
# | train/                |           |
# |    entropy_loss       | -4.73     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -346      |
# |    value_loss         | 6.5e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 502       |
# |    ep_rew_mean        | -9.22e+04 |
# | time/                 |           |
# |    fps                | 572       |
# |    iterations         | 4300      |
# |    time_elapsed       | 150       |
# |    total_timesteps    | 86000     |
# | train/                |           |
# |    entropy_loss       | -4.7      |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -343      |
# |    value_loss         | 6.66e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 505       |
# |    ep_rew_mean        | -9.23e+04 |
# | time/                 |           |
# |    fps                | 571       |
# |    iterations         | 4400      |
# |    time_elapsed       | 153       |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -4.74     |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -332      |
# |    value_loss         | 6.44e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 498       |
# |    ep_rew_mean        | -9.21e+04 |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 4500      |
# |    time_elapsed       | 156       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -4.72     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -420      |
# |    value_loss         | 1e+04     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 498       |
# |    ep_rew_mean        | -9.21e+04 |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 4600      |
# |    time_elapsed       | 160       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -4.75     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -350      |
# |    value_loss         | 7.16e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 514       |
# |    ep_rew_mean        | -9.06e+04 |
# | time/                 |           |
# |    fps                | 576       |
# |    iterations         | 4700      |
# |    time_elapsed       | 163       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -4.59     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -350      |
# |    value_loss         | 6.99e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 514       |
# |    ep_rew_mean        | -9.05e+04 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 4800      |
# |    time_elapsed       | 166       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -4.7      |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -421      |
# |    value_loss         | 9.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 540       |
# |    ep_rew_mean        | -9.04e+04 |
# | time/                 |           |
# |    fps                | 576       |
# |    iterations         | 4900      |
# |    time_elapsed       | 169       |
# |    total_timesteps    | 98000     |
# | train/                |           |
# |    entropy_loss       | -4.32     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -332      |
# |    value_loss         | 6.87e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 532       |
# |    ep_rew_mean        | -9.23e+04 |
# | time/                 |           |
# |    fps                | 576       |
# |    iterations         | 5000      |
# |    time_elapsed       | 173       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -4.68     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -331      |
# |    value_loss         | 6.68e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 532       |
# |    ep_rew_mean        | -9.23e+04 |
# | time/                 |           |
# |    fps                | 576       |
# |    iterations         | 5100      |
# |    time_elapsed       | 176       |
# |    total_timesteps    | 102000    |
# | train/                |           |
# |    entropy_loss       | -4.24     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -376      |
# |    value_loss         | 1.47e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 552       |
# |    ep_rew_mean        | -9.09e+04 |
# | time/                 |           |
# |    fps                | 575       |
# |    iterations         | 5200      |
# |    time_elapsed       | 180       |
# |    total_timesteps    | 104000    |
# | train/                |           |
# |    entropy_loss       | -4.47     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -365      |
# |    value_loss         | 1.04e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 543       |
# |    ep_rew_mean        | -9.16e+04 |
# | time/                 |           |
# |    fps                | 576       |
# |    iterations         | 5300      |
# |    time_elapsed       | 183       |
# |    total_timesteps    | 106000    |
# | train/                |           |
# |    entropy_loss       | -4.74     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -342      |
# |    value_loss         | 6.73e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 527       |
# |    ep_rew_mean        | -9.13e+04 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 5400      |
# |    time_elapsed       | 187       |
# |    total_timesteps    | 108000    |
# | train/                |           |
# |    entropy_loss       | -4.75     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -403      |
# |    value_loss         | 9.03e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 523       |
# |    ep_rew_mean        | -9.33e+04 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 5500      |
# |    time_elapsed       | 190       |
# |    total_timesteps    | 110000    |
# | train/                |           |
# |    entropy_loss       | -4.73     |
# |    explained_variance | 3.58e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -337      |
# |    value_loss         | 6.78e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 518       |
# |    ep_rew_mean        | -9.71e+04 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 5600      |
# |    time_elapsed       | 193       |
# |    total_timesteps    | 112000    |
# | train/                |           |
# |    entropy_loss       | -4.73     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -355      |
# |    value_loss         | 6.62e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 508       |
# |    ep_rew_mean        | -1.01e+05 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 5700      |
# |    time_elapsed       | 197       |
# |    total_timesteps    | 114000    |
# | train/                |           |
# |    entropy_loss       | -4.37     |
# |    explained_variance | -5.96e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -228      |
# |    value_loss         | 4.15e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 503       |
# |    ep_rew_mean        | -1.03e+05 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 5800      |
# |    time_elapsed       | 200       |
# |    total_timesteps    | 116000    |
# | train/                |           |
# |    entropy_loss       | -4.56     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -398      |
# |    value_loss         | 9.48e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 482       |
# |    ep_rew_mean        | -1.03e+05 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 5900      |
# |    time_elapsed       | 204       |
# |    total_timesteps    | 118000    |
# | train/                |           |
# |    entropy_loss       | -4.2      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -304      |
# |    value_loss         | 7.75e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 478       |
# |    ep_rew_mean        | -1.03e+05 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 6000      |
# |    time_elapsed       | 207       |
# |    total_timesteps    | 120000    |
# | train/                |           |
# |    entropy_loss       | -4.66     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -338      |
# |    value_loss         | 7.04e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 467      |
# |    ep_rew_mean        | -1e+05   |
# | time/                 |          |
# |    fps                | 577      |
# |    iterations         | 6100     |
# |    time_elapsed       | 211      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -4.39    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -283     |
# |    value_loss         | 5.08e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 452      |
# |    ep_rew_mean        | -1e+05   |
# | time/                 |          |
# |    fps                | 577      |
# |    iterations         | 6200     |
# |    time_elapsed       | 214      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -4.58    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -438     |
# |    value_loss         | 1.17e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 457      |
# |    ep_rew_mean        | -1e+05   |
# | time/                 |          |
# |    fps                | 578      |
# |    iterations         | 6300     |
# |    time_elapsed       | 217      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -4.58    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -345     |
# |    value_loss         | 6.42e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 423       |
# |    ep_rew_mean        | -1.02e+05 |
# | time/                 |           |
# |    fps                | 578       |
# |    iterations         | 6400      |
# |    time_elapsed       | 221       |
# |    total_timesteps    | 128000    |
# | train/                |           |
# |    entropy_loss       | -4.52     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -261      |
# |    value_loss         | 4.61e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 431       |
# |    ep_rew_mean        | -1.02e+05 |
# | time/                 |           |
# |    fps                | 580       |
# |    iterations         | 6500      |
# |    time_elapsed       | 224       |
# |    total_timesteps    | 130000    |
# | train/                |           |
# |    entropy_loss       | -4.58     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -343      |
# |    value_loss         | 6.56e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 429       |
# |    ep_rew_mean        | -1.02e+05 |
# | time/                 |           |
# |    fps                | 580       |
# |    iterations         | 6600      |
# |    time_elapsed       | 227       |
# |    total_timesteps    | 132000    |
# | train/                |           |
# |    entropy_loss       | -4.26     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -333      |
# |    value_loss         | 7.72e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 421       |
# |    ep_rew_mean        | -1.04e+05 |
# | time/                 |           |
# |    fps                | 580       |
# |    iterations         | 6700      |
# |    time_elapsed       | 230       |
# |    total_timesteps    | 134000    |
# | train/                |           |
# |    entropy_loss       | -4.63     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -278      |
# |    value_loss         | 4.34e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 429       |
# |    ep_rew_mean        | -1.02e+05 |
# | time/                 |           |
# |    fps                | 580       |
# |    iterations         | 6800      |
# |    time_elapsed       | 234       |
# |    total_timesteps    | 136000    |
# | train/                |           |
# |    entropy_loss       | -4.55     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -265      |
# |    value_loss         | 5.99e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 435      |
# |    ep_rew_mean        | -1e+05   |
# | time/                 |          |
# |    fps                | 579      |
# |    iterations         | 6900     |
# |    time_elapsed       | 238      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -4.47    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -288     |
# |    value_loss         | 5.7e+03  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 449       |
# |    ep_rew_mean        | -9.88e+04 |
# | time/                 |           |
# |    fps                | 579       |
# |    iterations         | 7000      |
# |    time_elapsed       | 241       |
# |    total_timesteps    | 140000    |
# | train/                |           |
# |    entropy_loss       | -4.56     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -314      |
# |    value_loss         | 6.31e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 431       |
# |    ep_rew_mean        | -9.72e+04 |
# | time/                 |           |
# |    fps                | 579       |
# |    iterations         | 7100      |
# |    time_elapsed       | 245       |
# |    total_timesteps    | 142000    |
# | train/                |           |
# |    entropy_loss       | -4.49     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -270      |
# |    value_loss         | 6.37e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 436       |
# |    ep_rew_mean        | -9.73e+04 |
# | time/                 |           |
# |    fps                | 578       |
# |    iterations         | 7200      |
# |    time_elapsed       | 248       |
# |    total_timesteps    | 144000    |
# | train/                |           |
# |    entropy_loss       | -4.37     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -289      |
# |    value_loss         | 5.31e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 447       |
# |    ep_rew_mean        | -9.56e+04 |
# | time/                 |           |
# |    fps                | 578       |
# |    iterations         | 7300      |
# |    time_elapsed       | 252       |
# |    total_timesteps    | 146000    |
# | train/                |           |
# |    entropy_loss       | -4.51     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -343      |
# |    value_loss         | 7.2e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 453       |
# |    ep_rew_mean        | -9.57e+04 |
# | time/                 |           |
# |    fps                | 577       |
# |    iterations         | 7400      |
# |    time_elapsed       | 256       |
# |    total_timesteps    | 148000    |
# | train/                |           |
# |    entropy_loss       | -4.29     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -299      |
# |    value_loss         | 6.64e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 454       |
# |    ep_rew_mean        | -9.68e+04 |
# | time/                 |           |
# ...
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 47600     |
# |    time_elapsed       | 1658      |
# |    total_timesteps    | 952000    |
# | train/                |           |
# |    entropy_loss       | -0.000266 |
# |    explained_variance | 0.00154   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47599     |
# |    policy_loss        | 0.0236    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 47700     |
# |    time_elapsed       | 1661      |
# |    total_timesteps    | 954000    |
# | train/                |           |
# |    entropy_loss       | -0.000258 |
# |    explained_variance | 0.00266   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47699     |
# |    policy_loss        | 0.0229    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 47800     |
# |    time_elapsed       | 1665      |
# |    total_timesteps    | 956000    |
# | train/                |           |
# |    entropy_loss       | -0.000156 |
# |    explained_variance | 0.827     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47799     |
# |    policy_loss        | 1.81e-05  |
# |    value_loss         | 905       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 47900     |
# |    time_elapsed       | 1668      |
# |    total_timesteps    | 958000    |
# | train/                |           |
# |    entropy_loss       | -0.000265 |
# |    explained_variance | 0.00155   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47899     |
# |    policy_loss        | 0.0236    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 48000     |
# |    time_elapsed       | 1672      |
# |    total_timesteps    | 960000    |
# | train/                |           |
# |    entropy_loss       | -0.000255 |
# |    explained_variance | 0.00267   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47999     |
# |    policy_loss        | 0.0229    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 48100     |
# |    time_elapsed       | 1675      |
# |    total_timesteps    | 962000    |
# | train/                |           |
# |    entropy_loss       | -0.000155 |
# |    explained_variance | 0.829     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48099     |
# |    policy_loss        | 2.11e-05  |
# |    value_loss         | 901       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 574       |
# |    iterations         | 48200     |
# |    time_elapsed       | 1679      |
# |    total_timesteps    | 964000    |
# | train/                |           |
# |    entropy_loss       | -0.000263 |
# |    explained_variance | 0.00156   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48199     |
# |    policy_loss        | 0.019     |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 48300     |
# |    time_elapsed       | 1682      |
# |    total_timesteps    | 966000    |
# | train/                |           |
# |    entropy_loss       | -0.000252 |
# |    explained_variance | 0.00268   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48299     |
# |    policy_loss        | 0.0183    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 48400     |
# |    time_elapsed       | 1686      |
# |    total_timesteps    | 968000    |
# | train/                |           |
# |    entropy_loss       | -0.000154 |
# |    explained_variance | 0.83      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48399     |
# |    policy_loss        | 2.07e-05  |
# |    value_loss         | 897       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 48500     |
# |    time_elapsed       | 1689      |
# |    total_timesteps    | 970000    |
# | train/                |           |
# |    entropy_loss       | -0.000262 |
# |    explained_variance | 0.00156   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48499     |
# |    policy_loss        | 0.0144    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 48600     |
# |    time_elapsed       | 1693      |
# |    total_timesteps    | 972000    |
# | train/                |           |
# |    entropy_loss       | -0.000249 |
# |    explained_variance | 0.0027    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48599     |
# |    policy_loss        | 0.0137    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 48700     |
# |    time_elapsed       | 1697      |
# |    total_timesteps    | 974000    |
# | train/                |           |
# |    entropy_loss       | -0.000154 |
# |    explained_variance | 0.831     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48699     |
# |    policy_loss        | 2.14e-05  |
# |    value_loss         | 893       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1e+05    |
# | time/                 |          |
# |    fps                | 573      |
# |    iterations         | 48800    |
# |    time_elapsed       | 1700     |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | -0.00026 |
# |    explained_variance | 0.00157  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | 0.0144   |
# |    value_loss         | 1.87e+09 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 48900     |
# |    time_elapsed       | 1704      |
# |    total_timesteps    | 978000    |
# | train/                |           |
# |    entropy_loss       | -0.000247 |
# |    explained_variance | 0.00271   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48899     |
# |    policy_loss        | 0.0137    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 49000     |
# |    time_elapsed       | 1707      |
# |    total_timesteps    | 980000    |
# | train/                |           |
# |    entropy_loss       | -0.000153 |
# |    explained_variance | 0.833     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48999     |
# |    policy_loss        | 2.09e-05  |
# |    value_loss         | 890       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 49100     |
# |    time_elapsed       | 1711      |
# |    total_timesteps    | 982000    |
# | train/                |           |
# |    entropy_loss       | -0.000259 |
# |    explained_variance | 0.00158   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49099     |
# |    policy_loss        | 0.0143    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 49200     |
# |    time_elapsed       | 1714      |
# |    total_timesteps    | 984000    |
# | train/                |           |
# |    entropy_loss       | -0.000245 |
# |    explained_variance | 0.00273   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49199     |
# |    policy_loss        | 0.0137    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1e+05    |
# | time/                 |          |
# |    fps                | 573      |
# |    iterations         | 49300    |
# |    time_elapsed       | 1718     |
# |    total_timesteps    | 986000   |
# | train/                |          |
# |    entropy_loss       | -0.00015 |
# |    explained_variance | 0.834    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | 1.97e-05 |
# |    value_loss         | 886      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 49400     |
# |    time_elapsed       | 1721      |
# |    total_timesteps    | 988000    |
# | train/                |           |
# |    entropy_loss       | -0.000331 |
# |    explained_variance | 0.00159   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49399     |
# |    policy_loss        | 0.0147    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 49500     |
# |    time_elapsed       | 1725      |
# |    total_timesteps    | 990000    |
# | train/                |           |
# |    entropy_loss       | -0.000238 |
# |    explained_variance | 0.00274   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49499     |
# |    policy_loss        | 0.0137    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1e+05    |
# | time/                 |          |
# |    fps                | 573      |
# |    iterations         | 49600    |
# |    time_elapsed       | 1728     |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | -0.00015 |
# |    explained_variance | 0.835    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49599    |
# |    policy_loss        | 1.89e-05 |
# |    value_loss         | 883      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 49700     |
# |    time_elapsed       | 1732      |
# |    total_timesteps    | 994000    |
# | train/                |           |
# |    entropy_loss       | -0.000329 |
# |    explained_variance | 0.00159   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49699     |
# |    policy_loss        | 0.0147    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 49800     |
# |    time_elapsed       | 1735      |
# |    total_timesteps    | 996000    |
# | train/                |           |
# |    entropy_loss       | -0.000235 |
# |    explained_variance | 0.00275   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49799     |
# |    policy_loss        | 0.0137    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 49900     |
# |    time_elapsed       | 1739      |
# |    total_timesteps    | 998000    |
# | train/                |           |
# |    entropy_loss       | -0.000149 |
# |    explained_variance | 0.836     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49899     |
# |    policy_loss        | 1.84e-05  |
# |    value_loss         | 880       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1e+05     |
# | time/                 |           |
# |    fps                | 573       |
# |    iterations         | 50000     |
# |    time_elapsed       | 1742      |
# |    total_timesteps    | 1000000   |
# | train/                |           |
# |    entropy_loss       | -0.000327 |
# |    explained_variance | 0.0016    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49999     |
# |    policy_loss        | 0.0146    |
# |    value_loss         | 1.87e+09  |
# -------------------------------------

# %% [markdown]
# # Training using Advantage Actor-Critic (A2C)

# %%
# from stable_baselines3 import A2C
# from stable_baselines3.common.env_util import make_vec_env

# # Training cell
# vec_env = make_vec_env('ThreeAgentGridworld-v0', n_envs=4)

# model = A2C("MlpPolicy", vec_env, verbose=1, tensorboard_log="./a2c_log2", gamma=0.9)
# model.learn(total_timesteps=300000)
# model.save("three_agent_a2c4")
# del model, A2C, make_vec_env

# %% [markdown]
# # Inference

# %%
# Load trained network
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

model = A2C.load("three_agent_a2c_test_1")

# %% [markdown]
# Playing using trained network and default env:

# %%
import pygame
import gymnasium as gym
# Make the environment
env = gym.make('ThreeAgentGridworld-v0', render_mode='human')
env.metadata['render_fps'] = 30
obs, info = env.reset()
# env.render()
# Start playing
terminated, truncated = False, False
total_rewards = 0
while True:
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated,  info = env.step(list(action))
    env.render()
    total_rewards += reward
    print(f"Obs: {obs}, Reward: {reward}, terminated: {terminated}, total_rewards: {total_rewards}")
    if terminated or truncated:
        print('terminated:', terminated, 'truncated:', truncated)
        break
    pygame.event.get()
# Out:
# Obs: [ 29 694 134   0], Reward: -3, terminated: False, total_rewards: -3
# Obs: [ 90 680 198   0], Reward: -3, terminated: False, total_rewards: -6
# Obs: [419 344 270   0], Reward: -3, terminated: False, total_rewards: -9
# Obs: [483 613 592   0], Reward: -3, terminated: False, total_rewards: -12
# Obs: [812 280 664   2], Reward: 97, terminated: False, total_rewards: 85
# Obs: [ 62  58 162   2], Reward: -3, terminated: False, total_rewards: 82
# Obs: [380 800 231   2], Reward: -3, terminated: False, total_rewards: 79
# Obs: [452 240 305   2], Reward: -3, terminated: False, total_rewards: 76
# Obs: [513 737 624   2], Reward: -3, terminated: False, total_rewards: 73
# Obs: [ 26 404 699   2], Reward: -3, terminated: False, total_rewards: 70
# Obs: [ 89 158 195   2], Reward: -3, terminated: False, total_rewards: 67
# Obs: [416 494 267   2], Reward: -3, terminated: False, total_rewards: 64
# Obs: [481 152 590   2], Reward: -3, terminated: False, total_rewards: 61
# Obs: [809 221 661   2], Reward: -3, terminated: False, total_rewards: 58
# Obs: [ 59 547 736   2], Reward: -3, terminated: False, total_rewards: 55
# Obs: [117 615 228   2], Reward: -3, terminated: False, total_rewards: 52
# Obs: [449 324 302   2], Reward: -3, terminated: False, total_rewards: 49
# Obs: [512   1 622  18], Reward: 97, terminated: False, total_rewards: 146
# Obs: [ 23 534 696  18], Reward: -3, terminated: False, total_rewards: 143
# Obs: [ 87  49 194  19], Reward: 97, terminated: False, total_rewards: 240
# Obs: [413 566 264  19], Reward: -3, terminated: False, total_rewards: 237
# Obs: [479 230 337  19], Reward: -3, terminated: False, total_rewards: 234
# Obs: [540 510 658  19], Reward: -3, terminated: False, total_rewards: 231
# Obs: [ 63  21 733  19], Reward: -3, terminated: False, total_rewards: 228
# Obs: [383  86 226  27], Reward: 97, terminated: False, total_rewards: 325
# Obs: [456 411 298  27], Reward: -3, terminated: False, total_rewards: 322
# Obs: [776 477 368  27], Reward: -3, terminated: False, total_rewards: 319
# Obs: [ 30 805 692  27], Reward: -3, terminated: False, total_rewards: 316
# Obs: [ 30  54 764  27], Reward: -13, terminated: False, total_rewards: 303
# Obs: [ 30 112 261  31], Reward: 100078, terminated: True, total_rewards: 100381
# terminated: True truncated: False

# %%
env.close()

# %% [markdown]
# Play using vector envs:

# %%
vec_env = make_vec_env('ThreeAgentGridworld-v0', n_envs=1)
obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    print(f"Obs: {obs}, Reward: {rewards}, dones: {dones}, info: {info}")
    if dones.any():
        print('dones:', dones)
        print('rewards:', rewards)
        break
    vec_env.render("human")
# Out:
# Observation points: [[15. 21.]
#  [26. 21.]
#  [38. 23.]
#  ...
#  [22. 42.]
#  [15. 12.]
#  [18.  8.]]
# Obs: [[803  96 697   0]], Reward: [0.], dones: [ True], info: [{'agent1': array([39., 25.]), 'agent2': array([25.,  4.]), 'agent3': array([21., 28.]), 'step_count': 1, 'episode': {'r': 0.0, 'l': 1, 't': 0.007}, 'TimeLimit.truncated': False, 'terminal_observation': array([694, 469, 557,   0])}]
# dones: [ True]
# rewards: [0.]

# %% [markdown]
# Not good, training again

# %%
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

# Training cell
vec_env = make_vec_env('ThreeAgentGridworld-v0', n_envs=8)

model = A2C("MlpPolicy", vec_env, verbose=1, tensorboard_log="./a2c_log", gamma=0.95)
model.learn(total_timesteps=200000)
model.save("three_agent_a2c3")
del model, A2C, make_vec_env
