# %% [markdown]
# *************** Spraying length incorrect ***********

# %% [markdown]
# # Muti-agent reinforcement learning for Precision Agriculture

# %%
# Import libraries
import matplotlib.pyplot as plt
from shapely import Polygon
from shapely.geometry import Point
from scipy.spatial import ConvexHull
import numpy as np
plt.rcParams["figure.figsize"] = (5,5)
np.random.seed(33)

# Take random x,y values
x = [int(np.random.random()*100/2) for i in range(5)]
y = [int(np.random.random()*100/2) for i in range(5)]
# Make polygon using the values
vertices = list(set(zip(x,y))) # Take unique x,y combinations
Poly1 = Polygon(vertices) # The first polygon (maybe non-convex)
print("Vertices:", vertices)
print("Vertices from polygon object:", Poly1.exterior.xy)
Poly1.exterior
# Out:
# Vertices: [(43, 24), (12, 9), (22, 0), (20, 47), (13, 34)]
# Vertices from polygon object: (array('d', [43.0, 12.0, 22.0, 20.0, 13.0, 43.0]), array('d', [24.0, 9.0, 0.0, 47.0, 34.0, 24.0]))
# <LINEARRING (43 24, 12 9, 22 0, 20 47, 13 34, 43 24)>

# %%
# Take the convex hull
hull = ConvexHull(vertices)
hull_points = [vertices[i] for i in hull.vertices]
inner_points = [point for i, point in enumerate(vertices) if i not in hull.vertices]
conv_vertices = hull_points + inner_points
Poly2 = Polygon(conv_vertices)
print('vertices of convex polygon:', conv_vertices)
print('vertices from convex polygon object:', Poly2.exterior.xy)
Poly2.exterior
# Out:
# vertices of convex polygon: [(43, 24), (20, 47), (13, 34), (12, 9), (22, 0)]
# vertices from convex polygon object: (array('d', [43.0, 20.0, 13.0, 12.0, 22.0, 43.0]), array('d', [24.0, 47.0, 34.0, 9.0, 0.0, 24.0]))
# <LINEARRING (43 24, 20 47, 13 34, 12 9, 22 0, 43 24)>

# %%
# Polygon exterior points
xp,yp = Poly2.exterior.xy

# Gridpoints
xs = np.arange(0, 90, 1)
ys = np.arange(0, 90, 1)

# Inside points
xps, yps = [], []
for xi in xs:
    for yi in ys:
        p = Point(xi,yi)
        if Poly2.contains(p):
            xps += [p.x]
            yps += [p.y]
xps += xp
yps += yp

plt.plot(xp,yp) # Plot the vertices
plt.scatter(xps,yps, color='r') # Plot the inside points

# Take buffer of distance 2 and plot it
buff = Poly2.buffer(distance=2)
print('Buffer vertices:', buff.exterior.xy)
x1,y1 = buff.exterior.xy
plt.plot(x1,y1, color='orange') # Plot the buffer

plt.show()
# Out:
# Buffer vertices: (array('d', [44.505153389413756, 23.505153389413756, 23.367541098854634, 23.216523275503103, 23.05358029489221, 22.880309430750476, 22.69840919747952, 22.509662700204384, 22.315920155610172, 22.119080754907316, 21.921074046716445, 21.723841022370106, 21.529315089045483, 21.339403117241996, 21.155966748388792, 20.980804145817153, 20.81563236798678, 20.6620705367551, 10.6620705367551, 10.52364307351378, 10.399253805864424, 10.290085510707032, 10.19717623368786, 10.121409418762571, 10.063505507816336, 10.024015090217361, 10.003313667442502, 10.001598082556422, 11.001598082556422, 11.017076756107226, 11.048890004907665, 11.096775763389614, 11.160339566700372, 11.23905780015565, 18.23905780015565, 18.34029684315675, 18.4574672493014, 18.589444308859253, 18.734961184170967, 18.892621069925575, 19.06091060098741, 19.23821437907181, 19.422830478829216, 19.612986784495877, 19.806858000296998, 20.00258317132068, 20.19828354668124, 20.392080613504636, 20.582114128629325, 20.766559974937493, 20.943647670915173, 21.111677365368347, 21.269036154164016, 21.414213562373096, 44.41421356237309, 44.54869094185812, 44.66760702815008, 44.769766948835034, 44.85414419795534, 44.91989095037243, 44.96634658073929, 44.99304430148389, 44.99971585310469, 44.98629419965022, 44.95291420229832, 44.89991126426698, 44.82781796067273, 44.73735868719978, 44.62944238135045, 44.505153389413756]), array('d', [22.682990784262962, -1.317009215737036, -1.4593941698333115, -1.587473187225283, -1.6999907535674543, -1.7958438980411897, -1.8740930053964797, -1.9339710266755228, -1.974890998328577, -1.9964517960147958, -1.9984420666855174, -1.9808423004051614, -1.943825021600385, -1.88775309786275, -1.8131761828831237, -1.7208253283864985, -1.6116058178845722, -1.4865882924943328, 7.513411707505667, 7.65078903591167, 7.800995570500063, 7.962603046415709, 8.134074790977817, 8.313780335398334, 8.500010918376876, 8.690995734153567, 8.884918770522365, 9.079936076697743, 34.07993607669774, 34.26079763961692, 34.43951084975321, 34.614603534954696, 34.78463334759098, 34.94819964607004, 47.94819964607004, 48.11596838269037, 48.273025024507454, 48.41786199687785, 48.54908902082672, 48.665446458228914, 48.76581740297863, 48.84923840208531, 48.91490870378498, 48.96219794389484, 48.99065219663073, 48.999998331805784, 48.99014663658624, 48.96119167663791, 48.913411388397726, 48.84726441118315, 48.76338568474863, 48.66258035454762, 48.54581604320327, 48.41421356237309, 25.414213562373096, 25.2655261224513, 25.10412263796394, 24.93162489598074, 24.749766159004626, 24.56037374909793, 24.36535068689534, 24.166656569995265, 23.96628788286419, 23.766257936100697, 23.568576636629945, 23.375230292098415, 23.188161652394896, 23.00925038884113, 22.840294207197804, 22.682990784262962]))

# %%
# Now print all points inside polygon
all_points = set(zip(xps,yps))
print("All points inside polygon:", all_points)
poly_vertices = conv_vertices # Taking all vertices of polygon
print("Polygon vertices for gymnasium test case:", poly_vertices)
# Out:
# All points inside polygon: {(15.0, 21.0), (26.0, 21.0), (38.0, 23.0), (18.0, 17.0), (15.0, 30.0), (26.0, 30.0), (18.0, 26.0), (26.0, 39.0), (18.0, 35.0), (27.0, 13.0), (29.0, 32.0), (19.0, 9.0), (19.0, 18.0), (21.0, 37.0), (30.0, 18.0), (41.0, 24.0), (33.0, 20.0), (33.0, 29.0), (25.0, 25.0), (25.0, 34.0), (22.0, 10.0), (22.0, 19.0), (34.0, 21.0), (14.0, 15.0), (22.0, 28.0), (34.0, 30.0), (14.0, 24.0), (37.0, 26.0), (22.0, 37.0), (14.0, 33.0), (15.0, 7.0), (26.0, 7.0), (15.0, 16.0), (26.0, 16.0), (18.0, 12.0), (15.0, 25.0), (26.0, 25.0), (18.0, 21.0), (18.0, 30.0), (27.0, 8.0), (29.0, 27.0), (19.0, 4.0), (29.0, 36.0), (30.0, 13.0), (21.0, 32.0), (21.0, 41.0), (33.0, 15.0), (25.0, 11.0), (33.0, 24.0), (25.0, 20.0), (33.0, 33.0), (25.0, 29.0), (22.0, 5.0), (25.0, 38.0), (22.0, 14.0), (34.0, 16.0), (14.0, 10.0), (22.0, 23.0), (34.0, 25.0), (14.0, 19.0), (37.0, 21.0), (22.0, 32.0), (14.0, 28.0), (15.0, 11.0), (26.0, 11.0), (18.0, 7.0), (26.0, 20.0), (17.0, 39.0), (18.0, 16.0), (29.0, 13.0), (29.0, 22.0), (40.0, 22.0), (21.0, 18.0), (29.0, 31.0), (21.0, 27.0), (21.0, 36.0), (21.0, 45.0), (41.0, 23.0), (25.0, 6.0), (33.0, 19.0), (25.0, 15.0), (33.0, 28.0), (25.0, 24.0), (22.0, 0.0), (25.0, 33.0), (22.0, 9.0), (22.0, 18.0), (14.0, 14.0), (22.0, 27.0), (14.0, 23.0), (14.0, 32.0), (36.0, 29.0), (26.0, 6.0), (17.0, 25.0), (28.0, 25.0), (17.0, 34.0), (28.0, 34.0), (18.0, 11.0), (29.0, 17.0), (21.0, 13.0), (29.0, 26.0), (40.0, 26.0), (21.0, 22.0), (29.0, 35.0), (21.0, 31.0), (21.0, 40.0), (33.0, 14.0), (25.0, 10.0), (33.0, 23.0), (25.0, 19.0), (25.0, 28.0), (22.0, 4.0), (22.0, 13.0), (13.0, 32.0), (24.0, 32.0), (14.0, 9.0), (24.0, 41.0), (14.0, 18.0), (16.0, 37.0), (36.0, 24.0), (17.0, 20.0), (28.0, 20.0), (17.0, 29.0), (28.0, 29.0), (17.0, 38.0), (28.0, 38.0), (29.0, 12.0), (21.0, 8.0), (29.0, 21.0), (40.0, 21.0), (21.0, 17.0), (29.0, 30.0), (21.0, 26.0), (21.0, 35.0), (20.0, 39.0), (25.0, 5.0), (33.0, 18.0), (25.0, 14.0), (32.0, 22.0), (32.0, 31.0), (22.0, 8.0), (13.0, 27.0), (24.0, 27.0), (35.0, 27.0), (24.0, 36.0), (16.0, 32.0), (17.0, 6.0), (36.0, 19.0), (17.0, 15.0), (28.0, 15.0), (36.0, 28.0), (17.0, 24.0), (28.0, 24.0), (17.0, 33.0), (28.0, 33.0), (21.0, 3.0), (29.0, 16.0), (21.0, 12.0), (29.0, 25.0), (40.0, 25.0), (21.0, 21.0), (21.0, 30.0), (20.0, 34.0), (31.0, 34.0), (20.0, 43.0), (25.0, 9.0), (23.0, 39.0), (32.0, 17.0), (13.0, 13.0), (24.0, 13.0), (32.0, 26.0), (13.0, 22.0), (24.0, 22.0), (35.0, 22.0), (16.0, 18.0), (13.0, 31.0), (24.0, 31.0), (35.0, 31.0), (16.0, 27.0), (24.0, 40.0), (16.0, 36.0), (17.0, 10.0), (28.0, 10.0), (36.0, 23.0), (17.0, 19.0), (28.0, 19.0), (17.0, 28.0), (28.0, 28.0), (17.0, 37.0), (28.0, 37.0), (29.0, 11.0), (21.0, 7.0), (21.0, 16.0), (39.0, 24.0), (20.0, 20.0), (20.0, 29.0), (31.0, 29.0), (23.0, 25.0), (20.0, 38.0), (23.0, 34.0), (20.0, 47.0), (32.0, 12.0), (23.0, 43.0), (24.0, 8.0), (32.0, 21.0), (13.0, 17.0), (24.0, 17.0), (32.0, 30.0), (16.0, 13.0), (35.0, 17.0), (13.0, 26.0), (24.0, 26.0), (35.0, 26.0), (16.0, 22.0), (24.0, 35.0), (16.0, 31.0), (17.0, 5.0), (36.0, 18.0), (17.0, 14.0), (28.0, 14.0), (17.0, 23.0), (28.0, 23.0), (21.0, 2.0), (27.0, 36.0), (19.0, 32.0), (19.0, 41.0), (20.0, 15.0), (31.0, 15.0), (20.0, 24.0), (31.0, 24.0), (23.0, 20.0), (20.0, 33.0), (31.0, 33.0), (23.0, 29.0), (20.0, 42.0), (23.0, 38.0), (24.0, 3.0), (32.0, 16.0), (13.0, 12.0), (24.0, 12.0), (32.0, 25.0), (16.0, 8.0), (13.0, 21.0), (24.0, 21.0), (35.0, 21.0), (16.0, 17.0), (13.0, 30.0), (24.0, 30.0), (35.0, 30.0), (16.0, 26.0), (16.0, 35.0), (17.0, 9.0), (28.0, 9.0), (28.0, 18.0), (27.0, 22.0), (27.0, 31.0), (19.0, 27.0), (30.0, 27.0), (19.0, 36.0), (30.0, 36.0), (19.0, 45.0), (20.0, 10.0), (39.0, 23.0), (23.0, 6.0), (20.0, 19.0), (31.0, 19.0), (23.0, 15.0), (20.0, 28.0), (31.0, 28.0), (23.0, 24.0), (20.0, 37.0), (23.0, 33.0), (23.0, 42.0), (24.0, 7.0), (32.0, 20.0), (13.0, 16.0), (24.0, 16.0), (35.0, 16.0), (16.0, 12.0), (24.0, 25.0), (35.0, 25.0), (16.0, 21.0), (16.0, 30.0), (38.0, 27.0), (15.0, 34.0), (26.0, 34.0 ...
# Polygon vertices for gymnasium test case: [(43, 24), (20, 47), (13, 34), (12, 9), (22, 0)]

# %% [markdown]
# Some helpful functions:

# %%
import random

# function for random starting points
def random_starting_locations(points, infected_locations):
    points = set([tuple(p) for p in points])
    st_locs = points.difference(infected_locations) # for points - infected_locations
    st_locs = random.choices(np.array(list(st_locs)),k=3)
    return st_locs

infected_locations = {(15,10), (22,13), (25,20), (26,21), (35,25)}
random_starting_locations(all_points, infected_locations)

def binary_list_to_decimal(bin_list):
    bin = ''
    for b in bin_list:
        bin += str(b)
    dec = int(bin,2)
    return dec

blist = [1,1,0,0,1]
x = binary_list_to_decimal(blist)
print(x)
# Out:
# 25

# %% [markdown]
# Make the multi-agent class:

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pygame

class ThreeAgentGridworldEnv(gym.Env):
    metadata = {'render_modes': ['human', 'print', 'rgb_array'], "render_fps": 4}    
    def __init__(self, render_mode=None, grid_size=(50, 50), poly_vertices=poly_vertices):        
        super(ThreeAgentGridworldEnv, self).__init__()        
        self.Poly = Polygon(poly_vertices) # Get the points of the polygon
        self.poly_vertices = poly_vertices # Vertices of polygon
        self.size = grid_size[0]  # The size of the square grid
        self.window_size = 800  # The size of the PyGame window        
        self.grid_size = grid_size # Size of the grid (May need to remove later on)
        self.outer_boundary = self.Poly.buffer(distance=2) # outer boundary with buffer of distance 2

        # Observation points
        self.observation_points = self.obs_points()
        # print('Observation points:', self.observation_points)
        self.observation_length = len(self.observation_points)
        self.observation_map = {tuple(v):i for i,v in enumerate(self.observation_points)}
        # for p in self.observation_points:
        #     print('observation map:', p, self.observation_map[tuple(p)])

        # Keep track of visited states and count steps
        self.step_count = 0
        self.visited = set()
        self.infected_locations = {(15,10), (22,13), (25,20), (26,21), (35,25), (25, 35)}
        self.infected_length = 2**(len(self.infected_locations)) # 2**5, binary to decimal
        self.infected_dict = {v:0 for v in self.infected_locations} # dictionary of locations
        
        # Action and observation space
        self.action_space = spaces.MultiDiscrete([5, 5, 5])  # 4 possible actions for each of the two agents
        # self.observation_positions = spaces.MultiDiscrete([self.observation_length, self.observation_length, self.observation_length])
        # self.infected_space = spaces.MultiBinary(5)
        # self.observation_space = spaces.Tuple((self.observation_positions, self.infected_space))
        self.observation_space = spaces.MultiDiscrete([self.observation_length, self.observation_length, self.observation_length, self.infected_length])
        
        assert render_mode is None or render_mode in self.metadata["render_modes"] # Check if the render mode is correct
        self.render_mode = render_mode
        # If human-rendering is used, `self.window` will be a reference
        # to the window that we draw to. `self.clock` will be a clock that is used
        # to ensure that the environment is rendered at the correct framerate in
        # human-mode. They will remain `None` until human-mode is used for the
        # first time.
        self.window = None
        self.clock = None

        # Reset the environment and start
        self.reset()

    def obs_points(self):
        xp,yp = self.Poly.exterior.xy
        # Gridpoints
        xs = np.arange(0, 90, 1)
        ys = np.arange(0, 90, 1)
        # Inside points
        # print(xs,ys)
        xps, yps = [], []
        for xi in xs:
            for yi in ys:
                p = Point(xi,yi)
                if self.Poly.contains(p):
                    xps += [p.x]
                    yps += [p.y]
        xps += xp
        yps += yp
        # plt.plot(xp,yp)
        # plt.scatter(xps,yps, color='r')
        obs_points = np.array(list(set(zip(xps,yps)))) # Taking unique observation points
        return obs_points
    
    def _get_obs(self):
        a1, a2, a3 = self.agent_positions[0], self.agent_positions[1], self.agent_positions[2]
        info = {'agent1': a1, 'agent2': a2, 'agent3': a3, 'step_count': self.step_count}
        # print('agent positions:', a1, a2, a3)
        p1,p2,p3 = self.observation_map[tuple(a1)], self.observation_map[tuple(a2)], self.observation_map[tuple(a3)]
        infected = binary_list_to_decimal(list(self.infected_dict.values()))
        state = np.array([p1,p2,p3,infected]) # convert the infected binary list to decimal
        return state, info

    def reset(self, seed=None, options={}):
        self.visited = set()
        self.step_count = 0
        self.infected_locations = {(15,10), (22,13), (25,20), (26,21), (35,25), (25, 35)}
        self.infected_dict = {v:0 for v in self.infected_locations} # dictionary of locations
        self.agent_positions = [
            np.array([14, 34]),  # Agent 1 
            # np.array([self.grid_size[0]-1, self.grid_size[1]-1]),  # Agent 2 starts at bottom-right corner,
            # np.array([self.grid_size[0]-3, self.grid_size[1]-3])  # Agent 3 starts at specific position,
            np.array([80/2, 50/2]),  # Agent 2 
            np.array([40/2, 80/2]),  # Agent 3
        ]
        # self.agent_positions = random_starting_locations(self.observation_points, self.infected_locations)
        return self._get_obs()

    def step(self, action):
        # Placeholder for terminal state and rewards
        terminated, truncated = False, False
        rewards = 0
        self.step_count += 1

        # Define the movements corresponding to each action
        movements = [(-1, 0), (1, 0), (0, -1), (0, 1), (0, 0)]  # up, down, left, right, none
        
        # Update the positions of both agents
        for i, act in enumerate(action):
            # if act == 4: # If the action is none
            #     terminated = True # Terminated
            #     break

            movement = movements[act] # What movement to take
            new_position = self.agent_positions[i] + movement # New position after movement
            
            # Ensure the new position is within bounds
            # new_position = np.clip(new_position, [0, 0], [self.grid_size[0]-1, self.grid_size[1]-1])
            new_p = Point(new_position[0], new_position[1])
            # print("checking new position", tuple(new_position))
            if self.Poly.contains(new_p):
                self.agent_positions[i] = new_position
            else:
                rewards -= 10
            if tuple(new_position) in self.visited:
                rewards -= 10
            else:
                rewards -= 1
            self.visited.add(tuple(new_position))
        
        # Check if an infected location is visited
        infected_visited = [x for x in self.agent_positions if tuple(x) in self.infected_locations] # If infected cells are visited
        for v in infected_visited:
            if tuple(v) in self.infected_locations:
                self.infected_locations.remove(tuple(v))
                self.infected_dict[tuple(v)] = 1
        
        if infected_visited:
            rewards += 100 * len(infected_visited) 

        if sum(list(self.infected_dict.values()))==5:
            rewards += 100000
            terminated = True

        
        # If the agents meet at the same position, we can assign a reward or consider it a terminal state
        if np.array_equal(self.agent_positions[0], self.agent_positions[1]) or np.array_equal(self.agent_positions[0], self.agent_positions[2]) or np.array_equal(self.agent_positions[1], self.agent_positions[2]):
            rewards -= 100000  # Infinity reward for meeting at the same position
            terminated = True
        
        obs, info = self._get_obs()
        # rewards = rewards * self.gamma ** self.step_count
        return obs, rewards, terminated, truncated, info

    def render(self):
        if self.render_mode == 'print':
            grid = np.zeros(self.grid_size)
            grid[tuple(self.agent_positions[0])] = 1  # Mark the position of the first agent
            grid[tuple(self.agent_positions[1])] = 2  # Mark the position of the second agent
            print(grid)
        else:
            if self.window is None and self.render_mode == "human": # Initialize pygame if it is not initialized
                pygame.init()
                pygame.display.init()
                self.window = pygame.display.set_mode(
                    (self.window_size, self.window_size)
                )
            if self.clock is None and self.render_mode == "human":
                self.clock = pygame.time.Clock()
            
            # Fill the canvas
            canvas = pygame.Surface((self.window_size, self.window_size))
            canvas.fill((255, 255, 255))
            pix_square_size = (
                self.window_size / self.size
            )  # The size of a single grid square in pixels

            # Draw the polygon
            pixel_poly_vertices = [(point[0] * pix_square_size, point[1] * pix_square_size) for point in self.poly_vertices]
            pygame.draw.polygon(surface=canvas, 
                                color=(255, 255, 0), 
                                points=pixel_poly_vertices)
            
            # Draw the visited regions
            for p in self.visited:
                pygame.draw.rect(
                canvas,
                pygame.Color(100, 100, 100, a=0.5),
                pygame.Rect(
                    pix_square_size * np.array(p),
                    (pix_square_size, pix_square_size),
                ),
                )
            # Draw agent1 (square)
            pygame.draw.rect(
                canvas,
                (255, 0, 0),
                pygame.Rect(
                    pix_square_size * self.agent_positions[0],
                    (pix_square_size, pix_square_size),
                ),
            )
            # Draw agent2 (circle)
            pygame.draw.circle(
                canvas,
                (0, 0, 255),
                (self.agent_positions[1] + 0.5) * pix_square_size,
                pix_square_size / 3,
            )
            # Draw agent3 (circle)
            pygame.draw.circle(
                canvas,
                (0, 255, 0),
                (self.agent_positions[2] + 0.5) * pix_square_size,
                pix_square_size / 3,
            )
            # Draw infected locations
            for l in self.infected_locations:
                pygame.draw.rect(
                    canvas,
                    (0, 255, 255),
                    pygame.Rect(
                        pix_square_size * np.array(l),
                        (pix_square_size, pix_square_size),
                    ),
                )


            if self.render_mode == "human":
                # The following line copies our drawings from `canvas` to the visible window
                self.window.blit(canvas, canvas.get_rect())
                pygame.event.pump()
                pygame.display.update()

                # We need to ensure that human-rendering occurs at the predefined framerate.
                # The following line will automatically add a delay to keep the framerate stable.
                self.clock.tick(self.metadata["render_fps"])
                # Finally
                pygame.event.get()

            elif self.render_mode == 'rgb_array':  # rgb_array
                return np.transpose(
                    np.array(pygame.surfarray.pixels3d(canvas)), axes=(1, 0, 2)
                )
            
    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()

# %% [markdown]
# Register, create the environment and random play:

# %%
# Register the environment
gym.envs.registration.register(
    id='ThreeAgentGridworld-v0',
    entry_point=ThreeAgentGridworldEnv,
    max_episode_steps=2000,
)

# Example of creating and using the environment
env = gym.make('ThreeAgentGridworld-v0',poly_vertices=poly_vertices, render_mode='human')
env.metadata['render_fps'] = 30
obs, info = env.reset()
env.render()

# %% [markdown]
# Random play with keyboard:

# %%
env.reset()
terminated, truncated = False, False
total_rewards = 0
while True:
    act_str = input("Enter 3 actions by comma:")
    action = eval(act_str)
    obs, reward, terminated, truncated,  info = env.step(action)
    env.render()
    total_rewards += reward
    print(f"Obs: {obs}, Reward: {reward}, terminated: {terminated}, total_rewards: {total_rewards}, action: {action}")
    if terminated or truncated:
        print('terminated:', terminated, 'truncated:', truncated)
        break
    pygame.event.get()
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[8], line 6
#     action = eval(act_str)
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Just random play!

# %%
# Random play
env.reset()
terminated, truncated = False, False
total_rewards = 0
while True:
    action = env.action_space.sample()
    print(action)
    obs, reward, terminated, truncated,  info = env.step(action)
    env.render()
    total_rewards += reward
    print(f"Obs: {obs}, Reward: {reward}, terminated: {terminated}, total_rewards: {total_rewards}")
    if terminated or truncated:
        print('terminated:', terminated, 'truncated:', truncated)
        break
    pygame.event.get()
# Out:
# [3 4 1]
# Obs: [455 159 105   0], Reward: -3, terminated: False, total_rewards: -3
# [0 2 4]
# Obs: [455 495 105   0], Reward: -22, terminated: False, total_rewards: -25
# [3 2 1]
# Obs: [455 555 382   0], Reward: -13, terminated: False, total_rewards: -38
# [1 4 1]
# Obs: [786 555 668   0], Reward: -12, terminated: False, total_rewards: -50
# [1 2 3]
# Obs: [250  71 595   0], Reward: -3, terminated: False, total_rewards: -53
# [2 4 3]
# Obs: [574  71 272   0], Reward: -12, terminated: False, total_rewards: -65
# [4 0 1]
# Obs: [574 335 609   0], Reward: -12, terminated: False, total_rewards: -77
# [4 1 3]
# Obs: [574  71 609   0], Reward: -31, terminated: False, total_rewards: -108
# [1 4 1]
# Obs: [ 95  71 609   0], Reward: -22, terminated: False, total_rewards: -130
# [3 2 4]
# Obs: [583 129 609   0], Reward: -12, terminated: False, total_rewards: -142
# [4 0 1]
# Obs: [583 657 609   0], Reward: -31, terminated: False, total_rewards: -173
# [0 0 4]
# Obs: [250 388 609   0], Reward: -21, terminated: False, total_rewards: -194
# [3 1 0]
# Obs: [180 657 272   0], Reward: -21, terminated: False, total_rewards: -215
# [1 1 1]
# Obs: [519 129 609   0], Reward: -21, terminated: False, total_rewards: -236
# [0 3 3]
# Obs: [180  71 609   0], Reward: -40, terminated: False, total_rewards: -276
# [4 0 2]
# Obs: [180 335 116   0], Reward: -21, terminated: False, total_rewards: -297
# [2 3 2]
# Obs: [250 262 179   0], Reward: -12, terminated: False, total_rewards: -309
# [0 1 2]
# Obs: [786 555 511   0], Reward: -21, terminated: False, total_rewards: -330
# [4 2 3]
# Obs: [786  71 179   0], Reward: -30, terminated: False, total_rewards: -360
# [4 4 3]
# Obs: [786  71 116   0], Reward: -30, terminated: False, total_rewards: -390
# [1 2 3]
# Obs: [250 129 609   0], Reward: -30, terminated: False, total_rewards: -420
# [2 3 3]
# Obs: [574  71 609   0], Reward: -40, terminated: False, total_rewards: -460
# [1 0 3]
# Obs: [ 95 335 609   0], Reward: -40, terminated: False, total_rewards: -500
# [3 0 1]
# Obs: [583 315 609   0], Reward: -31, terminated: False, total_rewards: -531
# [0 0 2]
# Obs: [250 810 116   0], Reward: -21, terminated: False, total_rewards: -552
# [0 2 2]
# Obs: [786  60 179   0], Reward: -21, terminated: False, total_rewards: -573
# [2 2 3]
# Obs: [284 378 116   0], Reward: -12, terminated: False, total_rewards: -585
# [2 0 0]
# Obs: [352 647 595   0], Reward: -12, terminated: False, total_rewards: -597
# [3 0 2]
# Obs: [284 568 668   0], Reward: -21, terminated: False, total_rewards: -618
# [0 2 3]
# Obs: [775 638 595   0], Reward: -12, terminated: False, total_rewards: -630
# [1 3 3]
# Obs: [284 568 272   0], Reward: -30, terminated: False, total_rewards: -660
# [0 1 2]
# Obs: [775 647 595   0], Reward: -30, terminated: False, total_rewards: -690
# [2 4 3]
# Obs: [ 29 647 272   0], Reward: -21, terminated: False, total_rewards: -711
# [0 3 2]
# Obs: [606 577 595   0], Reward: -12, terminated: False, total_rewards: -723
# [4 2 1]
# Obs: [606 647 116   0], Reward: -30, terminated: False, total_rewards: -753
# [1 4 4]
# Obs: [ 29 647 116   0], Reward: -30, terminated: False, total_rewards: -783
# [0 1 3]
# Obs: [606 378 609   0], Reward: -30, terminated: False, total_rewards: -813
# [0 1 2]
# Obs: [606 712 116   0], Reward: -22, terminated: False, total_rewards: -835
# [4 1 4]
# Obs: [606 731 116   0], Reward: -21, terminated: False, total_rewards: -856
# [4 3 1]
# Obs: [606 657 410   0], Reward: -21, terminated: False, total_rewards: -877
# [4 3 4]
# Obs: [606 335 410   0], Reward: -30, terminated: False, total_rewards: -907
# [4 2 1]
# Obs: [606 657 410   0], Reward: -31, terminated: False, total_rewards: -938
# [3 2 3]
# Obs: [606 731 410   0], Reward: -41, terminated: False, total_rewards: -979
# [4 1 4]
# Obs: [606 731 410   0], Reward: -31, terminated: False, total_rewards: -1010
# [1 3 2]
# Obs: [ 29 657 476   0], Reward: -21, terminated: False, total_rewards: -1031
# [2 4 2]
# Obs: [ 90 657 804   0], Reward: -12, terminated: False, total_rewards: -1043
# [2 4 0]
# Obs: [419 657 511   0], Reward: -21, terminated: False, total_rewards: -1064
# [2 0 0]
# Obs: [483 388 166   0], Reward: -12, terminated: False, total_rewards: -1076
# [4 0 0]
# Obs: [483  60 454   0], Reward: -21, terminated: False, total_rewards: -1097
# [4 0 0]
# Obs: [483 577 436   0], Reward: -21, terminated: False, total_rewards: -1118
# [4 3 3]
# Obs: [483 514 105   0], Reward: -21, terminated: False, total_rewards: -1139
# [2 1 2]
# Obs: [812 810 436   0], Reward: -21, terminated: False, total_rewards: -1160
# [3 3 4]
# Obs: [483 482 436   0], Reward: -21, terminated: False, total_rewards: -1181
# [3 4 1]
# Obs: [419 482 454   0], Reward: -30, terminated: False, total_rewards: -1211
# [0 0 4]
# Obs: [175 183 454   0], Reward: -12, terminated: False, total_rewards: -1223
# [2 0 3]
# Obs: [246 677 382   0], Reward: -12, terminated: False, total_rewards: -1235
# [3 4 4]
# Obs: [175 677 382   0], Reward: -30, terminated: False, total_rewards: -1265
# [0 4 4]
# Obs: [175 677 382   0], Reward: -31, terminated: False, total_rewards: -1296
# [3 1 1]
# Obs: [113 183 668   0], Reward: -21, terminated: False, total_rewards: -1317
# [1 0 3]
# Obs: [ 90 677 595   0], Reward: -30, terminated: False, total_rewards: -1347
# [2 4 3]
# Obs: [419 677 272   0], Reward: -30, terminated: False, total_rewards: -1377
# [3 1 4]
# Obs: [ 90 183 272   0], Reward: -30, terminated: False, total_rewards: -1407
# [0 3 4]
# Obs: [113 119 272   0], Reward: -21, terminated: False, total_rewards: -1428
# [2 3 0]
# Obs: [175 613 813   0], Reward: -12, terminated: False, total_rewards: -1440
# [0 0 3]
# Obs: [175 280 744   2], Reward: 78, terminated: False, total_rewards: -1362
# [3 4 4]
# Obs: [113 280 744   2], Reward: -30, terminated: False, total_rewards: -1392
# [3 3 0]
# Obs: [606 212 468   2], Reward: -12, terminated: False, total_rewards: -1404
# [1 4 1]
# Obs: [ 29 212 744   2], Reward: -30, terminated: False, total_rewards: -1434
# [3 3 3]
# Obs: [775 143 420   2], Reward: -12, terminated: False, total_rewards: -1446
# [4 0 1]
# Obs: [775 740 420   2], Reward: -22, terminated: False, total_rewards: -1468
# [3 4 3]
# Obs: [455 740 420   2], Reward: -31, terminated: False, total_rewards: -1499
# [3 3 2]
# Obs: [455 415 744   2], Reward: -31, terminated: False, total_rewards: -1530
# [3 0 3]
# Obs: [455  81 420   2], Reward: -31, terminated: False, total_rewards: -1561
# [3 4 4]
# Obs: [455  81 420   2], Reward: -40, terminated: False, total_rewards: -1601
# [2 4 4]
# Obs: [775  81 420   2], Reward: -30, terminated: False, total_rewards: -1631
# [2 2 0]
# Obs: [ 29 406 403   2], Reward: -12, terminated: False, total_rewards: -1643
# [4 1 3]
# Obs: [ 29 740  76   2], Reward: -21, terminated: False, total_rewards: -1664
# [1 1 2]
# Obs: [352 143 403   2], Reward: -30, terminated: False, total_rewards: -1694
# [3 4 2]
# Obs: [284 143 468   2], Reward: -30, terminated: False, total_rewards: -1724
# [4 4 3]
# Obs: [284 143 403   2], Reward: -30, terminated: False, total_rewards: -1754
# [0 2 3]
# Obs: [775 212  76   2], Reward: -30, terminated: False, total_rewards: -1784
# [2 4 3]
# Obs: [ 29 212  76   2], Reward: -31, terminated: False, total_rewards: -1815
# [2 0 0]
# Obs: [ 90 808 594   2], Reward: -12, terminated: False, total_rewards: -1827
# [2 0 2]
# Obs: [419 472 667   2], Reward: -12, terminated: False, total_rewards: -1839
# [0 3 4]
# Obs: [175 406 667   2], Reward: -30, terminated: False, total_rewards: -1869
# [4 0 1]
# Obs: [175 673 403   2], Reward: -21, terminated: False, total_rewards: -1890
# [0 1 3]
# Obs: [175 406  76   2], Reward: -40, terminated: False, total_rewards: -1930
# [4 1 4]
# Obs: [175 740  76   2], Reward: -30, terminated: False, total_rewards: -1960
# [4 1 4]
# Obs: [175 143  76   2], Reward: -30, terminated: False, total_rewards: -1990
# [4 3 0]
# Obs: [175 641 594   2], Reward: -21, terminated: False, total_rewards: -2011
# [1 3 4]
# Obs: [419 571 594   2], Reward: -21, terminated: False, total_rewards: -2032
# [2 0 4]
# Obs: [483 342 594   2], Reward: -21, terminated: False, total_rewards: -2053
# [4 3 4]
# Obs: [483  25 594   2], Reward: -21, terminated: False, total_rewards: -2074
# [2 0 2]
# Obs: [812 504 667   2], Reward: -21, terminated: False, total_rewards: -2095
# [1 2 3]
# Obs: [316  17 594   2], Reward: -12, terminated: False, total_rewards: -2107
# [3 4 1]
# Obs: [ 4 17 76  2], Reward: -21, terminated: False, total_rewards: -2128
# [1 3 0]
# Obs: [282 504 594   2], Reward: -21, terminated: False, total_rewards: -2149
# [0 0 1]
# Obs: [  4 207  76   2], Reward: -21, terminated: False, total_rewards: -2170
# [4 3 2]
# Obs: [  4 139 403   2], Reward: -21, terminated: False, total_rewards: -2191
# [1 0 1]
# Obs: [282 625 420   2], Reward: -21, terminated: False, total_rewards: -2212
# [3 2 4]
# Obs: [215 700 420   2], Reward: -12, terminated: False, total_rewards: -2224
# [0 4 1]
# Obs: [748 700 420   2], Reward: -31, terminated: False, total_rewards: -2255
# [4 2 0]
# Obs: [748 196 403   2], Reward: -21, terminated: False, total_rewards: -2276
# [2 3 3]
# Obs: [  4 700  76   2], Reward: -30, terminated: False, total_rewards: -2306
# [3 2 1]
# Obs: [748 196  76   2], Reward: -40, terminated: False, total_rewards: -2346
# [0 3 2]
# Obs: [419 700 403   2], Reward: -30, terminated: False, total_rewards: -2376
# [1 4 0]
# Obs: [748 700 667   2], Reward: -30, terminated: False, total_rewards: -2406
# [4 4 2]
# Obs: [748 700 164   2], Reward: -21, terminated: False, total_rewards: -2427
# [1 2 1]
# Obs: [215 196 468   2], Reward: -30, terminated: False, total_rewards: -2457
# [3 2 1]
# Obs: [145 268 744   2], Reward: -12, terminated: False, total_rewards: -2469
# [1 3 1]
# Obs: [486 196 202   2], Reward: -12, terminated: False, total_rewards: -2481
# [4 1 3]
# Obs: [486 535 202   2], Reward: -31, terminated: False, total_rewards: -2512
# [1 3 1]
# Obs: [717 207 202   2], Reward: -31, terminated: False, total_rewards: -2543
# [1 4 2]
# Obs: [224 207 272   2], Reward: -21, terminated: False, total_rewards: -2564
# [2 3 4]
# Obs: [294 139 272   2], Reward: -21, terminated: False, total_rewards: -2585
# [4 4 3]
# Obs: [294 139 202   2], Reward: -30, terminated: False, total_rewards: -2615
# [2 4 3]
# Obs: [365 139 202   2], Reward: -31, terminated: False, total_rewards: -2646
# [2 4 4]
# Obs: [688 139 202   2], Reward: -21, terminated: False, total_rewards: -2667
# [0 2 2]
# Obs: [354 207 272   2], Reward: -21, terminated: False, total_rewards: -2688
# [0 0 3]
# Obs: [122 700 202   2], Reward: -21, terminated: False, total_rewards: -2709
# [4 4 2]
# Obs: [122 700 272   2], Reward: -30, terminated: False, total_rewards: -2739
# [2 4 3]
# Obs: [186 700 202   2], Reward: -21, terminated: False, total_rewards: -2760
# [0 0 3]
# Obs: [679 366 202   2], Reward: -22, terminated: False, total_rewards: -2782
# [0 4 2]
# Obs: [390 366 272   2], Reward: -21, terminated: False, total_rewards: -2803
# [2 4 0]
# Obs: [713 366 813   2], Reward: -21, terminated: False, total_rewards: -2824
# [3 0 1]
# Obs: [390 131 272   2], Reward: -21, terminated: False, total_rewards: -2845
# [3 0 4]
# Obs: [316 617 272   2], Reward: -21, terminated: False, total_rewards: -2866
# [2 3 4]
# Obs: [390 549 272   2], Reward: -21, terminated: False, total_rewards: -2887
# [0 4 4]
# Obs: [ 62 549 272   2], Reward: -21, terminated: False, total_rewards: -2908
# [4 1 4]
# Obs: [ 62  73 272   2], Reward: -21, terminated: False, total_rewards: -2929
# [4 0 1]
# Obs: [ 62 549 609   2], Reward: -30, terminated: False, total_rewards: -2959
# [3 1 2]
# Obs: [812  73 116   2], Reward: -30, terminated: False, total_rewards: -2989
# [3 0 3]
# Obs: [483 549 609   2], Reward: -30, terminated: False, total_rewards: -3019
# [3 3 2]
# Obs: [419 489 116   2], Reward: -21, terminated: False, total_rewards: -3040
# [2 4 0]
# Obs: [483 489 595   2], Reward: -30, terminated: False, total_rewards: -3070
# [1 2 0]
# Obs: [  4 549 312   2], Reward: -21, terminated: False, total_rewards: -3091
# [2 1 0]
# Obs: [316  73  45   2], Reward: -21, terminated: False, total_rewards: -3112
# [1 2 1]
# Obs: [608 131 312   2], Reward: -21, terminated: False, total_rewards: -3133
# [0 0 0]
# Obs: [316 617  45   2], Reward: -30, terminated: False, total_rewards: -3163
# [1 1 4]
# Obs: [608 131  45   2], Reward: -30, terminated: False, total_rewards: -3193
# [3 0 0]
# Obs: [282 617 558   2], Reward: -21, terminated: False, total_rewards: -3214
# [4 0 1]
# Obs: [282 327  45   2], Reward: -21, terminated: False, total_rewards: -3235
# [3 4 4]
# Obs: [215 327  45   2], Reward: -30, terminated: False, total_rewards: -3265
# [1 0 1]
# Obs: [548   5 312   2], Reward: -12, terminated: False, total_rewards: -3277
# [0 1 3]
# Obs: [215 327 813   2], Reward: -30, terminated: False, total_rewards: -3307
# [1 4 4]
# Obs: [548 327 813   2], Reward: -30, terminated: False, total_rewards: -3337
# [1 1 2]
# Obs: [788 617 312   2], Reward: -21, terminated: False, total_rewards: -3358
# [1 0 0]
# Obs: [294 327  45   2], Reward: -30, terminated: False, total_rewards: -3388
# [4 3 2]
# Obs: [294 255 105   2], Reward: -21, terminated: False, total_rewards: -3409
# [0 0 0]
# Obs: [788 749 627   2], Reward: -12, terminated: False, total_rewards: -3421
# [2 0 4]
# Obs: [ 38 474 627   2], Reward: -12, terminated: False, total_rewards: -3433
# [1 0 0]
# Obs: [365 176 296   2], Reward: -12, terminated: False, total_rewards: -3445
# [3 3 3]
# Obs: [294 114 225   2], Reward: -12, terminated: False, total_rewards: -3457
# [2 2 4]
# Obs: [365 176 225   2], Reward: -30, terminated: False, total_rewards: -3487
# [0 3 4]
# Obs: [ 38 114 225   2], Reward: -30, terminated: False, total_rewards: -3517
# [2 4 2]
# Obs: [354 114 296   2], Reward: -30, terminated: False, total_rewards: -3547
# [1 0 2]
# Obs: [688 593 620   2], Reward: -12, terminated: False, total_rewards: -3559
# [3 1 3]
# Obs: [365 114 296   2], Reward: -30, terminated: False, total_rewards: -3589
# [2 1 3]
# Obs: [688 409 225   2], Reward: -21, terminated: False, total_rewards: -3610
# [4 0 4]
# Obs: [688 114 225   2], Reward: -30, terminated: False, total_rewards: -3640
# [2 2 1]
# Obs: [760 176 558   2], Reward: -21, terminated: False, total_rewards: -3661
# [4 2 3]
# Obs: [760 247 234   2], Reward: -12, terminated: False, total_rewards: -3673
# [3 4 1]
# Obs: [688 247 530   2], Reward: -21, terminated: False, total_rewards: -3694
# [3 2 3]
# Obs: [365 570 468   2], Reward: -21, terminated: False, total_rewards: -3715
# [0 4 0]
# Obs: [ 38 570 164   2], Reward: -30, terminated: False, total_rewards: -3745
# [1 4 1]
# Obs: [365 570 468   2], Reward: -30, terminated: False, total_rewards: -3775
# [2 2 3]
# Obs: [688 640 403   2], Reward: -21, terminated: False, total_rewards: -3796
# [1 1 2]
# Obs: [195 110 468   2], Reward: -12, terminated: False, total_rewards: -3808
# [1 3 3]
# Obs: [498  51 403   2], Reward: -12, terminated: False, total_rewards: -3820
# [3 0 1]
# Obs: [161 570 420   2], Reward: -21, terminated: False, total_rewards: -3841
# [0 2 4]
# Obs: [699 640 420   2], Reward: -21, terminated: False, total_rewards: -3862
# [2 4 4]
# Obs: [195 640 420   2], Reward: -30, terminated: False, total_rewards: -3892
# [1 2 1]
# Obs: [498 142 420   2], Reward: -31, terminated: False, total_rewards: -3923
# [1 3 3]
# Obs: [771 640 420   2], Reward: -31, terminated: False, total_rewards: -3954
# [1 0 1]
# Obs: [233 307 420   2], Reward: -22, terminated: False, total_rewards: -3976
# [2 4 3]
# Obs: [307 307 420   2], Reward: -100040, terminated: True, total_rewards: -104016
# terminated: True truncated: False

# %%
# Close the environment
env.close()
# Set a breakpoint, will give an error
assert False, "breakpoint"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 4
#       2 env.close()
#       3 # Set a breakpoint, will give an error
# ----> 4 assert False, "breakpoint"
#
# AssertionError: breakpoint

# %% [markdown]
# # Training cells!

# %% [markdown]
# Advantage actor-critic:

# %%
# Advantage Actor Critic
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

vec_env = make_vec_env('ThreeAgentGridworld-v0', n_envs=4)

model = A2C("MlpPolicy", vec_env, verbose=1, tensorboard_log="./a2c_log1", gamma=0.99)
model.learn(total_timesteps=1000000)
model.save("multi_agent_a2c_w1")
del model, A2C, make_vec_env
# Out:
# Using cuda device
# Logging to ./a2c_log1\A2C_1
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 209       |
# |    ep_rew_mean        | -1.05e+05 |
# | time/                 |           |
# |    fps                | 688       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -4.83     |
# |    explained_variance | 0.00483   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -344      |
# |    value_loss         | 6.34e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 355       |
# |    ep_rew_mean        | -8.63e+04 |
# | time/                 |           |
# |    fps                | 718       |
# |    iterations         | 200       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -4.82     |
# |    explained_variance | 0.000915  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -366      |
# |    value_loss         | 6.97e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 355       |
# |    ep_rew_mean        | -8.63e+04 |
# | time/                 |           |
# |    fps                | 707       |
# |    iterations         | 300       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -4.82     |
# |    explained_variance | 0.00124   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -403      |
# |    value_loss         | 8.56e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 392       |
# |    ep_rew_mean        | -8.94e+04 |
# | time/                 |           |
# |    fps                | 674       |
# |    iterations         | 400       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -4.82     |
# |    explained_variance | 3.56e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -381      |
# |    value_loss         | 7.96e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 607       |
# |    ep_rew_mean        | -6.19e+04 |
# | time/                 |           |
# |    fps                | 657       |
# |    iterations         | 500       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -4.81     |
# |    explained_variance | 0.000195  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -371      |
# |    value_loss         | 7.6e+03   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 621      |
# |    ep_rew_mean        | -5.3e+04 |
# | time/                 |          |
# |    fps                | 647      |
# |    iterations         | 600      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -4.8     |
# |    explained_variance | 3.84e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -275     |
# |    value_loss         | 5.15e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 613       |
# |    ep_rew_mean        | -5.98e+04 |
# | time/                 |           |
# |    fps                | 638       |
# |    iterations         | 700       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -4.8      |
# |    explained_variance | 5.26e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -396      |
# |    value_loss         | 8.16e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 624       |
# |    ep_rew_mean        | -6.35e+04 |
# | time/                 |           |
# |    fps                | 634       |
# |    iterations         | 800       |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -4.8      |
# |    explained_variance | 1e-05     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -383      |
# |    value_loss         | 7.67e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 596       |
# |    ep_rew_mean        | -6.49e+04 |
# | time/                 |           |
# |    fps                | 630       |
# |    iterations         | 900       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -4.75     |
# |    explained_variance | -6.99e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -346      |
# |    value_loss         | 6.82e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 605       |
# |    ep_rew_mean        | -6.36e+04 |
# | time/                 |           |
# |    fps                | 627       |
# |    iterations         | 1000      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -4.72     |
# |    explained_variance | -9.66e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -372      |
# |    value_loss         | 9.01e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 573       |
# |    ep_rew_mean        | -6.72e+04 |
# | time/                 |           |
# |    fps                | 625       |
# |    iterations         | 1100      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -4.79     |
# |    explained_variance | 2.66e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -332      |
# |    value_loss         | 6.11e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 537       |
# |    ep_rew_mean        | -6.06e+04 |
# | time/                 |           |
# |    fps                | 623       |
# |    iterations         | 1200      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -4.81     |
# |    explained_variance | 5.36e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -405      |
# |    value_loss         | 8.65e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 590       |
# |    ep_rew_mean        | -5.07e+04 |
# | time/                 |           |
# |    fps                | 621       |
# |    iterations         | 1300      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -4.77     |
# |    explained_variance | 8.34e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -413      |
# |    value_loss         | 9.32e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 587       |
# |    ep_rew_mean        | -5.21e+04 |
# | time/                 |           |
# |    fps                | 619       |
# |    iterations         | 1400      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -4.78     |
# |    explained_variance | -4.29e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -386      |
# |    value_loss         | 9.57e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 587       |
# |    ep_rew_mean        | -5.21e+04 |
# | time/                 |           |
# |    fps                | 618       |
# |    iterations         | 1500      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -4.8      |
# |    explained_variance | 5.36e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -409      |
# |    value_loss         | 8.96e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 640       |
# |    ep_rew_mean        | -5.2e+04  |
# | time/                 |           |
# |    fps                | 616       |
# |    iterations         | 1600      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -4.79     |
# |    explained_variance | -3.22e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -380      |
# |    value_loss         | 7.22e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 673       |
# |    ep_rew_mean        | -4.87e+04 |
# | time/                 |           |
# |    fps                | 615       |
# |    iterations         | 1700      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -4.78     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -348      |
# |    value_loss         | 6.5e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 676       |
# |    ep_rew_mean        | -4.75e+04 |
# | time/                 |           |
# |    fps                | 614       |
# |    iterations         | 1800      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -4.78     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -418      |
# |    value_loss         | 9.27e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 669       |
# |    ep_rew_mean        | -5.12e+04 |
# | time/                 |           |
# |    fps                | 613       |
# |    iterations         | 1900      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -4.72     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -260      |
# |    value_loss         | 3.7e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 630       |
# |    ep_rew_mean        | -5e+04    |
# | time/                 |           |
# |    fps                | 613       |
# |    iterations         | 2000      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -4.71     |
# |    explained_variance | -7.15e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -344      |
# |    value_loss         | 6.13e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 630       |
# |    ep_rew_mean        | -5.3e+04  |
# | time/                 |           |
# |    fps                | 611       |
# |    iterations         | 2100      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -4.68     |
# |    explained_variance | -2.38e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -292      |
# |    value_loss         | 5.83e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 616       |
# |    ep_rew_mean        | -5.34e+04 |
# | time/                 |           |
# |    fps                | 611       |
# |    iterations         | 2200      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -4.49     |
# |    explained_variance | 3.58e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -355      |
# |    value_loss         | 7.77e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 627       |
# |    ep_rew_mean        | -4.98e+04 |
# | time/                 |           |
# |    fps                | 610       |
# |    iterations         | 2300      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -4.72     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -405      |
# |    value_loss         | 1.02e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 616       |
# |    ep_rew_mean        | -5.21e+04 |
# | time/                 |           |
# |    fps                | 610       |
# |    iterations         | 2400      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -4.59     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -273      |
# |    value_loss         | 4.77e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 608       |
# |    ep_rew_mean        | -5.43e+04 |
# | time/                 |           |
# |    fps                | 609       |
# |    iterations         | 2500      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -4.76     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -378      |
# |    value_loss         | 8.15e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 594       |
# |    ep_rew_mean        | -5.51e+04 |
# | time/                 |           |
# |    fps                | 609       |
# |    iterations         | 2600      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 52000     |
# | train/                |           |
# |    entropy_loss       | -4.76     |
# |    explained_variance | -1.91e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -341      |
# |    value_loss         | 6.5e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 577       |
# |    ep_rew_mean        | -5.67e+04 |
# | time/                 |           |
# |    fps                | 608       |
# |    iterations         | 2700      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 54000     |
# | train/                |           |
# |    entropy_loss       | -4.8      |
# |    explained_variance | -1.31e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -416      |
# |    value_loss         | 9.9e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 595       |
# |    ep_rew_mean        | -5.32e+04 |
# | time/                 |           |
# |    fps                | 608       |
# |    iterations         | 2800      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 56000     |
# | train/                |           |
# |    entropy_loss       | -4.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -270      |
# |    value_loss         | 3.82e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 582       |
# |    ep_rew_mean        | -5.67e+04 |
# | time/                 |           |
# |    fps                | 608       |
# |    iterations         | 2900      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 58000     |
# | train/                |           |
# |    entropy_loss       | -4.75     |
# |    explained_variance | -1.67e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -274      |
# |    value_loss         | 4.26e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 577       |
# |    ep_rew_mean        | -5.57e+04 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 3000      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 60000     |
# | train/                |           |
# |    entropy_loss       | -4.69     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -291      |
# |    value_loss         | 4.94e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 576       |
# |    ep_rew_mean        | -5.57e+04 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 3100      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 62000     |
# | train/                |           |
# |    entropy_loss       | -4.71     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -342      |
# |    value_loss         | 6.34e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 570       |
# |    ep_rew_mean        | -5.55e+04 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 3200      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 64000     |
# | train/                |           |
# |    entropy_loss       | -4.73     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -363      |
# |    value_loss         | 7.09e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 555       |
# |    ep_rew_mean        | -5.91e+04 |
# | time/                 |           |
# |    fps                | 606       |
# |    iterations         | 3300      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 66000     |
# | train/                |           |
# |    entropy_loss       | -4.57     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -1.17e+05 |
# |    value_loss         | 2.4e+09   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 525       |
# |    ep_rew_mean        | -5.83e+04 |
# | time/                 |           |
# |    fps                | 606       |
# |    iterations         | 3400      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 68000     |
# | train/                |           |
# |    entropy_loss       | -4.64     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -307      |
# |    value_loss         | 5.6e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 498       |
# |    ep_rew_mean        | -6.16e+04 |
# | time/                 |           |
# |    fps                | 606       |
# |    iterations         | 3500      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 70000     |
# | train/                |           |
# |    entropy_loss       | -4.65     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -368      |
# |    value_loss         | 8.19e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 440       |
# |    ep_rew_mean        | -7.09e+04 |
# | time/                 |           |
# |    fps                | 605       |
# |    iterations         | 3600      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 72000     |
# | train/                |           |
# |    entropy_loss       | -4.32     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -233      |
# |    value_loss         | 5.29e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 389       |
# |    ep_rew_mean        | -7.95e+04 |
# | time/                 |           |
# |    fps                | 605       |
# |    iterations         | 3700      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 74000     |
# | train/                |           |
# |    entropy_loss       | -4.73     |
# |    explained_variance | 3.58e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -347      |
# |    value_loss         | 6.8e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 380       |
# |    ep_rew_mean        | -7.92e+04 |
# | time/                 |           |
# |    fps                | 605       |
# |    iterations         | 3800      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 76000     |
# | train/                |           |
# |    entropy_loss       | -4.36     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -302      |
# |    value_loss         | 6.13e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 359       |
# |    ep_rew_mean        | -8.27e+04 |
# | time/                 |           |
# |    fps                | 605       |
# |    iterations         | 3900      |
# |    time_elapsed       | 128       |
# |    total_timesteps    | 78000     |
# | train/                |           |
# |    entropy_loss       | -4.33     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -411      |
# |    value_loss         | 1.01e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 328       |
# |    ep_rew_mean        | -8.79e+04 |
# | time/                 |           |
# |    fps                | 604       |
# |    iterations         | 4000      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 80000     |
# | train/                |           |
# |    entropy_loss       | -4.18     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -248      |
# |    value_loss         | 7.19e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 294      |
# |    ep_rew_mean        | -9.3e+04 |
# | time/                 |          |
# |    fps                | 604      |
# |    iterations         | 4100     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -4.55    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -385     |
# |    value_loss         | 9.42e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 272       |
# |    ep_rew_mean        | -9.44e+04 |
# | time/                 |           |
# |    fps                | 604       |
# |    iterations         | 4200      |
# |    time_elapsed       | 138       |
# |    total_timesteps    | 84000     |
# | train/                |           |
# |    entropy_loss       | -4.61     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -303      |
# |    value_loss         | 5.93e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 268       |
# |    ep_rew_mean        | -9.43e+04 |
# | time/                 |           |
# |    fps                | 604       |
# |    iterations         | 4300      |
# |    time_elapsed       | 142       |
# |    total_timesteps    | 86000     |
# | train/                |           |
# |    entropy_loss       | -4.52     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -337      |
# |    value_loss         | 6.79e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 266       |
# |    ep_rew_mean        | -9.43e+04 |
# | time/                 |           |
# |    fps                | 604       |
# |    iterations         | 4400      |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -4.37     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -311      |
# |    value_loss         | 6.41e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 271       |
# |    ep_rew_mean        | -9.65e+04 |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 4500      |
# |    time_elapsed       | 149       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -4.64     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -315      |
# |    value_loss         | 6.01e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 266       |
# |    ep_rew_mean        | -9.63e+04 |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 4600      |
# |    time_elapsed       | 152       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -4.7      |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -376      |
# |    value_loss         | 7.93e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 261       |
# |    ep_rew_mean        | -9.82e+04 |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 4700      |
# |    time_elapsed       | 155       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -4.55     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -342      |
# |    value_loss         | 7.1e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 271       |
# |    ep_rew_mean        | -9.65e+04 |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 4800      |
# |    time_elapsed       | 159       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -4.7      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -266      |
# |    value_loss         | 4.86e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 300       |
# |    ep_rew_mean        | -9.53e+04 |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 4900      |
# |    time_elapsed       | 162       |
# |    total_timesteps    | 98000     |
# | train/                |           |
# |    entropy_loss       | -4.64     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -317      |
# |    value_loss         | 5.41e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 304       |
# |    ep_rew_mean        | -9.34e+04 |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 5000      |
# |    time_elapsed       | 165       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -3.94     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -236      |
# |    value_loss         | 5.11e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 310       |
# |    ep_rew_mean        | -9.16e+04 |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 5100      |
# |    time_elapsed       | 169       |
# |    total_timesteps    | 102000    |
# | train/                |           |
# |    entropy_loss       | -4.42     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -313      |
# |    value_loss         | 8.02e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 315       |
# |    ep_rew_mean        | -9.17e+04 |
# | time/                 |           |
# |    fps                | 603       |
# |    iterations         | 5200      |
# |    time_elapsed       | 172       |
# |    total_timesteps    | 104000    |
# | train/                |           |
# |    entropy_loss       | -4.35     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -279      |
# |    value_loss         | 5.78e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 317       |
# |    ep_rew_mean        | -8.97e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 5300      |
# |    time_elapsed       | 175       |
# |    total_timesteps    | 106000    |
# | train/                |           |
# |    entropy_loss       | -4.24     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -298      |
# |    value_loss         | 6.09e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 309       |
# |    ep_rew_mean        | -8.76e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 5400      |
# |    time_elapsed       | 179       |
# |    total_timesteps    | 108000    |
# | train/                |           |
# |    entropy_loss       | -4.09     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -220      |
# |    value_loss         | 3.59e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 326      |
# |    ep_rew_mean        | -8.8e+04 |
# | time/                 |          |
# |    fps                | 602      |
# |    iterations         | 5500     |
# |    time_elapsed       | 182      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -4.25    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -286     |
# |    value_loss         | 5.79e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 326      |
# |    ep_rew_mean        | -8.8e+04 |
# | time/                 |          |
# |    fps                | 602      |
# |    iterations         | 5600     |
# |    time_elapsed       | 185      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -4.21    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -348     |
# |    value_loss         | 1.22e+04 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 340       |
# |    ep_rew_mean        | -8.85e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 5700      |
# |    time_elapsed       | 189       |
# |    total_timesteps    | 114000    |
# | train/                |           |
# |    entropy_loss       | -3.96     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -343      |
# |    value_loss         | 1.42e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 352       |
# |    ep_rew_mean        | -8.69e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 5800      |
# |    time_elapsed       | 192       |
# |    total_timesteps    | 116000    |
# | train/                |           |
# |    entropy_loss       | -4.25     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -1.13e+05 |
# |    value_loss         | 2.39e+09  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 353      |
# |    ep_rew_mean        | -8.7e+04 |
# | time/                 |          |
# |    fps                | 602      |
# |    iterations         | 5900     |
# |    time_elapsed       | 195      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -4.57    |
# |    explained_variance | 3.58e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -417     |
# |    value_loss         | 9.91e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 361       |
# |    ep_rew_mean        | -8.52e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 6000      |
# |    time_elapsed       | 199       |
# |    total_timesteps    | 120000    |
# | train/                |           |
# |    entropy_loss       | -4.58     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -412      |
# |    value_loss         | 1.16e+04  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 382      |
# |    ep_rew_mean        | -8.6e+04 |
# | time/                 |          |
# |    fps                | 602      |
# |    iterations         | 6100     |
# |    time_elapsed       | 202      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -4.62    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -317     |
# |    value_loss         | 6.65e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 403       |
# |    ep_rew_mean        | -8.56e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 6200      |
# |    time_elapsed       | 205       |
# |    total_timesteps    | 124000    |
# | train/                |           |
# |    entropy_loss       | -4.47     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -286      |
# |    value_loss         | 5.85e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 412       |
# |    ep_rew_mean        | -8.79e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 6300      |
# |    time_elapsed       | 209       |
# |    total_timesteps    | 126000    |
# | train/                |           |
# |    entropy_loss       | -4.68     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -359      |
# |    value_loss         | 7.92e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 414       |
# |    ep_rew_mean        | -8.99e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 6400      |
# |    time_elapsed       | 212       |
# |    total_timesteps    | 128000    |
# | train/                |           |
# |    entropy_loss       | -4.61     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -375      |
# |    value_loss         | 8.49e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 427       |
# |    ep_rew_mean        | -9.03e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 6500      |
# |    time_elapsed       | 215       |
# |    total_timesteps    | 130000    |
# | train/                |           |
# |    entropy_loss       | -3.59     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -220      |
# |    value_loss         | 8.23e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 445       |
# |    ep_rew_mean        | -9.08e+04 |
# | time/                 |           |
# |    fps                | 602       |
# |    iterations         | 6600      |
# |    time_elapsed       | 219       |
# |    total_timesteps    | 132000    |
# | train/                |           |
# |    entropy_loss       | -4.57     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -338      |
# |    value_loss         | 7.67e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 443       |
# |    ep_rew_mean        | -9.07e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 6700      |
# |    time_elapsed       | 222       |
# |    total_timesteps    | 134000    |
# | train/                |           |
# |    entropy_loss       | -3.93     |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -163      |
# |    value_loss         | 2.63e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 410       |
# |    ep_rew_mean        | -9.18e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 6800      |
# |    time_elapsed       | 225       |
# |    total_timesteps    | 136000    |
# | train/                |           |
# |    entropy_loss       | -4.4      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -377      |
# |    value_loss         | 9.22e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 405       |
# |    ep_rew_mean        | -9.17e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 6900      |
# |    time_elapsed       | 229       |
# |    total_timesteps    | 138000    |
# | train/                |           |
# |    entropy_loss       | -4.55     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -336      |
# |    value_loss         | 6.16e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 399       |
# |    ep_rew_mean        | -9.35e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 7000      |
# |    time_elapsed       | 232       |
# |    total_timesteps    | 140000    |
# | train/                |           |
# |    entropy_loss       | -4.38     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -327      |
# |    value_loss         | 6.89e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 402       |
# |    ep_rew_mean        | -9.36e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 7100      |
# |    time_elapsed       | 235       |
# |    total_timesteps    | 142000    |
# | train/                |           |
# |    entropy_loss       | -4.63     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -285      |
# |    value_loss         | 5.28e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 429       |
# |    ep_rew_mean        | -9.24e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 7200      |
# |    time_elapsed       | 239       |
# |    total_timesteps    | 144000    |
# | train/                |           |
# |    entropy_loss       | -4.46     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -309      |
# |    value_loss         | 6.23e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 435       |
# |    ep_rew_mean        | -9.05e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 7300      |
# |    time_elapsed       | 242       |
# |    total_timesteps    | 146000    |
# | train/                |           |
# |    entropy_loss       | -3.91     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -288      |
# |    value_loss         | 7.42e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 409       |
# |    ep_rew_mean        | -9.39e+04 |
# | time/                 |           |
# |    fps                | 601       |
# |    iterations         | 7400      |
# |    time_elapsed       | 246       |
# |    total_timesteps    | 148000    |
# | train/                |           |
# |    entropy_loss       | -4.23     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -373      |
# |    value_loss         | 7.95e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 426       |
# |    ep_rew_mean        | -9.23e+04 |
# | time/                 |           |
# |    fps                | 601       |
# ...
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 125       |
# |    ep_rew_mean        | 7.41e+04  |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 47600     |
# |    time_elapsed       | 1567      |
# |    total_timesteps    | 952000    |
# | train/                |           |
# |    entropy_loss       | -2.99     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47599     |
# |    policy_loss        | -226      |
# |    value_loss         | 7.91e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 125       |
# |    ep_rew_mean        | 7.41e+04  |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 47700     |
# |    time_elapsed       | 1571      |
# |    total_timesteps    | 954000    |
# | train/                |           |
# |    entropy_loss       | -2.12     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47699     |
# |    policy_loss        | -227      |
# |    value_loss         | 1.92e+04  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | 7.16e+04 |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 47800    |
# |    time_elapsed       | 1574     |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | -2.32    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47799    |
# |    policy_loss        | -234     |
# |    value_loss         | 1.66e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 159      |
# |    ep_rew_mean        | 6.9e+04  |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 47900    |
# |    time_elapsed       | 1577     |
# |    total_timesteps    | 958000   |
# | train/                |          |
# |    entropy_loss       | -2.45    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47899    |
# |    policy_loss        | -223     |
# |    value_loss         | 1.08e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | 5.71e+04 |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 48000    |
# |    time_elapsed       | 1580     |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47999    |
# |    policy_loss        | -230     |
# |    value_loss         | 7.06e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 223       |
# |    ep_rew_mean        | 5.06e+04  |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 48100     |
# |    time_elapsed       | 1584      |
# |    total_timesteps    | 962000    |
# | train/                |           |
# |    entropy_loss       | -2.09     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48099     |
# |    policy_loss        | -8.12e+04 |
# |    value_loss         | 1.94e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 241       |
# |    ep_rew_mean        | 4.21e+04  |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 48200     |
# |    time_elapsed       | 1587      |
# |    total_timesteps    | 964000    |
# | train/                |           |
# |    entropy_loss       | -2.97     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48199     |
# |    policy_loss        | -184      |
# |    value_loss         | 5.27e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 258      |
# |    ep_rew_mean        | 3.97e+04 |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 48300    |
# |    time_elapsed       | 1590     |
# |    total_timesteps    | 966000   |
# | train/                |          |
# |    entropy_loss       | -2.57    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | -298     |
# |    value_loss         | 1.12e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 263      |
# |    ep_rew_mean        | 3.55e+04 |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 48400    |
# |    time_elapsed       | 1593     |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | -1.85    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48399    |
# |    policy_loss        | -190     |
# |    value_loss         | 1.16e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 305      |
# |    ep_rew_mean        | 2.6e+04  |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 48500    |
# |    time_elapsed       | 1597     |
# |    total_timesteps    | 970000   |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | -199     |
# |    value_loss         | 5.34e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 320      |
# |    ep_rew_mean        | 1.16e+04 |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 48600    |
# |    time_elapsed       | 1600     |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | -144     |
# |    value_loss         | 5.71e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 332      |
# |    ep_rew_mean        | 7.31e+03 |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 48700    |
# |    time_elapsed       | 1603     |
# |    total_timesteps    | 974000   |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48699    |
# |    policy_loss        | -300     |
# |    value_loss         | 8.28e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 355      |
# |    ep_rew_mean        | 634      |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 48800    |
# |    time_elapsed       | 1606     |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | -2.1     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | -207     |
# |    value_loss         | 7.26e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 367       |
# |    ep_rew_mean        | 265       |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 48900     |
# |    time_elapsed       | 1610      |
# |    total_timesteps    | 978000    |
# | train/                |           |
# |    entropy_loss       | -1.78     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48899     |
# |    policy_loss        | -101      |
# |    value_loss         | 6.48e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 373      |
# |    ep_rew_mean        | 85.6     |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 49000    |
# |    time_elapsed       | 1613     |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | -2.37    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | -165     |
# |    value_loss         | 8.39e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 399       |
# |    ep_rew_mean        | -2.72e+03 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 49100     |
# |    time_elapsed       | 1616      |
# |    total_timesteps    | 982000    |
# | train/                |           |
# |    entropy_loss       | -1.81     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49099     |
# |    policy_loss        | -130      |
# |    value_loss         | 7.68e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 432       |
# |    ep_rew_mean        | -6.77e+03 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 49200     |
# |    time_elapsed       | 1619      |
# |    total_timesteps    | 984000    |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49199     |
# |    policy_loss        | -1.52e+04 |
# |    value_loss         | 4.99e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 429       |
# |    ep_rew_mean        | -9.51e+03 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 49300     |
# |    time_elapsed       | 1623      |
# |    total_timesteps    | 986000    |
# | train/                |           |
# |    entropy_loss       | -1.73     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49299     |
# |    policy_loss        | -82.7     |
# |    value_loss         | 2.97e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 445      |
# |    ep_rew_mean        | -1.6e+04 |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 49400    |
# |    time_elapsed       | 1626     |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | -1.83    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49399    |
# |    policy_loss        | -80.6    |
# |    value_loss         | 2.81e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 411       |
# |    ep_rew_mean        | -1.58e+04 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 49500     |
# |    time_elapsed       | 1629      |
# |    total_timesteps    | 990000    |
# | train/                |           |
# |    entropy_loss       | -2.34     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49499     |
# |    policy_loss        | -164      |
# |    value_loss         | 6.58e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 349       |
# |    ep_rew_mean        | -1.35e+04 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 49600     |
# |    time_elapsed       | 1632      |
# |    total_timesteps    | 992000    |
# | train/                |           |
# |    entropy_loss       | -3.09     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49599     |
# |    policy_loss        | -274      |
# |    value_loss         | 7.44e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 325       |
# |    ep_rew_mean        | -5.54e+03 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 49700     |
# |    time_elapsed       | 1636      |
# |    total_timesteps    | 994000    |
# | train/                |           |
# |    entropy_loss       | -1.46     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49699     |
# |    policy_loss        | -154      |
# |    value_loss         | 6.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 323       |
# |    ep_rew_mean        | -1.49e+03 |
# | time/                 |           |
# |    fps                | 607       |
# |    iterations         | 49800     |
# |    time_elapsed       | 1639      |
# |    total_timesteps    | 996000    |
# | train/                |           |
# |    entropy_loss       | -2.75     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49799     |
# |    policy_loss        | -208      |
# |    value_loss         | 1.18e+04  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 305      |
# |    ep_rew_mean        | 936      |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 49900    |
# |    time_elapsed       | 1642     |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | -1.94    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49899    |
# |    policy_loss        | -180     |
# |    value_loss         | 6.3e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 293      |
# |    ep_rew_mean        | 3.44e+03 |
# | time/                 |          |
# |    fps                | 607      |
# |    iterations         | 50000    |
# |    time_elapsed       | 1645     |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | -2.24    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49999    |
# |    policy_loss        | -158     |
# |    value_loss         | 5.64e+03 |
# ------------------------------------

# %% [markdown]
# Proximal Policy Optimization

# %%
# Proximal Policy Optimization
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Training cell
vec_env = make_vec_env('ThreeAgentGridworld-v0', n_envs=4)

model = PPO("MlpPolicy", vec_env, verbose=1, tensorboard_log="./ppo_log1", gamma=0.99)
model.learn(total_timesteps=300000)
model.save("multi_agent_ppo_w1")
del model, PPO, make_vec_env
# Out:
# Using cuda device
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 8
#       5 # Training cell
#       6 vec_env = make_vec_env('ThreeAgentGridworld-v0', n_envs=4)
# ----> 8 model = PPO("MlpPolicy", vec_env, verbose=1, tensorboard_log="./ppo_log1", gamma=0.99)
#       9 model.learn(total_timesteps=300000)
#      10 model.save("multi_agent_ppo_w1")
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\stable_baselines3\ppo\ppo.py:171, in PPO.__init__(self, policy, env, learning_rate, n_steps, batch_size, n_epochs, gamma, gae_lambda, clip_range, clip_range_vf, normalize_advantage, ent_coef, vf_coef, max_grad_norm, use_sde, sde_sample_freq, rollout_buffer_class, rollout_buffer_kwargs, target_kl, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#     168 self.target_kl = target_kl
#     170 if _init_setup_model:
# --> 171     self._setup_model()
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\stable_baselines3\ppo\ppo.py:174, in PPO._setup_model(self)
#     173 def _setup_model(self) -> None:
# --> 174     super()._setup_model()
#     176     # Initialize schedules for policy/value clipping
#     177     self.clip_range = get_schedule_fn(self.clip_range)
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:137, in OnPolicyAlgorithm._setup_model(self)
#     124 self.rollout_buffer = self.rollout_buffer_class(
#     125     self.n_steps,
#     126     self.observation_space,  # type: ignore[arg-type]
#    (...)
#     132     **self.rollout_buffer_kwargs,
#     133 )
#     134 self.policy = self.policy_class(  # type: ignore[assignment]
#     135     self.observation_space, self.action_space, self.lr_schedule, use_sde=self.use_sde, **self.policy_kwargs
#     136 )
# --> 137 self.policy = self.policy.to(self.device)
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\torch\nn\modules\module.py:1152, in Module.to(self, *args, **kwargs)
#    1148         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                     non_blocking, memory_format=convert_to_format)
#    1150     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1152 return self._apply(convert)
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\torch\nn\modules\module.py:825, in Module._apply(self, fn, recurse)
#     821 # Tensors stored in modules are graph leaves, and we don't want to
#     822 # track autograd history of `param_applied`, so we have to use
#     823 # `with torch.no_grad():`
#     824 with torch.no_grad():
# --> 825     param_applied = fn(param)
#     826 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     827 if should_use_set_data:
#
# File c:\Users\choto\miniconda3\envs\weed\Lib\site-packages\torch\nn\modules\module.py:1150, in Module.to.<locals>.convert(t)
#    1147 if convert_to_format is not None and t.dim() in (4, 5):
#    1148     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                 non_blocking, memory_format=convert_to_format)
# -> 1150 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# # Inference

# %% [markdown]
# Play using trained network and default env (we can also use vector env):

# %%
import pygame
import gymnasium as gym
from stable_baselines3 import A2C # For PPO, need to change this

# Load trained network
model = A2C.load("multi_agent_a2c_w1")

# Make the environment
env = gym.make('ThreeAgentGridworld-v0', render_mode='human')
env.metadata['render_fps'] = 30
obs, info = env.reset()
# env.render()

# Start playing
terminated, truncated = False, False
total_rewards = 0
while True:
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated,  info = env.step(list(action))
    env.render()
    total_rewards += reward
    print(f"Obs: {obs}, Reward: {reward}, terminated: {terminated}, total_rewards: {total_rewards}")
    if terminated or truncated:
        print('terminated:', terminated, 'truncated:', truncated)
        break
    pygame.event.get()
# Out:
# Obs: [ 29 694 134   0], Reward: -3, terminated: False, total_rewards: -3
# Obs: [ 90 680 198   0], Reward: -3, terminated: False, total_rewards: -6
# Obs: [419 344 270   0], Reward: -3, terminated: False, total_rewards: -9
# Obs: [483 613 592   0], Reward: -3, terminated: False, total_rewards: -12
# Obs: [812 280 664   2], Reward: 97, terminated: False, total_rewards: 85
# Obs: [ 62 604 133   2], Reward: -3, terminated: False, total_rewards: 82
# Obs: [380 677 418   2], Reward: -3, terminated: False, total_rewards: 79
# Obs: [452 173 702   2], Reward: -3, terminated: False, total_rewards: 76
# Obs: [513 244 214   2], Reward: -3, terminated: False, total_rewards: 73
# Obs: [ 26 568 507   6], Reward: 97, terminated: False, total_rewards: 170
# Obs: [ 89 341  19   6], Reward: -3, terminated: False, total_rewards: 167
# Obs: [416 412  84   6], Reward: -3, terminated: False, total_rewards: 164
# Obs: [481  79 409   6], Reward: -3, terminated: False, total_rewards: 161
# Obs: [809 596 474   6], Reward: -3, terminated: False, total_rewards: 158
# Obs: [ 59 265 803   6], Reward: -3, terminated: False, total_rewards: 155
# Obs: [117 338  51   6], Reward: -3, terminated: False, total_rewards: 152
# Obs: [449 659 110   6], Reward: -3, terminated: False, total_rewards: 149
# Obs: [512 326 441   6], Reward: -3, terminated: False, total_rewards: 146
# Obs: [ 23  98 505   6], Reward: -3, terminated: False, total_rewards: 143
# Obs: [ 87 579  18   6], Reward: -3, terminated: False, total_rewards: 140
# Obs: [413 649  36   6], Reward: -3, terminated: False, total_rewards: 137
# Obs: [479 149 349   6], Reward: -3, terminated: False, total_rewards: 134
# Obs: [540 219 426   6], Reward: -3, terminated: False, total_rewards: 131
# Obs: [ 63 753 746   6], Reward: -3, terminated: False, total_rewards: 128
# Obs: [383   9   1  54], Reward: 197, terminated: False, total_rewards: 325
# Obs: [383 321 534  54], Reward: -12, terminated: False, total_rewards: 313
# Obs: [456 396  49  55], Reward: 100097, terminated: True, total_rewards: 100410
# terminated: True truncated: False

# %% [markdown]
# Playing using trained network and default env:

# %%
env.close()

# %%
# # Play using vec envs (not needed)
# vec_env = make_vec_env('ThreeAgentGridworld-v0', n_envs=1)
# obs = vec_env.reset()
# while True:
#     action, _states = model.predict(obs)
#     obs, rewards, dones, info = vec_env.step(action)
#     print(f"Obs: {obs}, Reward: {rewards}, dones: {dones}, info: {info}")
#     if dones.any():
#         print('dones:', dones)
#         print('rewards:', rewards)
#         break
#     vec_env.render("human")
